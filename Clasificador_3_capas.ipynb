# %% [markdown]
# # Código Clasificación buques mercantes utilizando 2 capas de CNN.

# %%
### Conocer version de paquetes y Hardware en uso
#------------------------------------------------------
#------------------------------------------------------
import sys
import tensorflow.keras
import keras
import pandas as pd
import sklearn as sk
import tensorflow as tf
import numpy as np
import platform

print(f"Plataforma (Software-Hardware): {platform.platform()}")
print(f"Versión de Python {sys.version}")
print(f"Versión de TensorFlow: {tf.__version__}")
print(f"versión de Pandas {pd.__version__}")
print(f"versión de Numpy {np.__version__}")
print(f"versión de Keras {keras.__version__}")
print(f"Versión de Scikit-Learn {sk.__version__}")
gpu = len(tf.config.list_physical_devices('GPU'))>0
print("GPU está", "Disponible" if gpu else "No Disponible")
#---------------------------------------------------------
# Out:
# Plataforma (Software-Hardware): Windows-10-10.0.19045-SP0
# Versión de Python 3.11.4 (tags/v3.11.4:d2340ef, Jun  7 2023, 05:45:37) [MSC v.1934 64 bit (AMD64)]
# Versión de TensorFlow: 2.13.0
# versión de Pandas 2.0.1
# versión de Numpy 1.23.5
# versión de Keras 2.13.1
# Versión de Scikit-Learn 1.2.2
# GPU está No Disponible

# %% [markdown]
# ## Cargamos las librerias necesarias

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import keras
from keras.utils import to_categorical
from keras.models import Sequential
from tensorflow.keras.layers import Input
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Convolution2D, MaxPooling2D
from tensorflow.keras.activations import relu
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping

# %% [markdown]
# ## Cargamos las imagenes

# %%
import os
import cv2
import numpy as np
from PIL import Image

altura, longitud = 100, 100

def cargar_y_redimensionar_imagenes(ruta):
    imagenes_redimensionadas = []
    for archivo in os.listdir(ruta):
        archivo_ruta = os.path.join(ruta, archivo)
        # Verificamos si el archivo es una imagen válida antes de abrirlo con OpenCV
        imagen = cv2.imread(archivo_ruta)
        if imagen is not None and len(imagen.shape) == 3 and imagen.shape[2] == 3:
            imagen = cv2.resize(imagen, (altura, longitud))
            imagenes_redimensionadas.append(imagen)
    return imagenes_redimensionadas

# Rutas de los directorios de imágenes
ruta_mercantes = './datos/mercantes'
ruta_otros = './datos/otros'

# Cargar y redimensionar imágenes de mercantes y otros
imagenes_mercantes = cargar_y_redimensionar_imagenes(ruta_mercantes)
imagenes_otros = cargar_y_redimensionar_imagenes(ruta_otros)

# Obtener la cantidad de imágenes en cada directorio
dircount = [len(imagenes_mercantes), len(imagenes_otros)]

print('Imagenes en cada directorio:', dircount)
print('Suma Total de imagenes en subdirectorios:', sum(dircount))
# Out:
# Imagenes en cada directorio: [56, 35]
# Suma Total de imagenes en subdirectorios: 91

# %% [markdown]
# ## Crear etiquetas y clases
#
# **Creamos los labels con valor 1 para mercante y 0 para otros**

# %%
# Crear una lista de etiquetas (0 para mercantes, 1 para otros)
etiquetas_mercantes = [0] * len(imagenes_mercantes)
etiquetas_otros = [1] * len(imagenes_otros)

# Combinar las imágenes y etiquetas en un solo conjunto de datos
imagenes = imagenes_mercantes + imagenes_otros
etiquetas = etiquetas_mercantes + etiquetas_otros

# %% [markdown]
# ## Muestra de Imágenes:

# %%
# Muestra de Etiqueta Mercante:
import matplotlib.pyplot as plt
plt.imshow(plt.imread('datos/mercantes/10.jpg'))
plt.title("Imagen con etiqueta Mercante")
# Out:
# Text(0.5, 1.0, 'Imagen con etiqueta Mercante')

# %%
# Muestra de Etiqueta Otros:
import matplotlib.pyplot as plt
plt.imshow(plt.imread('datos/otros/11.jpg'))
plt.title("Imagen con etiqueta Otros")
# Out:
# Text(0.5, 1.0, 'Imagen con etiqueta Otros')

# %% [markdown]
# ## Creamos sets de Entrenamiento y Test

# %%
# Convertir a arreglos NumPy
X = np.array(imagenes, dtype=np.uint8)
y = np.array(etiquetas)

# Dividir los datos en conjuntos de entrenamiento y validación (80% para entrenamiento, 20% para validación)
train_X, valid_X, train_label, valid_label = train_test_split(X, y, test_size=0.1, random_state=218) #num de cadete

train_X = train_X / 255.
valid_X = valid_X / 255.

# Find the unique numbers from the train labels
classes = np.unique(train_label)
nClasses = len(classes)
print('Total number of outputs:', nClasses)
print('Output classes:', classes)

train_label_one_hot = to_categorical(train_label, num_classes=nClasses)
valid_label_one_hot = to_categorical(valid_label, num_classes=nClasses)
# Out:
# Total number of outputs: 2
# Output classes: [0 1]

# %% [markdown]
# ## Data augmentation

# %%
# Configurar las transformaciones de data augmentation
data_augmentation = ImageDataGenerator(
    rotation_range=20,         # Rango de rotación aleatoria (en grados)
    width_shift_range=0.2,     # Rango de traslación horizontal aleatoria (como fracción del ancho total)
    height_shift_range=0.2,    # Rango de traslación vertical aleatoria (como fracción del alto total)
    shear_range=0.2,           # Rango de cizallamiento (shear) aleatorio
    zoom_range=0.2,            # Rango de zoom aleatorio
    horizontal_flip=True,      # Volteo horizontal aleatorio
    fill_mode='nearest'        # Modo de rellenado para las transformaciones
)

# %% [markdown]
# ## Creamos la red neuronal de 3 capas

# %% [markdown]
# ### Dropout (0.3)

# %%
INIT_LR = 0.001#1e-3 

filtrosConv1=32 #despoues de la 1ra conv, la imagen va a tener prof de 32
filtrosConv2=64 #despjes de la 2da, tendra 64
filtrosConv3=128
tamano_filtro1=(5,5)
tamano_filtro2=(3,3)
tamano_pool=(2,2)

modelo1 = Sequential(name='dropout_0.3')
modelo1.add(Convolution2D(filtrosConv1, tamano_filtro1, padding='same', input_shape=(altura,longitud,3),activation='relu'))
modelo1.add(MaxPooling2D(pool_size=tamano_pool))

#segunda capa de convolucion (), seguida de una capa de max pooling
modelo1.add(Convolution2D(filtrosConv2, tamano_filtro2, padding='same', activation='relu'))
modelo1.add(MaxPooling2D(pool_size=tamano_pool))

#tercera capa de convolucion
modelo1.add(Convolution2D(filtrosConv3, tamano_filtro2, padding='same', activation='relu'))

#capa que aplana la imagen (1D)
modelo1.add(Flatten())

#capa normal, de 256 neuronas
modelo1.add(Dense(256,activation='relu'))

#capa que apagara el 30% de las neuronas en cada paso, para evitar el overfitting
modelo1.add(Dropout(0.3))

#ultima capa, que son 2 neuronas (una por clase) donde dara % prob da cada clase
modelo1.add(Dense(nClasses,activation='softmax'))

#con Graphviz se puede hacer un diagrama de flujo para ver la logica del sistema
modelo1.summary()

modelo1.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adam(learning_rate=INIT_LR),metrics=['accuracy'])
# Out:
# Model: "dropout_0.3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 100, 100, 32)      2432
#
#  max_pooling2d_12 (MaxPooli  (None, 50, 50, 32)        0
#  ng2D)
#
#  conv2d_19 (Conv2D)          (None, 50, 50, 64)        18496
#
#  max_pooling2d_13 (MaxPooli  (None, 25, 25, 64)        0
#  ng2D)
#
#  conv2d_20 (Conv2D)          (None, 25, 25, 128)       73856
#
#  flatten_6 (Flatten)         (None, 80000)             0
#
#  dense_12 (Dense)            (None, 256)               20480256
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 2)                 514
#
# =================================================================
# Total params: 20575554 (78.49 MB)
# Trainable params: 20575554 (78.49 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Dropout (0.5)

# %%
INIT_LR = 0.0001#1e-3 

filtrosConv1=32 #despoues de la 1ra conv, la imagen va a tener prof de 32
filtrosConv2=64 #despjes de la 2da, tendra 64
filtrosConv3=128
tamano_filtro1=(5,5)
tamano_filtro2=(3,3)
tamano_pool=(2,2)

modelo2 = Sequential(name='dropout_0.5')
modelo2.add(Convolution2D(filtrosConv1, tamano_filtro1, padding='same', input_shape=(altura,longitud,3),activation='relu'))
modelo2.add(MaxPooling2D(pool_size=tamano_pool))

#segunda capa de convolucion (), seguida de una capa de max pooling
modelo2.add(Convolution2D(filtrosConv2, tamano_filtro2, padding='same', activation='relu'))
modelo2.add(MaxPooling2D(pool_size=tamano_pool))

#tercera capa de convolucion
modelo2.add(Convolution2D(filtrosConv3, tamano_filtro2, padding='same', activation='relu'))

#capa que aplana la imagen (1D)
modelo2.add(Flatten())

#capa normal, de 256 neuronas
modelo2.add(Dense(256,activation='relu'))

#capa que apagara el 50% de las neuronas en cada paso, para evitar el overfitting
modelo2.add(Dropout(0.5))

#ultima capa, que son 2 neuronas (una por clase) donde dara % prob da cada clase
modelo2.add(Dense(nClasses,activation='softmax'))

#con Graphviz se puede hacer un diagrama de flujo para ver la logica del sistema
modelo2.summary()

modelo2.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adam(learning_rate=INIT_LR),metrics=['accuracy'])
# Out:
# Model: "dropout_0.5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 100, 100, 32)      2432
#
#  max_pooling2d_2 (MaxPoolin  (None, 50, 50, 32)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 50, 50, 64)        18496
#
#  max_pooling2d_3 (MaxPoolin  (None, 25, 25, 64)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 25, 25, 128)       73856
#
#  flatten_1 (Flatten)         (None, 80000)             0
#
#  dense_2 (Dense)             (None, 256)               20480256
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 20575554 (78.49 MB)
# Trainable params: 20575554 (78.49 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Dropout (0.8)

# %%
INIT_LR = 0.0001#1e-3 

filtrosConv1=32 #despoues de la 1ra conv, la imagen va a tener prof de 32
filtrosConv2=64 #despjes de la 2da, tendra 64
filtrosConv3=128
tamano_filtro1=(5,5)
tamano_filtro2=(3,3)
tamano_pool=(2,2)

modelo3 = Sequential(name='dropout_0.7')
modelo3.add(Convolution2D(filtrosConv1, tamano_filtro1, padding='same', input_shape=(altura,longitud,3),activation='relu'))
modelo3.add(MaxPooling2D(pool_size=tamano_pool))

#segunda capa de convolucion (), seguida de una capa de max pooling
modelo3.add(Convolution2D(filtrosConv2, tamano_filtro2, padding='same', activation='relu'))
modelo3.add(MaxPooling2D(pool_size=tamano_pool))

#tercera capa de convolucion
modelo3.add(Convolution2D(filtrosConv3, tamano_filtro2, padding='same', activation='relu'))

#capa que aplana la imagen (1D)
modelo3.add(Flatten())

#capa normal, de 256 neuronas
modelo3.add(Dense(256,activation='relu'))

#capa que apagara el 80% de las neuronas en cada paso, para evitar el overfitting
modelo3.add(Dropout(0.8))

#ultima capa, que son 2 neuronas (una por clase) donde dara % prob da cada clase
modelo3.add(Dense(nClasses,activation='softmax'))

#con Graphviz se puede hacer un diagrama de flujo para ver la logica del sistema
modelo3.summary()

modelo3.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adam(learning_rate=INIT_LR),metrics=['accuracy'])
# Out:
# Model: "dropout_0.7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 100, 100, 32)      2432
#
#  max_pooling2d_6 (MaxPoolin  (None, 50, 50, 32)        0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 50, 50, 64)        18496
#
#  max_pooling2d_7 (MaxPoolin  (None, 25, 25, 64)        0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 25, 25, 128)       73856
#
#  flatten_3 (Flatten)         (None, 80000)             0
#
#  dense_6 (Dense)             (None, 256)               20480256
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 20575554 (78.49 MB)
# Trainable params: 20575554 (78.49 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Entrenamos la red

# %% [markdown]
# ### Dropout 0.3

# %%
epochs = 200
batch_size = 32

# Crea un callback para el entrenamiento
callback = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Crear el generador de datos para el conjunto de entrenamiento con data augmentation
train_data_generator = data_augmentation.flow(train_X, train_label_one_hot, batch_size=batch_size)

## Modifica el train_x para incluir las imagenes del train_data_generator
history1=modelo1.fit(train_data_generator, steps_per_epoch=len(train_X) // batch_size, epochs=epochs, verbose=1, validation_data=(valid_X, valid_label_one_hot), callbacks=[callback])
# Out:
# Epoch 1/200
# 2/2 [==============================] - 2s 710ms/step - loss: 0.6561 - accuracy: 0.5918 - val_loss: 0.6086 - val_accuracy: 0.6000
# Epoch 2/200
# 2/2 [==============================] - 1s 503ms/step - loss: 0.6017 - accuracy: 0.6531 - val_loss: 0.6448 - val_accuracy: 0.6000
# Epoch 3/200
# 2/2 [==============================] - 1s 750ms/step - loss: 0.6625 - accuracy: 0.5781 - val_loss: 0.5857 - val_accuracy: 0.6000
# Epoch 4/200
# 2/2 [==============================] - 1s 717ms/step - loss: 0.6514 - accuracy: 0.6406 - val_loss: 0.6116 - val_accuracy: 0.7000
# Epoch 5/200
# 2/2 [==============================] - 1s 678ms/step - loss: 0.6589 - accuracy: 0.6122 - val_loss: 0.6078 - val_accuracy: 0.8000
# Epoch 6/200
# 2/2 [==============================] - 1s 671ms/step - loss: 0.6505 - accuracy: 0.7188 - val_loss: 0.6432 - val_accuracy: 0.6000
# Epoch 7/200
# 2/2 [==============================] - 1s 663ms/step - loss: 0.6768 - accuracy: 0.5918 - val_loss: 0.6013 - val_accuracy: 0.6000
# Epoch 8/200
# 2/2 [==============================] - 1s 678ms/step - loss: 0.6221 - accuracy: 0.6562 - val_loss: 0.5918 - val_accuracy: 0.6000
# Epoch 9/200
# 2/2 [==============================] - 1s 750ms/step - loss: 0.6033 - accuracy: 0.6406 - val_loss: 0.5561 - val_accuracy: 0.7000
# Epoch 10/200
# 2/2 [==============================] - 1s 548ms/step - loss: 0.6025 - accuracy: 0.7347 - val_loss: 0.6738 - val_accuracy: 0.6000
# Epoch 11/200
# 2/2 [==============================] - 1s 744ms/step - loss: 0.6063 - accuracy: 0.6327 - val_loss: 0.5184 - val_accuracy: 0.7000
# Epoch 12/200
# 2/2 [==============================] - 2s 785ms/step - loss: 0.5952 - accuracy: 0.6094 - val_loss: 0.5041 - val_accuracy: 0.7000
# Epoch 13/200
# 2/2 [==============================] - 1s 646ms/step - loss: 0.5767 - accuracy: 0.6719 - val_loss: 0.6762 - val_accuracy: 0.6000
# Epoch 14/200
# 2/2 [==============================] - 2s 725ms/step - loss: 0.5554 - accuracy: 0.6735 - val_loss: 0.4709 - val_accuracy: 0.8000
# Epoch 15/200
# 2/2 [==============================] - 1s 761ms/step - loss: 0.5538 - accuracy: 0.7143 - val_loss: 0.5086 - val_accuracy: 0.6000
# Epoch 16/200
# 2/2 [==============================] - 1s 798ms/step - loss: 0.5319 - accuracy: 0.6939 - val_loss: 0.5182 - val_accuracy: 0.6000
# Epoch 17/200
# 2/2 [==============================] - 1s 509ms/step - loss: 0.4151 - accuracy: 0.8571 - val_loss: 0.6662 - val_accuracy: 0.6000
# Epoch 18/200
# 2/2 [==============================] - 1s 600ms/step - loss: 0.3846 - accuracy: 0.7959 - val_loss: 0.3791 - val_accuracy: 0.8000
# Epoch 19/200
# 2/2 [==============================] - 1s 508ms/step - loss: 0.5446 - accuracy: 0.6939 - val_loss: 0.7182 - val_accuracy: 0.6000
# Epoch 20/200
# 2/2 [==============================] - 1s 650ms/step - loss: 0.4606 - accuracy: 0.7344 - val_loss: 0.7064 - val_accuracy: 0.6000
# Epoch 21/200
# 2/2 [==============================] - 1s 494ms/step - loss: 0.4953 - accuracy: 0.6939 - val_loss: 0.4226 - val_accuracy: 0.8000
# Epoch 22/200
# 2/2 [==============================] - 1s 691ms/step - loss: 0.4895 - accuracy: 0.7959 - val_loss: 0.4307 - val_accuracy: 0.8000
# Epoch 23/200
# 2/2 [==============================] - 1s 529ms/step - loss: 0.3922 - accuracy: 0.8571 - val_loss: 0.4443 - val_accuracy: 0.8000
# Epoch 24/200
# 2/2 [==============================] - 1s 741ms/step - loss: 0.4309 - accuracy: 0.7959 - val_loss: 0.3677 - val_accuracy: 0.8000
# Epoch 25/200
# 2/2 [==============================] - 1s 648ms/step - loss: 0.4519 - accuracy: 0.7812 - val_loss: 0.8931 - val_accuracy: 0.7000
# Epoch 26/200
# 2/2 [==============================] - 1s 506ms/step - loss: 0.5041 - accuracy: 0.7755 - val_loss: 0.5571 - val_accuracy: 0.6000
# Epoch 27/200
# 2/2 [==============================] - 1s 667ms/step - loss: 0.4427 - accuracy: 0.8163 - val_loss: 0.4830 - val_accuracy: 0.8000
# Epoch 28/200
# 2/2 [==============================] - 1s 693ms/step - loss: 0.3863 - accuracy: 0.7959 - val_loss: 0.3952 - val_accuracy: 0.8000
# Epoch 29/200
# 2/2 [==============================] - 1s 680ms/step - loss: 0.3297 - accuracy: 0.9388 - val_loss: 0.4649 - val_accuracy: 0.9000
# Epoch 30/200
# 2/2 [==============================] - 1s 668ms/step - loss: 0.2876 - accuracy: 0.8906 - val_loss: 0.4842 - val_accuracy: 0.9000
# Epoch 31/200
# 2/2 [==============================] - 1s 664ms/step - loss: 0.3979 - accuracy: 0.7959 - val_loss: 0.3852 - val_accuracy: 0.9000
# Epoch 32/200
# 2/2 [==============================] - 1s 504ms/step - loss: 0.4638 - accuracy: 0.7755 - val_loss: 0.3910 - val_accuracy: 0.9000
# Epoch 33/200
# 2/2 [==============================] - 2s 738ms/step - loss: 0.3951 - accuracy: 0.8125 - val_loss: 0.3168 - val_accuracy: 0.8000
# Epoch 34/200
# 2/2 [==============================] - 1s 497ms/step - loss: 0.3629 - accuracy: 0.8163 - val_loss: 0.3967 - val_accuracy: 0.9000
# Epoch 35/200
# 2/2 [==============================] - 1s 672ms/step - loss: 0.4978 - accuracy: 0.7551 - val_loss: 0.5727 - val_accuracy: 0.7000
# Epoch 36/200
# 2/2 [==============================] - 1s 647ms/step - loss: 0.3439 - accuracy: 0.8367 - val_loss: 0.4178 - val_accuracy: 0.8000
# Epoch 37/200
# 2/2 [==============================] - 1s 692ms/step - loss: 0.3678 - accuracy: 0.8750 - val_loss: 0.4046 - val_accuracy: 0.9000
# Epoch 38/200
# 2/2 [==============================] - 1s 668ms/step - loss: 0.2969 - accuracy: 0.8906 - val_loss: 0.4628 - val_accuracy: 0.8000
# Epoch 39/200
# 2/2 [==============================] - 1s 567ms/step - loss: 0.2585 - accuracy: 0.8980 - val_loss: 0.9256 - val_accuracy: 0.8000
# Epoch 40/200
# 2/2 [==============================] - 1s 675ms/step - loss: 0.3303 - accuracy: 0.8438 - val_loss: 0.3935 - val_accuracy: 0.8000
# Epoch 41/200
# 2/2 [==============================] - 1s 684ms/step - loss: 0.3962 - accuracy: 0.8367 - val_loss: 0.6600 - val_accuracy: 0.8000
# Epoch 42/200
# 2/2 [==============================] - 1s 695ms/step - loss: 0.2500 - accuracy: 0.8980 - val_loss: 0.8950 - val_accuracy: 0.7000
# Epoch 43/200
# 2/2 [==============================] - 1s 728ms/step - loss: 0.3637 - accuracy: 0.8571 - val_loss: 0.4138 - val_accuracy: 0.8000

# %% [markdown]
# ### Dropout 0.5

# %%
# Crear el generador de datos para el conjunto de entrenamiento con data augmentation
train_data_generator = data_augmentation.flow(train_X, train_label_one_hot, batch_size=batch_size)

## Modifica el train_x para incluir las imagenes del train_data_generator
history2=modelo2.fit(train_data_generator, steps_per_epoch=len(train_X) // batch_size, epochs=epochs, verbose=1, validation_data=(valid_X, valid_label_one_hot))
# Out:
# Epoch 1/200
# 2/2 [==============================] - 4s 1s/step - loss: 0.6681 - accuracy: 0.5781 - val_loss: 0.6504 - val_accuracy: 0.6316
# Epoch 2/200
# 2/2 [==============================] - 2s 1s/step - loss: 0.7944 - accuracy: 0.6000 - val_loss: 0.6832 - val_accuracy: 0.6316
# Epoch 3/200
# 2/2 [==============================] - 3s 1s/step - loss: 0.6964 - accuracy: 0.6406 - val_loss: 0.6462 - val_accuracy: 0.6316
# Epoch 4/200
# 2/2 [==============================] - 2s 1s/step - loss: 0.6788 - accuracy: 0.6000 - val_loss: 0.6748 - val_accuracy: 0.6316
# Epoch 5/200
# 2/2 [==============================] - 2s 613ms/step - loss: 0.6859 - accuracy: 0.5250 - val_loss: 0.6788 - val_accuracy: 0.6316
# Epoch 6/200
# 2/2 [==============================] - 1s 957ms/step - loss: 0.6999 - accuracy: 0.4750 - val_loss: 0.6747 - val_accuracy: 0.6316
# Epoch 7/200
# 2/2 [==============================] - 1s 878ms/step - loss: 0.6983 - accuracy: 0.6000 - val_loss: 0.6475 - val_accuracy: 0.6316
# Epoch 8/200
# 2/2 [==============================] - 2s 588ms/step - loss: 0.6607 - accuracy: 0.5750 - val_loss: 0.6373 - val_accuracy: 0.6316
# Epoch 9/200
# 2/2 [==============================] - 2s 1s/step - loss: 0.6812 - accuracy: 0.6250 - val_loss: 0.6407 - val_accuracy: 0.6316
# Epoch 10/200
# 2/2 [==============================] - 2s 624ms/step - loss: 0.6298 - accuracy: 0.7250 - val_loss: 0.6491 - val_accuracy: 0.6316
# Epoch 11/200
# 2/2 [==============================] - 2s 1s/step - loss: 0.7115 - accuracy: 0.6250 - val_loss: 0.6499 - val_accuracy: 0.6316
# Epoch 12/200
# 2/2 [==============================] - 2s 1s/step - loss: 0.7314 - accuracy: 0.6000 - val_loss: 0.6513 - val_accuracy: 0.6316
# Epoch 13/200
# 2/2 [==============================] - 2s 964ms/step - loss: 0.6612 - accuracy: 0.6406 - val_loss: 0.6387 - val_accuracy: 0.6316
# Epoch 14/200
# 2/2 [==============================] - 2s 829ms/step - loss: 0.6855 - accuracy: 0.6094 - val_loss: 0.6275 - val_accuracy: 0.6316
# Epoch 15/200
# 2/2 [==============================] - 1s 813ms/step - loss: 0.6629 - accuracy: 0.5500 - val_loss: 0.6257 - val_accuracy: 0.6316
# Epoch 16/200
# 2/2 [==============================] - 1s 570ms/step - loss: 0.6734 - accuracy: 0.6750 - val_loss: 0.6277 - val_accuracy: 0.6316
# Epoch 17/200
# 2/2 [==============================] - 2s 1s/step - loss: 0.6436 - accuracy: 0.6750 - val_loss: 0.6287 - val_accuracy: 0.6316
# Epoch 18/200
# 2/2 [==============================] - 1s 843ms/step - loss: 0.6140 - accuracy: 0.7250 - val_loss: 0.6230 - val_accuracy: 0.6316
# Epoch 19/200
# 2/2 [==============================] - 2s 578ms/step - loss: 0.6435 - accuracy: 0.6250 - val_loss: 0.6162 - val_accuracy: 0.6316
# Epoch 20/200
# 2/2 [==============================] - 1s 537ms/step - loss: 0.6392 - accuracy: 0.6250 - val_loss: 0.6116 - val_accuracy: 0.6316
# Epoch 21/200
# 2/2 [==============================] - 1s 829ms/step - loss: 0.6482 - accuracy: 0.6250 - val_loss: 0.6093 - val_accuracy: 0.6316
# Epoch 22/200
# 2/2 [==============================] - 1s 520ms/step - loss: 0.6222 - accuracy: 0.6750 - val_loss: 0.6098 - val_accuracy: 0.6316
# Epoch 23/200
# 2/2 [==============================] - 2s 866ms/step - loss: 0.6625 - accuracy: 0.5625 - val_loss: 0.6059 - val_accuracy: 0.6316
# Epoch 24/200
# 2/2 [==============================] - 1s 514ms/step - loss: 0.6659 - accuracy: 0.6250 - val_loss: 0.6017 - val_accuracy: 0.6316
# Epoch 25/200
# 2/2 [==============================] - 1s 516ms/step - loss: 0.5688 - accuracy: 0.7250 - val_loss: 0.6076 - val_accuracy: 0.6316
# Epoch 26/200
# 2/2 [==============================] - 1s 856ms/step - loss: 0.5817 - accuracy: 0.7250 - val_loss: 0.6206 - val_accuracy: 0.6316
# Epoch 27/200
# 2/2 [==============================] - 2s 825ms/step - loss: 0.6528 - accuracy: 0.5938 - val_loss: 0.6182 - val_accuracy: 0.6316
# Epoch 28/200
# 2/2 [==============================] - 1s 522ms/step - loss: 0.6432 - accuracy: 0.6250 - val_loss: 0.6002 - val_accuracy: 0.6316
# Epoch 29/200
# 2/2 [==============================] - 1s 516ms/step - loss: 0.5832 - accuracy: 0.7000 - val_loss: 0.5875 - val_accuracy: 0.6316
# Epoch 30/200
# 2/2 [==============================] - 1s 496ms/step - loss: 0.6187 - accuracy: 0.6250 - val_loss: 0.5853 - val_accuracy: 0.6842
# Epoch 31/200
# 2/2 [==============================] - 1s 804ms/step - loss: 0.6107 - accuracy: 0.7000 - val_loss: 0.5806 - val_accuracy: 0.6842
# Epoch 32/200
# 2/2 [==============================] - 2s 839ms/step - loss: 0.6204 - accuracy: 0.6406 - val_loss: 0.5760 - val_accuracy: 0.6842
# Epoch 33/200
# 2/2 [==============================] - 2s 839ms/step - loss: 0.5947 - accuracy: 0.6875 - val_loss: 0.5740 - val_accuracy: 0.6316
# Epoch 34/200
# 2/2 [==============================] - 2s 846ms/step - loss: 0.5831 - accuracy: 0.7031 - val_loss: 0.5707 - val_accuracy: 0.6316
# Epoch 35/200
# 2/2 [==============================] - 1s 507ms/step - loss: 0.5479 - accuracy: 0.7500 - val_loss: 0.5900 - val_accuracy: 0.6316
# Epoch 36/200
# 2/2 [==============================] - 2s 813ms/step - loss: 0.5444 - accuracy: 0.6719 - val_loss: 0.5854 - val_accuracy: 0.6316
# Epoch 37/200
# 2/2 [==============================] - 2s 800ms/step - loss: 0.5411 - accuracy: 0.7031 - val_loss: 0.5553 - val_accuracy: 0.6316
# Epoch 38/200
# 2/2 [==============================] - 1s 828ms/step - loss: 0.4984 - accuracy: 0.8000 - val_loss: 0.5316 - val_accuracy: 0.6842
# Epoch 39/200
# 2/2 [==============================] - 1s 540ms/step - loss: 0.5513 - accuracy: 0.7250 - val_loss: 0.5252 - val_accuracy: 0.6842
# Epoch 40/200
# 2/2 [==============================] - 2s 831ms/step - loss: 0.5519 - accuracy: 0.6875 - val_loss: 0.5243 - val_accuracy: 0.6842
# Epoch 41/200
# 2/2 [==============================] - 1s 571ms/step - loss: 0.5507 - accuracy: 0.7000 - val_loss: 0.5229 - val_accuracy: 0.6316
# Epoch 42/200
# 2/2 [==============================] - 1s 815ms/step - loss: 0.4737 - accuracy: 0.8500 - val_loss: 0.5786 - val_accuracy: 0.6316
# Epoch 43/200
# 2/2 [==============================] - 1s 513ms/step - loss: 0.4710 - accuracy: 0.7750 - val_loss: 0.7212 - val_accuracy: 0.6316
# Epoch 44/200
# 2/2 [==============================] - 2s 802ms/step - loss: 0.6062 - accuracy: 0.6406 - val_loss: 0.5443 - val_accuracy: 0.6316
# Epoch 45/200
# 2/2 [==============================] - 2s 856ms/step - loss: 0.5286 - accuracy: 0.6875 - val_loss: 0.4701 - val_accuracy: 0.8947
# Epoch 46/200
# 2/2 [==============================] - 2s 809ms/step - loss: 0.5763 - accuracy: 0.7344 - val_loss: 0.4686 - val_accuracy: 0.7368
# Epoch 47/200
# 2/2 [==============================] - 1s 873ms/step - loss: 0.5192 - accuracy: 0.7500 - val_loss: 0.5620 - val_accuracy: 0.6316
# Epoch 48/200
# 2/2 [==============================] - 1s 809ms/step - loss: 0.5548 - accuracy: 0.6500 - val_loss: 0.6326 - val_accuracy: 0.6316
# Epoch 49/200
# 2/2 [==============================] - 2s 798ms/step - loss: 0.5067 - accuracy: 0.6875 - val_loss: 0.5294 - val_accuracy: 0.6316
# Epoch 50/200
# 2/2 [==============================] - 2s 828ms/step - loss: 0.4428 - accuracy: 0.7656 - val_loss: 0.4651 - val_accuracy: 0.7368
# Epoch 51/200
# 2/2 [==============================] - 2s 842ms/step - loss: 0.4916 - accuracy: 0.7656 - val_loss: 0.4523 - val_accuracy: 0.7368
# Epoch 52/200
# 2/2 [==============================] - 2s 822ms/step - loss: 0.5083 - accuracy: 0.7500 - val_loss: 0.4843 - val_accuracy: 0.7368
# Epoch 53/200
# 2/2 [==============================] - 1s 538ms/step - loss: 0.4058 - accuracy: 0.8750 - val_loss: 0.5530 - val_accuracy: 0.6316
# Epoch 54/200
# 2/2 [==============================] - 2s 822ms/step - loss: 0.4752 - accuracy: 0.7344 - val_loss: 0.5742 - val_accuracy: 0.6316
# Epoch 55/200
# 2/2 [==============================] - 1s 501ms/step - loss: 0.4715 - accuracy: 0.6750 - val_loss: 0.4964 - val_accuracy: 0.6842
# Epoch 56/200
# 2/2 [==============================] - 1s 619ms/step - loss: 0.4513 - accuracy: 0.8250 - val_loss: 0.4348 - val_accuracy: 0.7368
# Epoch 57/200
# 2/2 [==============================] - 2s 877ms/step - loss: 0.4254 - accuracy: 0.8906 - val_loss: 0.4609 - val_accuracy: 0.6842
# Epoch 58/200
# 2/2 [==============================] - 1s 821ms/step - loss: 0.3669 - accuracy: 0.9750 - val_loss: 0.5294 - val_accuracy: 0.6842
# Epoch 59/200
# 2/2 [==============================] - 1s 874ms/step - loss: 0.4177 - accuracy: 0.8000 - val_loss: 0.6045 - val_accuracy: 0.6316
# Epoch 60/200
# 2/2 [==============================] - 1s 879ms/step - loss: 0.3862 - accuracy: 0.7750 - val_loss: 0.6927 - val_accuracy: 0.6316
# Epoch 61/200
# 2/2 [==============================] - 1s 873ms/step - loss: 0.3857 - accuracy: 0.8000 - val_loss: 0.5244 - val_accuracy: 0.6316
# Epoch 62/200
# 2/2 [==============================] - 2s 830ms/step - loss: 0.3757 - accuracy: 0.8594 - val_loss: 0.3913 - val_accuracy: 0.8421
# Epoch 63/200
# 2/2 [==============================] - 1s 833ms/step - loss: 0.4087 - accuracy: 0.8750 - val_loss: 0.4872 - val_accuracy: 0.6842
# Epoch 64/200
# 2/2 [==============================] - 1s 526ms/step - loss: 0.3459 - accuracy: 0.8500 - val_loss: 0.7314 - val_accuracy: 0.6316
# Epoch 65/200
# 2/2 [==============================] - 1s 833ms/step - loss: 0.3126 - accuracy: 0.8500 - val_loss: 0.4343 - val_accuracy: 0.7895
# Epoch 66/200
# 2/2 [==============================] - 1s 876ms/step - loss: 0.3389 - accuracy: 0.8500 - val_loss: 0.5028 - val_accuracy: 0.7368
# Epoch 67/200
# 2/2 [==============================] - 1s 534ms/step - loss: 0.3528 - accuracy: 0.8250 - val_loss: 0.5735 - val_accuracy: 0.6316
# Epoch 68/200
# 2/2 [==============================] - 1s 857ms/step - loss: 0.2992 - accuracy: 0.8500 - val_loss: 0.5225 - val_accuracy: 0.7368
# Epoch 69/200
# 2/2 [==============================] - 1s 818ms/step - loss: 0.2685 - accuracy: 0.9500 - val_loss: 0.5241 - val_accuracy: 0.6842
# Epoch 70/200
# 2/2 [==============================] - 1s 697ms/step - loss: 0.3373 - accuracy: 0.8281 - val_loss: 0.4972 - val_accuracy: 0.6842
# Epoch 71/200
# 2/2 [==============================] - 1s 573ms/step - loss: 0.3621 - accuracy: 0.8500 - val_loss: 0.6566 - val_accuracy: 0.6842
# Epoch 72/200
# 2/2 [==============================] - 1s 552ms/step - loss: 0.3020 - accuracy: 0.8500 - val_loss: 0.8210 - val_accuracy: 0.6316
# Epoch 73/200
# 2/2 [==============================] - 1s 545ms/step - loss: 0.3155 - accuracy: 0.7500 - val_loss: 0.4529 - val_accuracy: 0.7895
# Epoch 74/200
# 2/2 [==============================] - 1s 845ms/step - loss: 0.4284 - accuracy: 0.8250 - val_loss: 0.4416 - val_accuracy: 0.8421
# Epoch 75/200
# 2/2 [==============================] - 2s 846ms/step - loss: 0.2618 - accuracy: 0.9375 - val_loss: 0.6000 - val_accuracy: 0.6842
# Epoch 76/200
# 2/2 [==============================] - 1s 509ms/step - loss: 0.2786 - accuracy: 0.8750 - val_loss: 1.0295 - val_accuracy: 0.6316
# Epoch 77/200
# 2/2 [==============================] - 1s 821ms/step - loss: 0.3007 - accuracy: 0.8250 - val_loss: 0.6526 - val_accuracy: 0.6316
# Epoch 78/200
# 2/2 [==============================] - 1s 864ms/step - loss: 0.2810 - accuracy: 0.8250 - val_loss: 0.5899 - val_accuracy: 0.7368
# Epoch 79/200
# 2/2 [==============================] - 2s 866ms/step - loss: 0.3213 - accuracy: 0.8594 - val_loss: 0.4938 - val_accuracy: 0.7368
# Epoch 80/200
# 2/2 [==============================] - 2s 824ms/step - loss: 0.3506 - accuracy: 0.8438 - val_loss: 0.4220 - val_accuracy: 0.8421
# Epoch 81/200
# 2/2 [==============================] - 1s 520ms/step - loss: 0.2730 - accuracy: 0.9000 - val_loss: 0.4937 - val_accuracy: 0.8421
# Epoch 82/200
# 2/2 [==============================] - 1s 523ms/step - loss: 0.3184 - accuracy: 0.9000 - val_loss: 0.7459 - val_accuracy: 0.6316
# Epoch 83/200
# 2/2 [==============================] - 1s 496ms/step - loss: 0.4367 - accuracy: 0.8750 - val_loss: 0.4831 - val_accuracy: 0.8421
# Epoch 84/200
# 2/2 [==============================] - 1s 552ms/step - loss: 0.3378 - accuracy: 0.8500 - val_loss: 0.4132 - val_accuracy: 0.8421
# Epoch 85/200
# 2/2 [==============================] - 1s 551ms/step - loss: 0.2112 - accuracy: 1.0000 - val_loss: 0.4440 - val_accuracy: 0.8421
# Epoch 86/200
# 2/2 [==============================] - 2s 825ms/step - loss: 0.2721 - accuracy: 0.9062 - val_loss: 0.5409 - val_accuracy: 0.7368
# Epoch 87/200
# 2/2 [==============================] - 2s 819ms/step - loss: 0.2803 - accuracy: 0.8750 - val_loss: 0.5432 - val_accuracy: 0.7895
# Epoch 88/200
# 2/2 [==============================] - 1s 828ms/step - loss: 0.2510 - accuracy: 0.8750 - val_loss: 0.4187 - val_accuracy: 0.8421
# Epoch 89/200
# 2/2 [==============================] - 1s 517ms/step - loss: 0.2678 - accuracy: 0.9000 - val_loss: 0.6033 - val_accuracy: 0.7368
# Epoch 90/200
# 2/2 [==============================] - 1s 869ms/step - loss: 0.3294 - accuracy: 0.8250 - val_loss: 0.8589 - val_accuracy: 0.6316
# Epoch 91/200
# 2/2 [==============================] - 2s 605ms/step - loss: 0.2756 - accuracy: 0.8500 - val_loss: 0.9427 - val_accuracy: 0.6316
# Epoch 92/200
# 2/2 [==============================] - 1s 547ms/step - loss: 0.2986 - accuracy: 0.8750 - val_loss: 0.6608 - val_accuracy: 0.6316
# Epoch 93/200
# 2/2 [==============================] - 1s 822ms/step - loss: 0.3604 - accuracy: 0.8500 - val_loss: 0.3213 - val_accuracy: 0.7895
# Epoch 94/200
# 2/2 [==============================] - 1s 830ms/step - loss: 0.3813 - accuracy: 0.8500 - val_loss: 0.3991 - val_accuracy: 0.8421
# Epoch 95/200
# 2/2 [==============================] - 1s 807ms/step - loss: 0.2272 - accuracy: 0.9500 - val_loss: 0.8815 - val_accuracy: 0.6316
# Epoch 96/200
# 2/2 [==============================] - 2s 863ms/step - loss: 0.3223 - accuracy: 0.7812 - val_loss: 0.9935 - val_accuracy: 0.6316
# Epoch 97/200
# 2/2 [==============================] - 1s 550ms/step - loss: 0.3856 - accuracy: 0.7750 - val_loss: 0.4537 - val_accuracy: 0.8421
# Epoch 98/200
# 2/2 [==============================] - 2s 822ms/step - loss: 0.3845 - accuracy: 0.8594 - val_loss: 0.3124 - val_accuracy: 0.7895
# Epoch 99/200
# 2/2 [==============================] - 1s 810ms/step - loss: 0.3077 - accuracy: 0.8250 - val_loss: 0.3229 - val_accuracy: 0.7895
# Epoch 100/200
# 2/2 [==============================] - 1s 522ms/step - loss: 0.3902 - accuracy: 0.8000 - val_loss: 0.5264 - val_accuracy: 0.7895
# Epoch 101/200
# 2/2 [==============================] - 1s 529ms/step - loss: 0.3265 - accuracy: 0.8750 - val_loss: 0.7393 - val_accuracy: 0.6842
# Epoch 102/200
# 2/2 [==============================] - 2s 868ms/step - loss: 0.2894 - accuracy: 0.9062 - val_loss: 0.6283 - val_accuracy: 0.6842
# Epoch 103/200
# 2/2 [==============================] - 1s 824ms/step - loss: 0.2955 - accuracy: 0.8750 - val_loss: 0.4328 - val_accuracy: 0.8421
# Epoch 104/200
# 2/2 [==============================] - 1s 973ms/step - loss: 0.3012 - accuracy: 0.8750 - val_loss: 0.3588 - val_accuracy: 0.8421
# Epoch 105/200
# 2/2 [==============================] - 1s 622ms/step - loss: 0.3534 - accuracy: 0.8000 - val_loss: 0.3814 - val_accuracy: 0.8421
# Epoch 106/200
# 2/2 [==============================] - 1s 393ms/step - loss: 0.3174 - accuracy: 0.8250 - val_loss: 0.6781 - val_accuracy: 0.6842
# Epoch 107/200
# 2/2 [==============================] - 1s 437ms/step - loss: 0.3315 - accuracy: 0.8500 - val_loss: 0.7424 - val_accuracy: 0.6842
# Epoch 108/200
# 2/2 [==============================] - 1s 618ms/step - loss: 0.3020 - accuracy: 0.8438 - val_loss: 0.5286 - val_accuracy: 0.8421
# Epoch 109/200
# 2/2 [==============================] - 1s 612ms/step - loss: 0.3425 - accuracy: 0.8594 - val_loss: 0.4886 - val_accuracy: 0.8421
# Epoch 110/200
# 2/2 [==============================] - 1s 370ms/step - loss: 0.2472 - accuracy: 0.8750 - val_loss: 0.5121 - val_accuracy: 0.8421
# Epoch 111/200
# 2/2 [==============================] - 1s 384ms/step - loss: 0.1966 - accuracy: 0.9750 - val_loss: 0.5981 - val_accuracy: 0.8421
# Epoch 112/200
# 2/2 [==============================] - 1s 401ms/step - loss: 0.2905 - accuracy: 0.8500 - val_loss: 0.5042 - val_accuracy: 0.8421
# Epoch 113/200
# 2/2 [==============================] - 1s 710ms/step - loss: 0.3479 - accuracy: 0.8500 - val_loss: 0.5081 - val_accuracy: 0.8421
# Epoch 114/200
# 2/2 [==============================] - 2s 879ms/step - loss: 0.2612 - accuracy: 0.9219 - val_loss: 0.7087 - val_accuracy: 0.7368
# Epoch 115/200
# 2/2 [==============================] - 2s 894ms/step - loss: 0.3139 - accuracy: 0.8906 - val_loss: 0.6932 - val_accuracy: 0.7895
# Epoch 116/200
# 2/2 [==============================] - 1s 557ms/step - loss: 0.2220 - accuracy: 0.8750 - val_loss: 0.5948 - val_accuracy: 0.7895
# Epoch 117/200
# 2/2 [==============================] - 2s 865ms/step - loss: 0.2714 - accuracy: 0.8906 - val_loss: 0.5731 - val_accuracy: 0.7895
# Epoch 118/200
# 2/2 [==============================] - 1s 543ms/step - loss: 0.2152 - accuracy: 0.9250 - val_loss: 0.6306 - val_accuracy: 0.7895
# Epoch 119/200
# 2/2 [==============================] - 1s 593ms/step - loss: 0.2467 - accuracy: 0.9250 - val_loss: 1.0351 - val_accuracy: 0.6842
# Epoch 120/200
# 2/2 [==============================] - 2s 877ms/step - loss: 0.3013 - accuracy: 0.9062 - val_loss: 0.6950 - val_accuracy: 0.7895
# Epoch 121/200
# 2/2 [==============================] - 1s 524ms/step - loss: 0.2973 - accuracy: 0.8500 - val_loss: 0.7644 - val_accuracy: 0.7895
# Epoch 122/200
# 2/2 [==============================] - 1s 892ms/step - loss: 0.4210 - accuracy: 0.8000 - val_loss: 1.3090 - val_accuracy: 0.6316
# Epoch 123/200
# 2/2 [==============================] - 1s 835ms/step - loss: 0.5438 - accuracy: 0.7500 - val_loss: 0.9550 - val_accuracy: 0.6316
# Epoch 124/200
# 2/2 [==============================] - 2s 836ms/step - loss: 0.2323 - accuracy: 0.9062 - val_loss: 0.4212 - val_accuracy: 0.8421
# Epoch 125/200
# 2/2 [==============================] - 1s 525ms/step - loss: 0.2306 - accuracy: 0.9000 - val_loss: 0.3089 - val_accuracy: 0.8421
# Epoch 126/200
# 2/2 [==============================] - 1s 593ms/step - loss: 0.4242 - accuracy: 0.7750 - val_loss: 0.3388 - val_accuracy: 0.8421
# Epoch 127/200
# 2/2 [==============================] - 1s 543ms/step - loss: 0.3108 - accuracy: 0.8750 - val_loss: 0.5278 - val_accuracy: 0.8421
# Epoch 128/200
# 2/2 [==============================] - 1s 865ms/step - loss: 0.1845 - accuracy: 0.9750 - val_loss: 0.8355 - val_accuracy: 0.6842
# Epoch 129/200
# 2/2 [==============================] - 1s 874ms/step - loss: 0.5126 - accuracy: 0.6750 - val_loss: 0.5406 - val_accuracy: 0.7895
# Epoch 130/200
# 2/2 [==============================] - 2s 877ms/step - loss: 0.3224 - accuracy: 0.8281 - val_loss: 0.3625 - val_accuracy: 0.8421
# Epoch 131/200
# 2/2 [==============================] - 2s 832ms/step - loss: 0.3176 - accuracy: 0.8594 - val_loss: 0.3598 - val_accuracy: 0.8421
# Epoch 132/200
# 2/2 [==============================] - 1s 521ms/step - loss: 0.3287 - accuracy: 0.8750 - val_loss: 0.4623 - val_accuracy: 0.8421
# Epoch 133/200
# 2/2 [==============================] - 1s 528ms/step - loss: 0.3056 - accuracy: 0.8500 - val_loss: 0.6825 - val_accuracy: 0.7368
# Epoch 134/200
# 2/2 [==============================] - 2s 917ms/step - loss: 0.2918 - accuracy: 0.8594 - val_loss: 0.8120 - val_accuracy: 0.7368
# Epoch 135/200
# 2/2 [==============================] - 1s 554ms/step - loss: 0.2352 - accuracy: 0.8750 - val_loss: 0.7899 - val_accuracy: 0.7895
# Epoch 136/200
# 2/2 [==============================] - 2s 1s/step - loss: 0.2715 - accuracy: 0.8750 - val_loss: 0.7547 - val_accuracy: 0.7895
# Epoch 137/200
# 2/2 [==============================] - 2s 962ms/step - loss: 0.2688 - accuracy: 0.8906 - val_loss: 0.6757 - val_accuracy: 0.7895
# Epoch 138/200
# 2/2 [==============================] - 2s 1s/step - loss: 0.2326 - accuracy: 0.9062 - val_loss: 0.6507 - val_accuracy: 0.7895
# Epoch 139/200
# 2/2 [==============================] - 2s 957ms/step - loss: 0.3337 - accuracy: 0.7750 - val_loss: 0.6221 - val_accuracy: 0.7895
# Epoch 140/200
# 2/2 [==============================] - 2s 1s/step - loss: 0.2956 - accuracy: 0.8906 - val_loss: 0.6421 - val_accuracy: 0.7895
# Epoch 141/200
# 2/2 [==============================] - 2s 572ms/step - loss: 0.2803 - accuracy: 0.8750 - val_loss: 0.6988 - val_accuracy: 0.7895
# Epoch 142/200
# 2/2 [==============================] - 2s 664ms/step - loss: 0.3578 - accuracy: 0.8500 - val_loss: 0.8921 - val_accuracy: 0.7895
# Epoch 143/200
# 2/2 [==============================] - 2s 945ms/step - loss: 0.4100 - accuracy: 0.7250 - val_loss: 1.4741 - val_accuracy: 0.6316
# Epoch 144/200
# 2/2 [==============================] - 2s 1s/step - loss: 0.4735 - accuracy: 0.7969 - val_loss: 0.7567 - val_accuracy: 0.7895
# Epoch 145/200
# 2/2 [==============================] - 1s 868ms/step - loss: 0.3039 - accuracy: 0.8500 - val_loss: 0.4184 - val_accuracy: 0.8421
# Epoch 146/200
# 2/2 [==============================] - 2s 893ms/step - loss: 0.3035 - accuracy: 0.8594 - val_loss: 0.3427 - val_accuracy: 0.8421
# Epoch 147/200
# 2/2 [==============================] - 2s 1s/step - loss: 0.3867 - accuracy: 0.8281 - val_loss: 0.3872 - val_accuracy: 0.8421
# Epoch 148/200
# 2/2 [==============================] - 1s 846ms/step - loss: 0.2238 - accuracy: 0.9250 - val_loss: 0.4828 - val_accuracy: 0.8421
# Epoch 149/200
# 2/2 [==============================] - 1s 843ms/step - loss: 0.3073 - accuracy: 0.8500 - val_loss: 0.5166 - val_accuracy: 0.7895
# Epoch 150/200
# 2/2 [==============================] - 1s 527ms/step - loss: 0.3017 - accuracy: 0.8750 - val_loss: 0.5376 - val_accuracy: 0.7895
# Epoch 151/200
# 2/2 [==============================] - 1s 872ms/step - loss: 0.2944 - accuracy: 0.8750 - val_loss: 0.6617 - val_accuracy: 0.6842
# Epoch 152/200
# 2/2 [==============================] - 2s 867ms/step - loss: 0.3079 - accuracy: 0.8750 - val_loss: 0.6334 - val_accuracy: 0.7895
# Epoch 153/200
# 2/2 [==============================] - 1s 903ms/step - loss: 0.2092 - accuracy: 0.9250 - val_loss: 0.5492 - val_accuracy: 0.7895
# Epoch 154/200
# 2/2 [==============================] - 2s 987ms/step - loss: 0.2368 - accuracy: 0.8750 - val_loss: 0.4761 - val_accuracy: 0.8421
# Epoch 155/200
# 2/2 [==============================] - 1s 568ms/step - loss: 0.2788 - accuracy: 0.8500 - val_loss: 0.3861 - val_accuracy: 0.8421
# Epoch 156/200
# 2/2 [==============================] - 1s 886ms/step - loss: 0.3736 - accuracy: 0.8250 - val_loss: 0.3972 - val_accuracy: 0.8421
# Epoch 157/200
# 2/2 [==============================] - 2s 856ms/step - loss: 0.2249 - accuracy: 0.9375 - val_loss: 0.4754 - val_accuracy: 0.8421
# Epoch 158/200
# 2/2 [==============================] - 1s 549ms/step - loss: 0.3049 - accuracy: 0.8750 - val_loss: 0.5661 - val_accuracy: 0.8421
# Epoch 159/200
# 2/2 [==============================] - 1s 871ms/step - loss: 0.2598 - accuracy: 0.8750 - val_loss: 0.6152 - val_accuracy: 0.7895
# Epoch 160/200
# 2/2 [==============================] - 1s 864ms/step - loss: 0.2032 - accuracy: 0.9250 - val_loss: 0.6647 - val_accuracy: 0.7895
# Epoch 161/200
# 2/2 [==============================] - 1s 554ms/step - loss: 0.1820 - accuracy: 0.9250 - val_loss: 0.6378 - val_accuracy: 0.7895
# Epoch 162/200
# 2/2 [==============================] - 1s 900ms/step - loss: 0.2839 - accuracy: 0.8750 - val_loss: 0.6622 - val_accuracy: 0.7895
# Epoch 163/200
# 2/2 [==============================] - 2s 874ms/step - loss: 0.2138 - accuracy: 0.9062 - val_loss: 0.6830 - val_accuracy: 0.7895
# Epoch 164/200
# 2/2 [==============================] - 1s 601ms/step - loss: 0.2495 - accuracy: 0.8750 - val_loss: 0.7177 - val_accuracy: 0.7895
# Epoch 165/200
# 2/2 [==============================] - 2s 862ms/step - loss: 0.2686 - accuracy: 0.8906 - val_loss: 0.6119 - val_accuracy: 0.8421
# Epoch 166/200
# 2/2 [==============================] - 1s 519ms/step - loss: 0.2007 - accuracy: 0.9250 - val_loss: 0.5139 - val_accuracy: 0.8421
# Epoch 167/200
# 2/2 [==============================] - 1s 839ms/step - loss: 0.1927 - accuracy: 0.9500 - val_loss: 0.5965 - val_accuracy: 0.8421
# Epoch 168/200
# 2/2 [==============================] - 1s 886ms/step - loss: 0.1859 - accuracy: 0.9250 - val_loss: 0.5593 - val_accuracy: 0.8421
# Epoch 169/200
# 2/2 [==============================] - 1s 593ms/step - loss: 0.1965 - accuracy: 0.9000 - val_loss: 0.7759 - val_accuracy: 0.7895
# Epoch 170/200
# 2/2 [==============================] - 1s 529ms/step - loss: 0.1781 - accuracy: 0.9250 - val_loss: 0.8184 - val_accuracy: 0.7895
# Epoch 171/200
# 2/2 [==============================] - 2s 924ms/step - loss: 0.1924 - accuracy: 0.9219 - val_loss: 0.5433 - val_accuracy: 0.8421
# Epoch 172/200
# 2/2 [==============================] - 1s 540ms/step - loss: 0.2076 - accuracy: 0.9250 - val_loss: 0.4435 - val_accuracy: 0.8421
# Epoch 173/200
# 2/2 [==============================] - 2s 613ms/step - loss: 0.2233 - accuracy: 0.9000 - val_loss: 0.4505 - val_accuracy: 0.8421
# Epoch 174/200
# 2/2 [==============================] - 1s 885ms/step - loss: 0.3543 - accuracy: 0.8750 - val_loss: 0.6067 - val_accuracy: 0.8421
# Epoch 175/200
# 2/2 [==============================] - 2s 848ms/step - loss: 0.2006 - accuracy: 0.9062 - val_loss: 0.9221 - val_accuracy: 0.7368
# Epoch 176/200
# 2/2 [==============================] - 1s 603ms/step - loss: 0.1705 - accuracy: 0.9750 - val_loss: 0.7265 - val_accuracy: 0.8421
# Epoch 177/200
# 2/2 [==============================] - 1s 870ms/step - loss: 0.1906 - accuracy: 0.9000 - val_loss: 0.5286 - val_accuracy: 0.8421
# Epoch 178/200
# 2/2 [==============================] - 2s 817ms/step - loss: 0.2809 - accuracy: 0.8750 - val_loss: 0.5872 - val_accuracy: 0.8421
# Epoch 179/200
# 2/2 [==============================] - 1s 570ms/step - loss: 0.3001 - accuracy: 0.8750 - val_loss: 0.7986 - val_accuracy: 0.8421
# Epoch 180/200
# 2/2 [==============================] - 2s 1s/step - loss: 0.2589 - accuracy: 0.8906 - val_loss: 0.7978 - val_accuracy: 0.8421
# Epoch 181/200
# 2/2 [==============================] - 2s 945ms/step - loss: 0.1772 - accuracy: 0.9500 - val_loss: 0.6616 - val_accuracy: 0.8421
# Epoch 182/200
# 2/2 [==============================] - 2s 1s/step - loss: 0.1846 - accuracy: 0.9531 - val_loss: 0.5545 - val_accuracy: 0.8421
# Epoch 183/200
# 2/2 [==============================] - 2s 614ms/step - loss: 0.2938 - accuracy: 0.8500 - val_loss: 0.8477 - val_accuracy: 0.7368
# Epoch 184/200
# 2/2 [==============================] - 1s 868ms/step - loss: 0.2925 - accuracy: 0.8250 - val_loss: 1.0493 - val_accuracy: 0.6842
# Epoch 185/200
# 2/2 [==============================] - 2s 872ms/step - loss: 0.3026 - accuracy: 0.8438 - val_loss: 0.6997 - val_accuracy: 0.8421
# Epoch 186/200
# 2/2 [==============================] - 1s 547ms/step - loss: 0.1796 - accuracy: 0.9500 - val_loss: 0.5274 - val_accuracy: 0.8421
# Epoch 187/200
# 2/2 [==============================] - 1s 525ms/step - loss: 0.2533 - accuracy: 0.9000 - val_loss: 0.7166 - val_accuracy: 0.8421
# Epoch 188/200
# 2/2 [==============================] - 1s 533ms/step - loss: 0.2013 - accuracy: 0.9000 - val_loss: 1.3436 - val_accuracy: 0.6316
# Epoch 189/200
# 2/2 [==============================] - 1s 863ms/step - loss: 0.5209 - accuracy: 0.7500 - val_loss: 1.0609 - val_accuracy: 0.6842
# Epoch 190/200
# 2/2 [==============================] - 1s 512ms/step - loss: 0.2304 - accuracy: 0.9250 - val_loss: 0.4809 - val_accuracy: 0.8421
# Epoch 191/200
# 2/2 [==============================] - 1s 854ms/step - loss: 0.3882 - accuracy: 0.8750 - val_loss: 0.3270 - val_accuracy: 0.8421
# Epoch 192/200
# 2/2 [==============================] - 1s 526ms/step - loss: 0.5091 - accuracy: 0.8000 - val_loss: 0.4643 - val_accuracy: 0.8421
# Epoch 193/200
# 2/2 [==============================] - 1s 531ms/step - loss: 0.1582 - accuracy: 0.9750 - val_loss: 0.8936 - val_accuracy: 0.7895
# Epoch 194/200
# 2/2 [==============================] - 2s 838ms/step - loss: 0.1870 - accuracy: 0.9375 - val_loss: 1.3319 - val_accuracy: 0.6316
# Epoch 195/200
# 2/2 [==============================] - 2s 820ms/step - loss: 0.2905 - accuracy: 0.8281 - val_loss: 1.1606 - val_accuracy: 0.6842
# Epoch 196/200
# 2/2 [==============================] - 1s 509ms/step - loss: 0.3936 - accuracy: 0.7750 - val_loss: 0.6127 - val_accuracy: 0.7895
# Epoch 197/200
# 2/2 [==============================] - 2s 801ms/step - loss: 0.2242 - accuracy: 0.9062 - val_loss: 0.3858 - val_accuracy: 0.8421
# Epoch 198/200
# 2/2 [==============================] - 2s 829ms/step - loss: 0.3087 - accuracy: 0.8750 - val_loss: 0.3424 - val_accuracy: 0.7895
# Epoch 199/200
# 2/2 [==============================] - 1s 527ms/step - loss: 0.3729 - accuracy: 0.8000 - val_loss: 0.3951 - val_accuracy: 0.8421
# Epoch 200/200
# 2/2 [==============================] - 2s 859ms/step - loss: 0.3100 - accuracy: 0.8281 - val_loss: 0.5022 - val_accuracy: 0.8421

# %% [markdown]
# ### Dropout 0.7

# %%
# Crear el generador de datos para el conjunto de entrenamiento con data augmentation
train_data_generator = data_augmentation.flow(train_X, train_label_one_hot, batch_size=batch_size)

## Modifica el train_x para incluir las imagenes del train_data_generator
history3=modelo3.fit(train_data_generator, steps_per_epoch=len(train_X) // batch_size, epochs=epochs, verbose=1, validation_data=(valid_X, valid_label_one_hot))
# Out:
# Epoch 1/200
# 2/2 [==============================] - 3s 822ms/step - loss: 0.7295 - accuracy: 0.4500 - val_loss: 0.7449 - val_accuracy: 0.3684
# Epoch 2/200
# 2/2 [==============================] - 1s 591ms/step - loss: 0.6765 - accuracy: 0.5781 - val_loss: 0.6526 - val_accuracy: 0.6316
# Epoch 3/200
# 2/2 [==============================] - 1s 594ms/step - loss: 0.7009 - accuracy: 0.5938 - val_loss: 0.6424 - val_accuracy: 0.6316
# Epoch 4/200
# 2/2 [==============================] - 1s 596ms/step - loss: 0.6543 - accuracy: 0.6406 - val_loss: 0.6427 - val_accuracy: 0.6316
# Epoch 5/200
# 2/2 [==============================] - 1s 388ms/step - loss: 0.6736 - accuracy: 0.6500 - val_loss: 0.6402 - val_accuracy: 0.6316
# Epoch 6/200
# 2/2 [==============================] - 1s 600ms/step - loss: 0.6603 - accuracy: 0.6094 - val_loss: 0.6400 - val_accuracy: 0.6316
# Epoch 7/200
# 2/2 [==============================] - 1s 374ms/step - loss: 0.7936 - accuracy: 0.5000 - val_loss: 0.6361 - val_accuracy: 0.6316
# Epoch 8/200
# 2/2 [==============================] - 1s 587ms/step - loss: 0.7270 - accuracy: 0.5938 - val_loss: 0.6350 - val_accuracy: 0.6316
# Epoch 9/200
# 2/2 [==============================] - 1s 613ms/step - loss: 0.6383 - accuracy: 0.5750 - val_loss: 0.6365 - val_accuracy: 0.6316
# Epoch 10/200
# 2/2 [==============================] - 1s 590ms/step - loss: 0.6619 - accuracy: 0.6000 - val_loss: 0.6362 - val_accuracy: 0.6316
# Epoch 11/200
# 2/2 [==============================] - 1s 369ms/step - loss: 0.7419 - accuracy: 0.4750 - val_loss: 0.6374 - val_accuracy: 0.6316
# Epoch 12/200
# 2/2 [==============================] - 1s 590ms/step - loss: 0.6536 - accuracy: 0.5625 - val_loss: 0.6370 - val_accuracy: 0.6316
# Epoch 13/200
# 2/2 [==============================] - 1s 612ms/step - loss: 0.6298 - accuracy: 0.6094 - val_loss: 0.6335 - val_accuracy: 0.6316
# Epoch 14/200
# 2/2 [==============================] - 1s 388ms/step - loss: 0.6135 - accuracy: 0.6500 - val_loss: 0.6299 - val_accuracy: 0.6316
# Epoch 15/200
# 2/2 [==============================] - 1s 592ms/step - loss: 0.6579 - accuracy: 0.6250 - val_loss: 0.6258 - val_accuracy: 0.6316
# Epoch 16/200
# 2/2 [==============================] - 1s 600ms/step - loss: 0.6857 - accuracy: 0.6250 - val_loss: 0.6225 - val_accuracy: 0.6316
# Epoch 17/200
# 2/2 [==============================] - 1s 600ms/step - loss: 0.6455 - accuracy: 0.6250 - val_loss: 0.6201 - val_accuracy: 0.6316
# Epoch 18/200
# 2/2 [==============================] - 1s 366ms/step - loss: 0.6968 - accuracy: 0.5250 - val_loss: 0.6178 - val_accuracy: 0.6316
# Epoch 19/200
# 2/2 [==============================] - 1s 587ms/step - loss: 0.6740 - accuracy: 0.6000 - val_loss: 0.6170 - val_accuracy: 0.6316
# Epoch 20/200
# 2/2 [==============================] - 1s 413ms/step - loss: 0.6836 - accuracy: 0.6500 - val_loss: 0.6163 - val_accuracy: 0.6316
# Epoch 21/200
# 2/2 [==============================] - 1s 590ms/step - loss: 0.7447 - accuracy: 0.5000 - val_loss: 0.6148 - val_accuracy: 0.6316
# Epoch 22/200
# 2/2 [==============================] - 1s 603ms/step - loss: 0.6436 - accuracy: 0.6250 - val_loss: 0.6132 - val_accuracy: 0.6316
# Epoch 23/200
# 2/2 [==============================] - 1s 597ms/step - loss: 0.6513 - accuracy: 0.6406 - val_loss: 0.6096 - val_accuracy: 0.6316
# Epoch 24/200
# 2/2 [==============================] - 1s 591ms/step - loss: 0.6746 - accuracy: 0.6250 - val_loss: 0.6071 - val_accuracy: 0.6316
# Epoch 25/200
# 2/2 [==============================] - 1s 599ms/step - loss: 0.6566 - accuracy: 0.6719 - val_loss: 0.6097 - val_accuracy: 0.6842
# Epoch 26/200
# 2/2 [==============================] - 1s 598ms/step - loss: 0.6151 - accuracy: 0.6250 - val_loss: 0.6133 - val_accuracy: 0.6842
# Epoch 27/200
# 2/2 [==============================] - 1s 605ms/step - loss: 0.6412 - accuracy: 0.6562 - val_loss: 0.6106 - val_accuracy: 0.6842
# Epoch 28/200
# 2/2 [==============================] - 1s 614ms/step - loss: 0.6386 - accuracy: 0.6250 - val_loss: 0.6066 - val_accuracy: 0.6842
# Epoch 29/200
# 2/2 [==============================] - 1s 601ms/step - loss: 0.6534 - accuracy: 0.6250 - val_loss: 0.6022 - val_accuracy: 0.6316
# Epoch 30/200
# 2/2 [==============================] - 1s 595ms/step - loss: 0.6246 - accuracy: 0.6719 - val_loss: 0.6014 - val_accuracy: 0.6316
# Epoch 31/200
# 2/2 [==============================] - 1s 375ms/step - loss: 0.6113 - accuracy: 0.6250 - val_loss: 0.6002 - val_accuracy: 0.6316
# Epoch 32/200
# 2/2 [==============================] - 1s 599ms/step - loss: 0.5964 - accuracy: 0.6562 - val_loss: 0.5966 - val_accuracy: 0.6316
# Epoch 33/200
# 2/2 [==============================] - 1s 596ms/step - loss: 0.5731 - accuracy: 0.7250 - val_loss: 0.5959 - val_accuracy: 0.6316
# Epoch 34/200
# 2/2 [==============================] - 1s 593ms/step - loss: 0.6003 - accuracy: 0.6500 - val_loss: 0.5996 - val_accuracy: 0.6316
# Epoch 35/200
# 2/2 [==============================] - 1s 588ms/step - loss: 0.5923 - accuracy: 0.6750 - val_loss: 0.5903 - val_accuracy: 0.6316
# Epoch 36/200
# 2/2 [==============================] - 1s 638ms/step - loss: 0.5857 - accuracy: 0.6250 - val_loss: 0.5863 - val_accuracy: 0.6316
# Epoch 37/200
# 2/2 [==============================] - 1s 597ms/step - loss: 0.6288 - accuracy: 0.6562 - val_loss: 0.5754 - val_accuracy: 0.7368
# Epoch 38/200
# 2/2 [==============================] - 1s 372ms/step - loss: 0.6175 - accuracy: 0.7000 - val_loss: 0.5703 - val_accuracy: 0.7368
# Epoch 39/200
# 2/2 [==============================] - 1s 594ms/step - loss: 0.5861 - accuracy: 0.7250 - val_loss: 0.5685 - val_accuracy: 0.7368
# Epoch 40/200
# 2/2 [==============================] - 1s 604ms/step - loss: 0.5624 - accuracy: 0.7031 - val_loss: 0.5676 - val_accuracy: 0.7368
# Epoch 41/200
# 2/2 [==============================] - 1s 596ms/step - loss: 0.5191 - accuracy: 0.7250 - val_loss: 0.5704 - val_accuracy: 0.6842
# Epoch 42/200
# 2/2 [==============================] - 1s 597ms/step - loss: 0.5748 - accuracy: 0.6875 - val_loss: 0.5723 - val_accuracy: 0.6316
# Epoch 43/200
# 2/2 [==============================] - 1s 642ms/step - loss: 0.5456 - accuracy: 0.7188 - val_loss: 0.5625 - val_accuracy: 0.7368
# Epoch 44/200
# 2/2 [==============================] - 1s 616ms/step - loss: 0.5038 - accuracy: 0.7500 - val_loss: 0.5447 - val_accuracy: 0.7368
# Epoch 45/200
# 2/2 [==============================] - 1s 598ms/step - loss: 0.5339 - accuracy: 0.7188 - val_loss: 0.5371 - val_accuracy: 0.7368
# Epoch 46/200
# 2/2 [==============================] - 1s 647ms/step - loss: 0.5087 - accuracy: 0.7969 - val_loss: 0.5361 - val_accuracy: 0.7368
# Epoch 47/200
# 2/2 [==============================] - 1s 599ms/step - loss: 0.4746 - accuracy: 0.8250 - val_loss: 0.5668 - val_accuracy: 0.6842
# Epoch 48/200
# 2/2 [==============================] - 1s 364ms/step - loss: 0.5231 - accuracy: 0.7250 - val_loss: 0.5599 - val_accuracy: 0.6842
# Epoch 49/200
# 2/2 [==============================] - 1s 396ms/step - loss: 0.6078 - accuracy: 0.7000 - val_loss: 0.5110 - val_accuracy: 0.7368
# Epoch 50/200
# 2/2 [==============================] - 1s 374ms/step - loss: 0.5273 - accuracy: 0.7500 - val_loss: 0.5069 - val_accuracy: 0.7368
# Epoch 51/200
# 2/2 [==============================] - 1s 602ms/step - loss: 0.4109 - accuracy: 0.8750 - val_loss: 0.5465 - val_accuracy: 0.6842
# Epoch 52/200
# 2/2 [==============================] - 1s 386ms/step - loss: 0.5545 - accuracy: 0.6500 - val_loss: 0.5670 - val_accuracy: 0.6842
# Epoch 53/200
# 2/2 [==============================] - 1s 753ms/step - loss: 0.4306 - accuracy: 0.7750 - val_loss: 0.5087 - val_accuracy: 0.7368
# Epoch 54/200
# 2/2 [==============================] - 1s 404ms/step - loss: 0.4893 - accuracy: 0.6750 - val_loss: 0.4955 - val_accuracy: 0.7368
# Epoch 55/200
# 2/2 [==============================] - 1s 368ms/step - loss: 0.5156 - accuracy: 0.7500 - val_loss: 0.4931 - val_accuracy: 0.7368
# Epoch 56/200
# 2/2 [==============================] - 1s 617ms/step - loss: 0.5015 - accuracy: 0.7656 - val_loss: 0.5147 - val_accuracy: 0.6842
# Epoch 57/200
# 2/2 [==============================] - 1s 607ms/step - loss: 0.4437 - accuracy: 0.7500 - val_loss: 0.5470 - val_accuracy: 0.6842
# Epoch 58/200
# 2/2 [==============================] - 1s 378ms/step - loss: 0.5301 - accuracy: 0.6750 - val_loss: 0.4980 - val_accuracy: 0.7368
# Epoch 59/200
# 2/2 [==============================] - 1s 372ms/step - loss: 0.5505 - accuracy: 0.7250 - val_loss: 0.4706 - val_accuracy: 0.7895
# Epoch 60/200
# 2/2 [==============================] - 1s 596ms/step - loss: 0.4975 - accuracy: 0.7656 - val_loss: 0.4783 - val_accuracy: 0.7368
# Epoch 61/200
# 2/2 [==============================] - 1s 368ms/step - loss: 0.4765 - accuracy: 0.7500 - val_loss: 0.5910 - val_accuracy: 0.6842
# Epoch 62/200
# 2/2 [==============================] - 1s 651ms/step - loss: 0.5812 - accuracy: 0.7000 - val_loss: 0.7506 - val_accuracy: 0.6316
# Epoch 63/200
# 2/2 [==============================] - 1s 368ms/step - loss: 0.5930 - accuracy: 0.6500 - val_loss: 0.5843 - val_accuracy: 0.6842
# Epoch 64/200
# 2/2 [==============================] - 1s 599ms/step - loss: 0.5298 - accuracy: 0.6750 - val_loss: 0.4688 - val_accuracy: 0.7895
# Epoch 65/200
# 2/2 [==============================] - 1s 599ms/step - loss: 0.5605 - accuracy: 0.6719 - val_loss: 0.4975 - val_accuracy: 0.7368
# Epoch 66/200
# 2/2 [==============================] - 1s 597ms/step - loss: 0.5572 - accuracy: 0.6500 - val_loss: 0.4883 - val_accuracy: 0.7895
# Epoch 67/200
# 2/2 [==============================] - 1s 598ms/step - loss: 0.5451 - accuracy: 0.6750 - val_loss: 0.5085 - val_accuracy: 0.7368
# Epoch 68/200
# 2/2 [==============================] - 1s 373ms/step - loss: 0.4860 - accuracy: 0.7750 - val_loss: 0.5684 - val_accuracy: 0.6316
# Epoch 69/200
# 2/2 [==============================] - 1s 633ms/step - loss: 0.4897 - accuracy: 0.7500 - val_loss: 0.5945 - val_accuracy: 0.6316
# Epoch 70/200
# 2/2 [==============================] - 1s 367ms/step - loss: 0.5578 - accuracy: 0.7000 - val_loss: 0.5785 - val_accuracy: 0.6316
# Epoch 71/200
# 2/2 [==============================] - 1s 363ms/step - loss: 0.4769 - accuracy: 0.7750 - val_loss: 0.5482 - val_accuracy: 0.6316
# Epoch 72/200
# 2/2 [==============================] - 1s 605ms/step - loss: 0.5191 - accuracy: 0.7500 - val_loss: 0.5264 - val_accuracy: 0.7368
# Epoch 73/200
# 2/2 [==============================] - 1s 592ms/step - loss: 0.4758 - accuracy: 0.7500 - val_loss: 0.5133 - val_accuracy: 0.7368
# Epoch 74/200
# 2/2 [==============================] - 1s 640ms/step - loss: 0.4173 - accuracy: 0.8000 - val_loss: 0.5033 - val_accuracy: 0.7368
# Epoch 75/200
# 2/2 [==============================] - 1s 375ms/step - loss: 0.4828 - accuracy: 0.7000 - val_loss: 0.4786 - val_accuracy: 0.7368
# Epoch 76/200
# 2/2 [==============================] - 1s 597ms/step - loss: 0.5566 - accuracy: 0.7000 - val_loss: 0.4605 - val_accuracy: 0.7368
# Epoch 77/200
# 2/2 [==============================] - 1s 595ms/step - loss: 0.4949 - accuracy: 0.7000 - val_loss: 0.4528 - val_accuracy: 0.7368
# Epoch 78/200
# 2/2 [==============================] - 1s 602ms/step - loss: 0.4578 - accuracy: 0.8906 - val_loss: 0.4621 - val_accuracy: 0.7368
# Epoch 79/200
# 2/2 [==============================] - 1s 595ms/step - loss: 0.4209 - accuracy: 0.7750 - val_loss: 0.5427 - val_accuracy: 0.6842
# Epoch 80/200
# 2/2 [==============================] - 1s 368ms/step - loss: 0.4916 - accuracy: 0.6750 - val_loss: 0.5849 - val_accuracy: 0.6842
# Epoch 81/200
# 2/2 [==============================] - 1s 631ms/step - loss: 0.4035 - accuracy: 0.8500 - val_loss: 0.5436 - val_accuracy: 0.6842
# Epoch 82/200
# 2/2 [==============================] - 1s 660ms/step - loss: 0.4160 - accuracy: 0.8250 - val_loss: 0.4490 - val_accuracy: 0.7368
# Epoch 83/200
# 2/2 [==============================] - 1s 419ms/step - loss: 0.4619 - accuracy: 0.7500 - val_loss: 0.4174 - val_accuracy: 0.7895
# Epoch 84/200
# 2/2 [==============================] - 1s 594ms/step - loss: 0.4674 - accuracy: 0.7656 - val_loss: 0.4177 - val_accuracy: 0.7895
# Epoch 85/200
# 2/2 [==============================] - 1s 588ms/step - loss: 0.4169 - accuracy: 0.7500 - val_loss: 0.4611 - val_accuracy: 0.7368
# Epoch 86/200
# 2/2 [==============================] - 1s 595ms/step - loss: 0.3900 - accuracy: 0.7750 - val_loss: 0.5162 - val_accuracy: 0.6842
# Epoch 87/200
# 2/2 [==============================] - 1s 588ms/step - loss: 0.4188 - accuracy: 0.7812 - val_loss: 0.5304 - val_accuracy: 0.6842
# Epoch 88/200
# 2/2 [==============================] - 1s 600ms/step - loss: 0.4795 - accuracy: 0.8000 - val_loss: 0.4799 - val_accuracy: 0.7368
# Epoch 89/200
# 2/2 [==============================] - 1s 610ms/step - loss: 0.3707 - accuracy: 0.8500 - val_loss: 0.4261 - val_accuracy: 0.7368
# Epoch 90/200
# 2/2 [==============================] - 1s 643ms/step - loss: 0.4350 - accuracy: 0.8250 - val_loss: 0.4624 - val_accuracy: 0.7368
# Epoch 91/200
# 2/2 [==============================] - 1s 608ms/step - loss: 0.3791 - accuracy: 0.8125 - val_loss: 0.5225 - val_accuracy: 0.7368
# Epoch 92/200
# 2/2 [==============================] - 1s 618ms/step - loss: 0.4008 - accuracy: 0.8000 - val_loss: 0.4389 - val_accuracy: 0.7368
# Epoch 93/200
# 2/2 [==============================] - 1s 598ms/step - loss: 0.4139 - accuracy: 0.8750 - val_loss: 0.5382 - val_accuracy: 0.6842
# Epoch 94/200
# 2/2 [==============================] - 1s 382ms/step - loss: 0.4755 - accuracy: 0.7500 - val_loss: 0.5464 - val_accuracy: 0.6842
# Epoch 95/200
# 2/2 [==============================] - 1s 656ms/step - loss: 0.3785 - accuracy: 0.8125 - val_loss: 0.4918 - val_accuracy: 0.7368
# Epoch 96/200
# 2/2 [==============================] - 1s 649ms/step - loss: 0.4493 - accuracy: 0.7750 - val_loss: 0.4456 - val_accuracy: 0.7895
# Epoch 97/200
# 2/2 [==============================] - 1s 626ms/step - loss: 0.4055 - accuracy: 0.7344 - val_loss: 0.4295 - val_accuracy: 0.7895
# Epoch 98/200
# 2/2 [==============================] - 1s 597ms/step - loss: 0.4696 - accuracy: 0.7000 - val_loss: 0.4121 - val_accuracy: 0.7895
# Epoch 99/200
# 2/2 [==============================] - 1s 374ms/step - loss: 0.3493 - accuracy: 0.9000 - val_loss: 0.4397 - val_accuracy: 0.7895
# Epoch 100/200
# 2/2 [==============================] - 1s 602ms/step - loss: 0.2729 - accuracy: 0.9000 - val_loss: 0.6201 - val_accuracy: 0.6842
# Epoch 101/200
# 2/2 [==============================] - 1s 591ms/step - loss: 0.3986 - accuracy: 0.8000 - val_loss: 0.8424 - val_accuracy: 0.6316
# Epoch 102/200
# 2/2 [==============================] - 1s 597ms/step - loss: 0.4275 - accuracy: 0.7812 - val_loss: 0.5706 - val_accuracy: 0.6842
# Epoch 103/200
# 2/2 [==============================] - 1s 640ms/step - loss: 0.3622 - accuracy: 0.7812 - val_loss: 0.4045 - val_accuracy: 0.7895
# Epoch 104/200
# 2/2 [==============================] - 1s 601ms/step - loss: 0.4169 - accuracy: 0.7750 - val_loss: 0.4042 - val_accuracy: 0.7895
# Epoch 105/200
# 2/2 [==============================] - 1s 407ms/step - loss: 0.3150 - accuracy: 0.9250 - val_loss: 0.4360 - val_accuracy: 0.7895
# Epoch 106/200
# 2/2 [==============================] - 1s 613ms/step - loss: 0.4359 - accuracy: 0.7500 - val_loss: 0.4601 - val_accuracy: 0.7895
# Epoch 107/200
# 2/2 [==============================] - 1s 596ms/step - loss: 0.3179 - accuracy: 0.8750 - val_loss: 0.5104 - val_accuracy: 0.7368
# Epoch 108/200
# 2/2 [==============================] - 1s 602ms/step - loss: 0.3948 - accuracy: 0.8125 - val_loss: 0.5541 - val_accuracy: 0.7368
# Epoch 109/200
# 2/2 [==============================] - 1s 614ms/step - loss: 0.3905 - accuracy: 0.7656 - val_loss: 0.5209 - val_accuracy: 0.7368
# Epoch 110/200
# 2/2 [==============================] - 1s 446ms/step - loss: 0.3994 - accuracy: 0.8000 - val_loss: 0.4189 - val_accuracy: 0.7895
# Epoch 111/200
# 2/2 [==============================] - 1s 597ms/step - loss: 0.3512 - accuracy: 0.8750 - val_loss: 0.4082 - val_accuracy: 0.7895
# Epoch 112/200
# 2/2 [==============================] - 1s 400ms/step - loss: 0.3249 - accuracy: 0.8750 - val_loss: 0.4642 - val_accuracy: 0.7895
# Epoch 113/200
# 2/2 [==============================] - 1s 594ms/step - loss: 0.4177 - accuracy: 0.7344 - val_loss: 0.5909 - val_accuracy: 0.6842
# Epoch 114/200
# 2/2 [==============================] - 1s 389ms/step - loss: 0.4166 - accuracy: 0.7500 - val_loss: 0.4905 - val_accuracy: 0.7895
# Epoch 115/200
# 2/2 [==============================] - 1s 590ms/step - loss: 0.3312 - accuracy: 0.8000 - val_loss: 0.3893 - val_accuracy: 0.7895
# Epoch 116/200
# 2/2 [==============================] - 1s 596ms/step - loss: 0.3419 - accuracy: 0.9000 - val_loss: 0.3917 - val_accuracy: 0.8421
# Epoch 117/200
# 2/2 [==============================] - 1s 374ms/step - loss: 0.3847 - accuracy: 0.8000 - val_loss: 0.4774 - val_accuracy: 0.7895
# Epoch 118/200
# 2/2 [==============================] - 1s 389ms/step - loss: 0.2694 - accuracy: 0.8750 - val_loss: 0.8200 - val_accuracy: 0.6316
# Epoch 119/200
# 2/2 [==============================] - 1s 600ms/step - loss: 0.5691 - accuracy: 0.6750 - val_loss: 0.7965 - val_accuracy: 0.6316
# Epoch 120/200
# 2/2 [==============================] - 1s 627ms/step - loss: 0.3684 - accuracy: 0.7750 - val_loss: 0.4089 - val_accuracy: 0.8421
# Epoch 121/200
# 2/2 [==============================] - 1s 612ms/step - loss: 0.4926 - accuracy: 0.8500 - val_loss: 0.3593 - val_accuracy: 0.7895
# Epoch 122/200
# 2/2 [==============================] - 1s 364ms/step - loss: 0.4433 - accuracy: 0.7750 - val_loss: 0.3655 - val_accuracy: 0.7895
# Epoch 123/200
# 2/2 [==============================] - 1s 584ms/step - loss: 0.4211 - accuracy: 0.8250 - val_loss: 0.3676 - val_accuracy: 0.7895
# Epoch 124/200
# 2/2 [==============================] - 1s 369ms/step - loss: 0.4890 - accuracy: 0.7250 - val_loss: 0.4028 - val_accuracy: 0.7895
# Epoch 125/200
# 2/2 [==============================] - 1s 615ms/step - loss: 0.4017 - accuracy: 0.8250 - val_loss: 0.4904 - val_accuracy: 0.7895
# Epoch 126/200
# 2/2 [==============================] - 1s 640ms/step - loss: 0.3575 - accuracy: 0.8000 - val_loss: 0.6429 - val_accuracy: 0.6316
# Epoch 127/200
# 2/2 [==============================] - 1s 602ms/step - loss: 0.4723 - accuracy: 0.7500 - val_loss: 0.7381 - val_accuracy: 0.6316
# Epoch 128/200
# 2/2 [==============================] - 1s 618ms/step - loss: 0.4060 - accuracy: 0.7250 - val_loss: 0.6586 - val_accuracy: 0.6316
# Epoch 129/200
# 2/2 [==============================] - 1s 601ms/step - loss: 0.3134 - accuracy: 0.8000 - val_loss: 0.5344 - val_accuracy: 0.7368
# Epoch 130/200
# 2/2 [==============================] - 1s 594ms/step - loss: 0.3688 - accuracy: 0.8000 - val_loss: 0.4678 - val_accuracy: 0.7895
# Epoch 131/200
# 2/2 [==============================] - 1s 584ms/step - loss: 0.3141 - accuracy: 0.8750 - val_loss: 0.4284 - val_accuracy: 0.7895
# Epoch 132/200
# 2/2 [==============================] - 1s 606ms/step - loss: 0.3268 - accuracy: 0.9250 - val_loss: 0.3872 - val_accuracy: 0.7895
# Epoch 133/200
# 2/2 [==============================] - 1s 376ms/step - loss: 0.2992 - accuracy: 0.9250 - val_loss: 0.3662 - val_accuracy: 0.8421
# Epoch 134/200
# 2/2 [==============================] - 1s 614ms/step - loss: 0.3518 - accuracy: 0.8281 - val_loss: 0.4008 - val_accuracy: 0.7895
# Epoch 135/200
# 2/2 [==============================] - 1s 601ms/step - loss: 0.3226 - accuracy: 0.8250 - val_loss: 0.6243 - val_accuracy: 0.7368
# Epoch 136/200
# 2/2 [==============================] - 1s 618ms/step - loss: 0.3338 - accuracy: 0.8750 - val_loss: 0.7975 - val_accuracy: 0.6842
# Epoch 137/200
# 2/2 [==============================] - 1s 686ms/step - loss: 0.3782 - accuracy: 0.8125 - val_loss: 0.7091 - val_accuracy: 0.7368
# Epoch 138/200
# 2/2 [==============================] - 1s 601ms/step - loss: 0.3990 - accuracy: 0.8125 - val_loss: 0.5088 - val_accuracy: 0.7368
# Epoch 139/200
# 2/2 [==============================] - 1s 603ms/step - loss: 0.3179 - accuracy: 0.8750 - val_loss: 0.4128 - val_accuracy: 0.8421
# Epoch 140/200
# 2/2 [==============================] - 1s 378ms/step - loss: 0.3436 - accuracy: 0.8000 - val_loss: 0.4284 - val_accuracy: 0.8421
# Epoch 141/200
# 2/2 [==============================] - 1s 387ms/step - loss: 0.3621 - accuracy: 0.9000 - val_loss: 0.4677 - val_accuracy: 0.8421
# Epoch 142/200
# 2/2 [==============================] - 1s 614ms/step - loss: 0.2895 - accuracy: 0.9000 - val_loss: 0.5849 - val_accuracy: 0.7368
# Epoch 143/200
# 2/2 [==============================] - 1s 370ms/step - loss: 0.2981 - accuracy: 0.8750 - val_loss: 0.7410 - val_accuracy: 0.6316
# Epoch 144/200
# 2/2 [==============================] - 1s 627ms/step - loss: 0.3829 - accuracy: 0.8250 - val_loss: 0.7875 - val_accuracy: 0.6316
# Epoch 145/200
# 2/2 [==============================] - 1s 589ms/step - loss: 0.4351 - accuracy: 0.8000 - val_loss: 0.5696 - val_accuracy: 0.7895
# Epoch 146/200
# 2/2 [==============================] - 1s 602ms/step - loss: 0.3385 - accuracy: 0.8750 - val_loss: 0.4439 - val_accuracy: 0.8421
# Epoch 147/200
# 2/2 [==============================] - 1s 606ms/step - loss: 0.3744 - accuracy: 0.9000 - val_loss: 0.4047 - val_accuracy: 0.8421
# Epoch 148/200
# 2/2 [==============================] - 1s 602ms/step - loss: 0.3661 - accuracy: 0.8750 - val_loss: 0.4020 - val_accuracy: 0.8421
# Epoch 149/200
# 2/2 [==============================] - 1s 626ms/step - loss: 0.3114 - accuracy: 0.9250 - val_loss: 0.4317 - val_accuracy: 0.7895
# Epoch 150/200
# 2/2 [==============================] - 1s 606ms/step - loss: 0.3270 - accuracy: 0.8500 - val_loss: 0.4705 - val_accuracy: 0.7895
# Epoch 151/200
# 2/2 [==============================] - 1s 606ms/step - loss: 0.3421 - accuracy: 0.8500 - val_loss: 0.5198 - val_accuracy: 0.7895
# Epoch 152/200
# 2/2 [==============================] - 1s 642ms/step - loss: 0.3050 - accuracy: 0.9000 - val_loss: 0.6113 - val_accuracy: 0.7895
# Epoch 153/200
# 2/2 [==============================] - 1s 653ms/step - loss: 0.4007 - accuracy: 0.8250 - val_loss: 0.7030 - val_accuracy: 0.7368
# Epoch 154/200
# 2/2 [==============================] - 1s 608ms/step - loss: 0.2560 - accuracy: 0.9000 - val_loss: 0.7295 - val_accuracy: 0.7368
# Epoch 155/200
# 2/2 [==============================] - 1s 610ms/step - loss: 0.2966 - accuracy: 0.8125 - val_loss: 0.5760 - val_accuracy: 0.7895
# Epoch 156/200
# 2/2 [==============================] - 1s 386ms/step - loss: 0.3684 - accuracy: 0.8000 - val_loss: 0.4445 - val_accuracy: 0.7895
# Epoch 157/200
# 2/2 [==============================] - 1s 603ms/step - loss: 0.3348 - accuracy: 0.8750 - val_loss: 0.4419 - val_accuracy: 0.7895
# Epoch 158/200
# 2/2 [==============================] - 1s 599ms/step - loss: 0.2880 - accuracy: 0.8750 - val_loss: 0.5420 - val_accuracy: 0.7895
# Epoch 159/200
# 2/2 [==============================] - 1s 618ms/step - loss: 0.3447 - accuracy: 0.8750 - val_loss: 0.6250 - val_accuracy: 0.7895
# Epoch 160/200
# 2/2 [==============================] - 1s 598ms/step - loss: 0.3190 - accuracy: 0.8750 - val_loss: 0.5925 - val_accuracy: 0.7895
# Epoch 161/200
# 2/2 [==============================] - 1s 593ms/step - loss: 0.3455 - accuracy: 0.8000 - val_loss: 0.5066 - val_accuracy: 0.7895
# Epoch 162/200
# 2/2 [==============================] - 1s 593ms/step - loss: 0.3521 - accuracy: 0.8594 - val_loss: 0.4371 - val_accuracy: 0.8421
# Epoch 163/200
# 2/2 [==============================] - 1s 604ms/step - loss: 0.2618 - accuracy: 0.9250 - val_loss: 0.4247 - val_accuracy: 0.8421
# Epoch 164/200
# 2/2 [==============================] - 1s 371ms/step - loss: 0.2288 - accuracy: 0.9500 - val_loss: 0.4583 - val_accuracy: 0.8421
# Epoch 165/200
# 2/2 [==============================] - 1s 383ms/step - loss: 0.2950 - accuracy: 0.8750 - val_loss: 0.5213 - val_accuracy: 0.8421
# Epoch 166/200
# 2/2 [==============================] - 1s 436ms/step - loss: 0.2809 - accuracy: 0.8250 - val_loss: 0.6077 - val_accuracy: 0.7895
# Epoch 167/200
# 2/2 [==============================] - 1s 623ms/step - loss: 0.2892 - accuracy: 0.8594 - val_loss: 0.6505 - val_accuracy: 0.7368
# Epoch 168/200
# 2/2 [==============================] - 1s 373ms/step - loss: 0.3147 - accuracy: 0.9000 - val_loss: 0.7284 - val_accuracy: 0.7368
# Epoch 169/200
# 2/2 [==============================] - 1s 434ms/step - loss: 0.3362 - accuracy: 0.8750 - val_loss: 0.5795 - val_accuracy: 0.7895
# Epoch 170/200
# 2/2 [==============================] - 1s 381ms/step - loss: 0.2205 - accuracy: 0.9250 - val_loss: 0.5092 - val_accuracy: 0.8421
# Epoch 171/200
# 2/2 [==============================] - 1s 654ms/step - loss: 0.2987 - accuracy: 0.8750 - val_loss: 0.4913 - val_accuracy: 0.8421
# Epoch 172/200
# 2/2 [==============================] - 1s 611ms/step - loss: 0.3611 - accuracy: 0.8500 - val_loss: 0.6685 - val_accuracy: 0.7368
# Epoch 173/200
# 2/2 [==============================] - 1s 381ms/step - loss: 0.2958 - accuracy: 0.8000 - val_loss: 0.6488 - val_accuracy: 0.7895
# Epoch 174/200
# 2/2 [==============================] - 1s 374ms/step - loss: 0.3021 - accuracy: 0.9000 - val_loss: 0.5028 - val_accuracy: 0.8421
# Epoch 175/200
# 2/2 [==============================] - 1s 646ms/step - loss: 0.2452 - accuracy: 0.9250 - val_loss: 0.4478 - val_accuracy: 0.8421
# Epoch 176/200
# 2/2 [==============================] - 1s 604ms/step - loss: 0.2777 - accuracy: 0.8750 - val_loss: 0.4771 - val_accuracy: 0.8421
# Epoch 177/200
# 2/2 [==============================] - 1s 381ms/step - loss: 0.2806 - accuracy: 0.8500 - val_loss: 0.6324 - val_accuracy: 0.7895
# Epoch 178/200
# 2/2 [==============================] - 1s 608ms/step - loss: 0.2767 - accuracy: 0.8750 - val_loss: 0.7296 - val_accuracy: 0.7895
# Epoch 179/200
# 2/2 [==============================] - 1s 593ms/step - loss: 0.2389 - accuracy: 0.9000 - val_loss: 0.7624 - val_accuracy: 0.7895
# Epoch 180/200
# 2/2 [==============================] - 1s 380ms/step - loss: 0.3774 - accuracy: 0.8500 - val_loss: 0.5796 - val_accuracy: 0.7895
# Epoch 181/200
# 2/2 [==============================] - 1s 604ms/step - loss: 0.3391 - accuracy: 0.8000 - val_loss: 0.4438 - val_accuracy: 0.8421
# Epoch 182/200
# 2/2 [==============================] - 1s 597ms/step - loss: 0.3730 - accuracy: 0.8000 - val_loss: 0.4324 - val_accuracy: 0.8421
# Epoch 183/200
# 2/2 [==============================] - 1s 397ms/step - loss: 0.2349 - accuracy: 0.9000 - val_loss: 0.4533 - val_accuracy: 0.8421
# Epoch 184/200
# 2/2 [==============================] - 1s 367ms/step - loss: 0.3598 - accuracy: 0.8500 - val_loss: 0.5231 - val_accuracy: 0.8421
# Epoch 185/200
# 2/2 [==============================] - 1s 584ms/step - loss: 0.2707 - accuracy: 0.8750 - val_loss: 0.5717 - val_accuracy: 0.8421
# Epoch 186/200
# 2/2 [==============================] - 1s 606ms/step - loss: 0.2916 - accuracy: 0.8750 - val_loss: 0.5873 - val_accuracy: 0.8421
# Epoch 187/200
# 2/2 [==============================] - 1s 610ms/step - loss: 0.2693 - accuracy: 0.8750 - val_loss: 0.6001 - val_accuracy: 0.8421
# Epoch 188/200
# 2/2 [==============================] - 1s 585ms/step - loss: 0.3001 - accuracy: 0.8438 - val_loss: 0.5439 - val_accuracy: 0.8421
# Epoch 189/200
# 2/2 [==============================] - 1s 589ms/step - loss: 0.2395 - accuracy: 0.8906 - val_loss: 0.4909 - val_accuracy: 0.8421
# Epoch 190/200
# 2/2 [==============================] - 1s 374ms/step - loss: 0.2770 - accuracy: 0.9000 - val_loss: 0.4722 - val_accuracy: 0.8421
# Epoch 191/200
# 2/2 [==============================] - 1s 368ms/step - loss: 0.2737 - accuracy: 0.8250 - val_loss: 0.4935 - val_accuracy: 0.8421
# Epoch 192/200
# 2/2 [==============================] - 1s 595ms/step - loss: 0.2595 - accuracy: 0.9219 - val_loss: 0.5611 - val_accuracy: 0.8421
# Epoch 193/200
# 2/2 [==============================] - 1s 607ms/step - loss: 0.1653 - accuracy: 0.9375 - val_loss: 0.6163 - val_accuracy: 0.8421
# Epoch 194/200
# 2/2 [==============================] - 1s 608ms/step - loss: 0.2573 - accuracy: 0.8906 - val_loss: 0.5458 - val_accuracy: 0.8421
# Epoch 195/200
# 2/2 [==============================] - 1s 395ms/step - loss: 0.1834 - accuracy: 0.9500 - val_loss: 0.5087 - val_accuracy: 0.8421
# Epoch 196/200
# 2/2 [==============================] - 1s 606ms/step - loss: 0.2790 - accuracy: 0.8750 - val_loss: 0.4839 - val_accuracy: 0.8421
# Epoch 197/200
# 2/2 [==============================] - 1s 607ms/step - loss: 0.1994 - accuracy: 0.9500 - val_loss: 0.4204 - val_accuracy: 0.8421
# Epoch 198/200
# 2/2 [==============================] - 1s 406ms/step - loss: 0.2095 - accuracy: 0.9250 - val_loss: 0.5473 - val_accuracy: 0.8421
# Epoch 199/200
# 2/2 [==============================] - 1s 643ms/step - loss: 0.2215 - accuracy: 0.9219 - val_loss: 0.7487 - val_accuracy: 0.8421
# Epoch 200/200
# 2/2 [==============================] - 1s 602ms/step - loss: 0.2139 - accuracy: 0.9250 - val_loss: 0.7449 - val_accuracy: 0.8421

# %% [markdown]
# ## Obtenemos las métricas de entrenamiento y validación, luego graficamos

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

def metricas(clases_reales, clases_predichas):
    matriz_conf=confusion_matrix(clases_reales, clases_predichas)
    accuracy=accuracy_score(clases_reales,clases_predichas)
    precision=precision_score(clases_reales,clases_predichas)
    recall=recall_score(clases_reales,clases_predichas)
    f1=f1_score(clases_reales,clases_predichas)
    return matriz_conf, accuracy, recall, precision, f1

def visualizar_metricas(clases_reales,clases_predichas, titulo):
    #Calculamos metricas con la funcion previa
    matriz, accuracy, recall, precision, f1=metricas(clases_reales,clases_predichas)

    #Graficamos
    plt.figure(figsize=(3,3))
    matriz=pd.DataFrame(matriz,columns=['0: Mercante', '1: Otro'])
    plt.matshow(matriz, cmap="Blues", vmin=0, vmax=10, fignum=1)
    plt.title("Reales")
    plt.ylabel("Predichas")
    plt.xticks(range(len(matriz.columns)), matriz.columns, rotation=45)
    plt.yticks(range(len(matriz.columns)), matriz.columns)
    etiquetas = (("Verdaderos\nnegativos", "Falsos\npositivos"),
                 ("Falsos\nnegativos", "Verdaderos\npositivos"))
    for i in range(len(matriz.columns)):
        for j in range(len(matriz.columns)):
            plt.text(i, j + 0.14, str(matriz.iloc[i, j]),
                     fontsize=30, ha="center", va="center")
            plt.text(i, j - 0.25, etiquetas[i][j],
                     fontsize=11.5, ha="center", va="center")           
    plt.text(1.60, -0.30, titulo, fontsize=25, c="red")
    plt.text(2.1, 0.10, "Accuracy: %0.2f" % accuracy, fontsize=20)
    plt.text(2.1, 0.40, "Precision: %0.2f" % precision, fontsize=20)
    plt.text(2.1, 0.70, "Recall: %0.2f" % recall, fontsize=20)
    plt.text(2.1, 1.00, "F1: %0.2f" % f1, fontsize=20)    
    plt.show()
    print("\n")

#print("\n")

#reales=[1,1,0,0,0,0,1,1]
#predichas=[1,1,0,1,0,1,1,1]

#visualizar_metricas(reales,predichas,'Métricas')

# %% [markdown]
# ## Métricas dropout 0.3

# %%
# Obtener las métricas de entrenamiento y validación
train_accuracy = history1.history['accuracy']
val_accuracy = history1.history['val_accuracy']
train_loss = history1.history['loss']
val_loss = history1.history['val_loss']
epochs_range = range(1, len(train_accuracy) + 1)

plt.figure(figsize=(20,6))

# Gráfica de precisión (accuracy)
plt.subplot(1,2,1)
plt.plot(epochs_range, train_accuracy, label='Training Accuracy', color='blue')
plt.plot(epochs_range, val_accuracy, label='Validation Accuracy', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy with 3 Layers and Dropot 0.3')
plt.legend()
plt.grid(True)

plt.subplot(1,2,2)
# Gráfica de pérdida (loss)
plt.plot(epochs_range, train_loss, label='Training Loss', color='blue')
plt.plot(epochs_range, val_loss, label='Validation Loss', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss with 3 Layers and Dropot 0.3')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Métricas dropout 0.5

# %%
# Obtener las métricas de entrenamiento y validación
train_accuracy = history2.history['accuracy']
val_accuracy = history2.history['val_accuracy']
train_loss = history2.history['loss']
val_loss = history2.history['val_loss']
epochs_range = range(1, epochs + 1)

plt.figure(figsize=(20,6))

# Gráfica de precisión (accuracy)
plt.subplot(1,2,1)
plt.plot(epochs_range, train_accuracy, label='Training Accuracy', color='blue')
plt.plot(epochs_range, val_accuracy, label='Validation Accuracy', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy with 3 Layers and Dropot 0.5')
plt.legend()
plt.grid(True)

plt.subplot(1,2,2)
# Gráfica de pérdida (loss)
plt.plot(epochs_range, train_loss, label='Training Loss', color='blue')
plt.plot(epochs_range, val_loss, label='Validation Loss', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss with 3 Layers and Dropot 0.5')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Métricas dropout 0.7

# %%
# Obtener las métricas de entrenamiento y validación
train_accuracy = history3.history['accuracy']
val_accuracy = history3.history['val_accuracy']
train_loss = history3.history['loss']
val_loss = history3.history['val_loss']
epochs_range = range(1, epochs + 1)

plt.figure(figsize=(20,6))

# Gráfica de precisión (accuracy)
plt.subplot(1,2,1)
plt.plot(epochs_range, train_accuracy, label='Training Accuracy', color='blue')
plt.plot(epochs_range, val_accuracy, label='Validation Accuracy', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy with 3 Layers and Dropot 0.7')
plt.legend()
plt.grid(True)

plt.subplot(1,2,2)
# Gráfica de pérdida (loss)
plt.plot(epochs_range, train_loss, label='Training Loss', color='blue')
plt.plot(epochs_range, val_loss, label='Validation Loss', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss with 3 Layers and Dropot 0.7')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Probamos la red

# %%
# Muestra de Etiqueta Mercante:
import matplotlib.pyplot as plt
plt.imshow(plt.imread('prueba/4.jpg'))

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage import color

directorio_imagen_prueba='./prueba/4.jpg'
# Carga la imagen de prueba
imagen_prueba = cv2.imread(directorio_imagen_prueba)
imagen_prueba = cv2.resize(imagen_prueba, (100, 100))

# OpenCV lee las imágenes en formato BGR, pero los modelos de Keras están entrenados con imágenes en formato RGB, por lo que es necesario convertir la imagen de BGR a RGB
imagen_prueba = cv2.cvtColor(imagen_prueba, cv2.COLOR_BGR2RGB)

# Convertir a float32 y normalizar
imagen_prueba = imagen_prueba.astype('float32') / 255.0

# Ajusta las dimensiones de la imagen para que sea compatible con la entrada del modelo
imagen_prueba = np.expand_dims(imagen_prueba, axis=0)

# Obtén las predicciones utilizando el modelo entrenado
predicciones = modelo3.predict(imagen_prueba)

# Las predicciones son un arreglo de probabilidades, conviértelas a una clase
clase_predicha = np.argmax(predicciones[0])

# Obten la clase correspondiente al índice
clase = classes[clase_predicha]

# Obten el porcentaje de confianza para la clase predicha
porcentaje_confianza = predicciones[0][clase_predicha] * 100

# Carga la imagen de nuevo para mostrarla (esta vez en formato RGB para matplotlib)
imagen_prueba = cv2.cvtColor(cv2.imread(directorio_imagen_prueba), cv2.COLOR_BGR2RGB)
imagen_prueba = cv2.resize(imagen_prueba, (100, 100))
imagen_array = np.array(imagen_prueba) # Arreglo de pixeles de la imagen

plt.imshow(imagen_prueba)
plt.title("La imagen es de clase: {} con un porcentaje de confianza de: {:.2f}%".format(clase, porcentaje_confianza))
plt.show()

imagen_prueba1=cv2.resize(imagen_prueba, (30, 30))
imagen_array1=np.array(imagen_prueba1)
# Aproximar los valores de píxeles a la unidad
imagen_pixeles = np.round(color.rgb2gray(imagen_array1) * 255).astype(int)

np.set_printoptions(linewidth=np.inf)
print(f'\nArreglo de pixeles de la imagen:\n {imagen_pixeles}') #Valores entre 0 y 255
# Out:
# 1/1 [==============================] - 0s 195ms/step
# Arreglo de pixeles de la imagen:
#  [[204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204]
#  [204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204]
#  [204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204]
#  [204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204]
#  [204 204 204 204 203 204 204 204 204 204 204 204 204 204 204 204 204 204 168 204 204 204 204 204 204 204 204 204 204 204]
#  [204 204 204 204 152 204 204 204 204 204 204 204 204 204 204 204 204 204  40 204 204 204 204 204 204 204 204 204 204 204]
#  [204 204 204 204 149 204 204 204 204 204 204 204 204 204 204 204 204 204  40 204 204 204 204 204 204 204 204 204 204 204]
#  [204 204 204 204 148 204 204 204 204 204 204 204 204 204 204 204 204 204  40 204 204 204 204 204 204 204 204 204 204 204]
#  [204 204 204 204 147 204 204 204 204 200 204 204 204 204 204 204 204 204  40 204 204 204 204 204 204 204 204 204 204 204]
#  [204 204 204   5   5  77 204 204 204 199 204 204 204 204 204 204 204 204  40 204 204 204 204 204 204 204 204 204 204 204]
#  [204 204 204   6   5 172 204 204 204 199 204 204 204 204 204 204 204 204  40 204 204 204 204 204 204 204 204 204 204 204]
#  [204 204 204  72 180 174 204 204 204 199 204 204 204 204 204 204 204 204  40 204 204 204 204 204 204 204 204 204 203 205]
#  [204 204 204   7   5 162 204 204 204 199 204 204 204 204 204 204 204 204  40 204 204 204 204 204 175   5   5   5   6 205]
#  [204 204 145   6   4 125 204 204 204 200 205 204 204 204 204 204 204 204  39 204 204 204 204 204  32   4   4   4   5 204]
#  [204 204   5   5   5 171 204 204 204 172 204 204 204 204 204 204 204 204  34 204 204 204 204 204   7   4   4   4  20 204]
#  [204 204  71   4  56 171 204 204 204 171 204 204 204 204 204 204 204 204  33 204 204 204 204 203   3   4   4   4 106 204]
#  [204 205   5   4   5 172 204 204 204  67  81 204 204 204 204 204 204 101  15 142 204 204 204 200   4   4   4   4 119 204]
#  [204  13   4   4   4  11  12  12  12   4   4  12  12  12  12  12  12   5   4   8  12  12  12   5   4   4   4   4 201 204]
#  [204   5   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4 205 204]
#  [204   5   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4 205 204]
#  [204   3   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   7 204 204]
#  [204  33   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4  36 204 204]
#  [204 132   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4  43 204 204]
#  [204 204   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4   4 201 204 204]
#  [204 204   9   7   7   7   7   7   7   7   7   7   7   7   7   7   7   7   7   7   7   7   7   7   7   7   7 203 204 204]
#  [204 204 167 158 158 158 158 158 158 158 158 158 158 158 158 158 158 158 158 158 158 158 158 158 158 158 158 204 204 204]
#  [204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204]
#  [204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204]
#  [204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204]
#  [204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204 204]]

# %%
def prueba_modelo(modelo, directorio, altura, longitud, classes):
    resultados = []
    for archivo in os.listdir(directorio):
        ruta_imagen = os.path.join(directorio, archivo)
        # Carga la imagen de prueba
        imagen_prueba = cv2.imread(ruta_imagen)
        imagen_prueba = cv2.resize(imagen_prueba, (altura, longitud))

        # OpenCV lee las imágenes en formato BGR, pero los modelos de Keras están entrenados con imágenes en formato RGB, por lo que es necesario convertir la imagen de BGR a RGB
        imagen_prueba = cv2.cvtColor(imagen_prueba, cv2.COLOR_BGR2RGB)

        # Convertir a float32 y normalizar
        imagen_prueba = imagen_prueba.astype('float32') / 255.0

        # Ajusta las dimensiones de la imagen para que sea compatible con la entrada del modelo
        imagen_prueba = np.expand_dims(imagen_prueba, axis=0)

        # Obtén las predicciones utilizando el modelo entrenado
        predicciones = modelo.predict(imagen_prueba)

        # Las predicciones son un arreglo de probabilidades, conviértelas a una clase
        clase_predicha = np.argmax(predicciones[0])

        # Obten la clase correspondiente al índice
        clase = classes[clase_predicha]

        resultados.append((archivo, clase))

    return resultados

# Uso de la función prueba_modelo
directorio_imagenes = './prueba'
resultados = prueba_modelo(modelo, directorio_imagenes, altura, longitud, classes)

# Mostrar resultados
for archivo, clase in resultados:
    print(f"La imagen {archivo} es de clase: {clase}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 33
#      31 # Uso de la función prueba_modelo
#      32 directorio_imagenes = './prueba'
# ---> 33 resultados = prueba_modelo(modelo, directorio_imagenes, altura, longitud, classes)
#      35 # Mostrar resultados
#      36 for archivo, clase in resultados:
#
# NameError: name 'modelo' is not defined
