# %% [markdown]
# # Código Clasificación buques mercantes utilizando CNN.
# Cristóbal Balmelli

# %% [markdown]
# #### Modificaciones Eduardo Carrasco
# Descripción Máquina en la que se está corriendo

# %%
### Conocer version de paquetes y Hardware en uso
#------------------------------------------------------
#------------------------------------------------------
import sys
import tensorflow.keras
import keras
import pandas as pd
import sklearn as sk
import tensorflow as tf
import numpy as np
import platform

print(f"Plataforma (Software-Hardware): {platform.platform()}")
print(f"Versión de Python {sys.version}")
print(f"Versión de TensorFlow: {tf.__version__}")
print(f"versión de Pandas {pd.__version__}")
print(f"versión de Numpy {np.__version__}")
print(f"versión de Keras {keras.__version__}")
print(f"Versión de Scikit-Learn {sk.__version__}")
gpu = len(tf.config.list_physical_devices('GPU'))>0
print("GPU está", "Disponible" if gpu else "No Disponible")
#---------------------------------------------------------
# Out:
# Plataforma (Software-Hardware): macOS-13.5-arm64-arm-64bit
# Versión de Python 3.11.4 | packaged by conda-forge | (main, Jun 10 2023, 18:08:41) [Clang 15.0.7 ]
# Versión de TensorFlow: 2.13.0
# versión de Pandas 2.0.3
# versión de Numpy 1.24.3
# versión de Keras 2.13.1
# Versión de Scikit-Learn 1.3.0
# GPU está Disponible

# %% [markdown]
# ## Cargamos las librerias necesarias

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import keras
from keras.utils import to_categorical
from keras.models import Sequential,Model
from tensorflow.keras.layers import Input
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Convolution2D, MaxPooling2D
from tensorflow.keras.activations import relu
from PIL import Image
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## Cargamos las imagenes

# %%
import os
import cv2
import numpy as np
from PIL import Image

altura, longitud = 100, 100

def cargar_y_redimensionar_imagenes(ruta):
    imagenes_redimensionadas = []
    for archivo in os.listdir(ruta):
        archivo_ruta = os.path.join(ruta, archivo)
        # Verificamos si el archivo es una imagen válida antes de abrirlo con OpenCV
        imagen = cv2.imread(archivo_ruta)
        if imagen is not None and len(imagen.shape) == 3 and imagen.shape[2] == 3:
            imagen = cv2.resize(imagen, (altura, longitud))
            imagenes_redimensionadas.append(imagen)
    return imagenes_redimensionadas

# Rutas de los directorios de imágenes
ruta_mercantes = './datos/mercantes'
ruta_otros = './datos/otros'

# Cargar y redimensionar imágenes de mercantes y otros
imagenes_mercantes = cargar_y_redimensionar_imagenes(ruta_mercantes)
imagenes_otros = cargar_y_redimensionar_imagenes(ruta_otros)

# Obtener la cantidad de imágenes en cada directorio
dircount = [len(imagenes_mercantes), len(imagenes_otros)]

print('Imagenes en cada directorio:', dircount)
print('Suma Total de imagenes en subdirectorios:', sum(dircount))
# Out:
# Imagenes en cada directorio: [56, 35]
# Suma Total de imagenes en subdirectorios: 91

# %% [markdown]
# ## Crear etiquetas y clases
#
# **Creamos los labels con valor 1 para mercante y 0 para otros**

# %%
# Crear una lista de etiquetas (0 para mercantes, 1 para otros)
etiquetas_mercantes = [0] * len(imagenes_mercantes)
etiquetas_otros = [1] * len(imagenes_otros)

# Combinar las imágenes y etiquetas en un solo conjunto de datos
imagenes = imagenes_mercantes + imagenes_otros
etiquetas = etiquetas_mercantes + etiquetas_otros

# %% [markdown]
# ## Muestra de Imágenes:

# %%
# Muestra de Etiqueta Mercante:
import matplotlib.pyplot as plt
plt.imshow(plt.imread('datos/mercantes/10.jpg'))

# %%
# Muestra de Etiqueta Otros:
import matplotlib.pyplot as plt
plt.imshow(plt.imread('datos/otros/11.jpg'))

# %% [markdown]
# ## Creamos sets de Entrenamiento y Test

# %%
# Convertir a arreglos NumPy
X = np.array(imagenes, dtype=np.uint8)
y = np.array(etiquetas)

# Dividir los datos en conjuntos de entrenamiento y validación (80% para entrenamiento, 20% para validación)
train_X, valid_X, train_label, valid_label = train_test_split(X, y, test_size=0.2, random_state=218) #num de cadete

train_X = train_X / 255.
valid_X = valid_X / 255.

# Find the unique numbers from the train labels
classes = np.unique(train_label)
nClasses = len(classes)
print('Total number of outputs:', nClasses)
print('Output classes:', classes)

train_label_one_hot = to_categorical(train_label, num_classes=nClasses)
valid_label_one_hot = to_categorical(valid_label, num_classes=nClasses)
# Out:
# Total number of outputs: 2
# Output classes: [0 1]

# %% [markdown]
# ## Data augmentation

# %%
# Configurar las transformaciones de data augmentation
data_augmentation = ImageDataGenerator(
    rotation_range=20,         # Rango de rotación aleatoria (en grados)
    width_shift_range=0.2,     # Rango de traslación horizontal aleatoria (como fracción del ancho total)
    height_shift_range=0.2,    # Rango de traslación vertical aleatoria (como fracción del alto total)
    shear_range=0.2,           # Rango de cizallamiento (shear) aleatorio
    zoom_range=0.2,            # Rango de zoom aleatorio
    horizontal_flip=True,      # Volteo horizontal aleatorio
    fill_mode='nearest'        # Modo de rellenado para las transformaciones
)

# %% [markdown]
# ## Creamos la red neuronal

# %% [markdown]
# ### 1RA PROPUESTA

# %%
INIT_LR = 0.0001#1e-3 

filtrosConv1=32 #despoues de la 1ra conv, la imagen va a tener prof de 32
filtrosConv2=64 #despjes de la 2da, tendra 64
filtrosConv3=128
tamano_filtro1=(5,5)
tamano_filtro2=(3,3)
tamano_pool=(2,2)

modelo = Sequential(name='modelo_edu')
modelo.add(Convolution2D(filtrosConv1, tamano_filtro1, padding='same', input_shape=(altura,longitud,3),activation='relu'))
modelo.add(MaxPooling2D(pool_size=tamano_pool))

#segunda capa de convolucion (), seguida de una capa de max pooling
modelo.add(Convolution2D(filtrosConv2, tamano_filtro2, padding='same', activation='relu'))
modelo.add(MaxPooling2D(pool_size=tamano_pool))

#tercera capa de convolucion
modelo.add(Convolution2D(filtrosConv3, tamano_filtro2, padding='same', activation='relu'))

#capa que aplana la imagen (1D)
modelo.add(Flatten())

#capa normal, de 256 neuronas
modelo.add(Dense(256,activation='relu'))

#capa que apagara el 50% de las neuronas en cada paso, para evitar el overfitting
modelo.add(Dropout(0.5))

#ultima capa, que son 2 neuronas (una por clase) donde dara % prob da cada clase
modelo.add(Dense(nClasses,activation='softmax'))

#con Graphviz se puede hacer un diagrama de flujo para ver la logica del sistema
modelo.summary()

modelo.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adam(learning_rate=INIT_LR),metrics=['accuracy'])
# Out:
# Model: "modelo_edu"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 100, 100, 32)      2432
#
#  max_pooling2d (MaxPooling2  (None, 50, 50, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 50, 50, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 25, 25, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 25, 25, 128)       73856
#
#  flatten (Flatten)           (None, 80000)             0
#
#  dense (Dense)               (None, 256)               20480256
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 20575554 (78.49 MB)
# Trainable params: 20575554 (78.49 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 2023-07-29 18:37:41.797182: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2023-07-29 18:37:41.797212: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2023-07-29 18:37:41.797218: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2023-07-29 18:37:41.797501: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-07-29 18:37:41.797529: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.

# %% [markdown]
# **Cristóbal, Aprender esta tabla que explica como se calcula todo en el modelo anterior:**
#
# | Layer (type) | Param Definition | Input Shape | Output Shape | Param Calculation (Formula and Values) | Param # |
# | --- | --- | --- | --- | --- | --- |
# | Conv2D | Kernel: (3,3) | (100, 100, 3) | (100, 100, 32) | (altura x ancho x canales_entrada + 1 bias) x filtros = (3x3x3+1) x 32 | 896 |
# | MaxPooling2D | Tamaño del Pool: (2,2) | (100, 100, 32) | (50, 50, 32) | 0 (No hay parámetros en las capas de pooling) | 0 |
# | Conv2D | Kernel: (2,2) | (50, 50, 32) | (50, 50, 64) | (altura x ancho x canales_entrada + 1 bias) x filtros = (2x2x32+1) x 64 | 8,256 |
# | MaxPooling2D | Tamaño del Pool: (2,2) | (50, 50, 64) | (25, 25, 64) | 0 (No hay parámetros en las capas de pooling) | 0 |
# | Flatten | N/A | (25, 25, 64) | (40,000) | 0 (No hay parámetros en las capas flatten) | 0 |
# | Dense | Unidades: 256 | (40,000) | (256) | (entrada x salida + 1 bias por unidad salida) = (40,000 x 256) + 256 | 10,240,256 |
# | Dropout | Rate: 0.5 | (256) | (256) | 0 (No hay parámetros en las capas de dropout) | 0 |
# | Dense | Unidades: 2 | (256) | (2) | (entrada x salida + 1 bias por unidad salida) = (256 x 2) + 2 | 514 |

# %% [markdown]
# ## Entrenamos la red
# Con los datos de data augmentation

# %%
epochs = 200
batch_size = 32

# Crear el generador de datos para el conjunto de entrenamiento con data augmentation
train_data_generator = data_augmentation.flow(train_X, train_label_one_hot, batch_size=batch_size)

## Modifica el train_x para incluir las imagenes del train_data_generator
history=modelo.fit(train_data_generator, steps_per_epoch=len(train_X) // batch_size, epochs=epochs, verbose=1, validation_data=(valid_X, valid_label_one_hot))
# history=modelo.fit(train_X, train_label_one_hot, batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(valid_X, valid_label_one_hot))

# guardamos la red, para reutilizarla en el futuro, sin tener que volver a entrenar
dir='./modelo/'

if not os.path.exists(dir):
    os.mkdir(dir)
modelo.save('./modelo/modelo.h5')
modelo.save_weights('./modelo/pesos.h5')
# Out:
# Epoch 1/200
# 2023-07-29 18:37:49.563324: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2/2 [==============================] - 1s 281ms/step - loss: 0.7422 - accuracy: 0.5312 - val_loss: 0.7484 - val_accuracy: 0.6316
# Epoch 2/200
# 2023-07-29 18:37:49.958991: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2/2 [==============================] - 0s 75ms/step - loss: 0.7089 - accuracy: 0.6250 - val_loss: 0.6657 - val_accuracy: 0.6316
# Epoch 3/200
# 2/2 [==============================] - 0s 53ms/step - loss: 0.6548 - accuracy: 0.6250 - val_loss: 0.7157 - val_accuracy: 0.3684
# Epoch 4/200
# 2/2 [==============================] - 0s 79ms/step - loss: 0.7087 - accuracy: 0.5500 - val_loss: 0.7365 - val_accuracy: 0.3684
# Epoch 5/200
# 2/2 [==============================] - 0s 73ms/step - loss: 0.7293 - accuracy: 0.6000 - val_loss: 0.6979 - val_accuracy: 0.4737
# Epoch 6/200
# 2/2 [==============================] - 0s 77ms/step - loss: 0.7158 - accuracy: 0.4500 - val_loss: 0.6685 - val_accuracy: 0.6316
# Epoch 7/200
# 2/2 [==============================] - 0s 74ms/step - loss: 0.7220 - accuracy: 0.4500 - val_loss: 0.6575 - val_accuracy: 0.6316
# Epoch 8/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.6998 - accuracy: 0.5750 - val_loss: 0.6712 - val_accuracy: 0.6316
# Epoch 9/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.6794 - accuracy: 0.5469 - val_loss: 0.6946 - val_accuracy: 0.6316
# Epoch 10/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.7184 - accuracy: 0.5500 - val_loss: 0.6994 - val_accuracy: 0.6316
# Epoch 11/200
# 2/2 [==============================] - 0s 70ms/step - loss: 0.7497 - accuracy: 0.5781 - val_loss: 0.6851 - val_accuracy: 0.6316
# Epoch 12/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.7097 - accuracy: 0.6000 - val_loss: 0.6735 - val_accuracy: 0.6316
# Epoch 13/200
# 2/2 [==============================] - 0s 52ms/step - loss: 0.6860 - accuracy: 0.6250 - val_loss: 0.6639 - val_accuracy: 0.6316
# Epoch 14/200
# 2/2 [==============================] - 0s 52ms/step - loss: 0.6491 - accuracy: 0.6000 - val_loss: 0.6559 - val_accuracy: 0.6316
# Epoch 15/200
# 2/2 [==============================] - 0s 72ms/step - loss: 0.6837 - accuracy: 0.5938 - val_loss: 0.6503 - val_accuracy: 0.6316
# Epoch 16/200
# 2/2 [==============================] - 0s 74ms/step - loss: 0.6735 - accuracy: 0.5500 - val_loss: 0.6476 - val_accuracy: 0.6316
# Epoch 17/200
# 2/2 [==============================] - 0s 80ms/step - loss: 0.6857 - accuracy: 0.5781 - val_loss: 0.6457 - val_accuracy: 0.6316
# Epoch 18/200
# 2/2 [==============================] - 0s 72ms/step - loss: 0.6838 - accuracy: 0.5938 - val_loss: 0.6438 - val_accuracy: 0.6316
# Epoch 19/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6683 - accuracy: 0.6500 - val_loss: 0.6415 - val_accuracy: 0.6316
# Epoch 20/200
# 2/2 [==============================] - 0s 72ms/step - loss: 0.6582 - accuracy: 0.5781 - val_loss: 0.6401 - val_accuracy: 0.6316
# Epoch 21/200
# 2/2 [==============================] - 0s 52ms/step - loss: 0.7068 - accuracy: 0.5000 - val_loss: 0.6370 - val_accuracy: 0.6316
# Epoch 22/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.6451 - accuracy: 0.6406 - val_loss: 0.6339 - val_accuracy: 0.6316
# Epoch 23/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6780 - accuracy: 0.5750 - val_loss: 0.6312 - val_accuracy: 0.6316
# Epoch 24/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.6565 - accuracy: 0.6250 - val_loss: 0.6291 - val_accuracy: 0.6316
# Epoch 25/200
# 2/2 [==============================] - 0s 88ms/step - loss: 0.6553 - accuracy: 0.6500 - val_loss: 0.6275 - val_accuracy: 0.6316
# Epoch 26/200
# 2/2 [==============================] - 0s 76ms/step - loss: 0.6573 - accuracy: 0.5750 - val_loss: 0.6276 - val_accuracy: 0.6316
# Epoch 27/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.6588 - accuracy: 0.5781 - val_loss: 0.6289 - val_accuracy: 0.6316
# Epoch 28/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.6564 - accuracy: 0.5938 - val_loss: 0.6285 - val_accuracy: 0.6316
# Epoch 29/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6443 - accuracy: 0.5750 - val_loss: 0.6237 - val_accuracy: 0.6316
# Epoch 30/200
# 2/2 [==============================] - 0s 83ms/step - loss: 0.6553 - accuracy: 0.5500 - val_loss: 0.6194 - val_accuracy: 0.6316
# Epoch 31/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6608 - accuracy: 0.5750 - val_loss: 0.6175 - val_accuracy: 0.6316
# Epoch 32/200
# 2/2 [==============================] - 0s 72ms/step - loss: 0.6541 - accuracy: 0.5781 - val_loss: 0.6173 - val_accuracy: 0.6316
# Epoch 33/200
# 2/2 [==============================] - 0s 72ms/step - loss: 0.6501 - accuracy: 0.5938 - val_loss: 0.6190 - val_accuracy: 0.6316
# Epoch 34/200
# 2/2 [==============================] - 0s 72ms/step - loss: 0.6508 - accuracy: 0.6094 - val_loss: 0.6174 - val_accuracy: 0.6316
# Epoch 35/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6217 - accuracy: 0.6000 - val_loss: 0.6181 - val_accuracy: 0.6316
# Epoch 36/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.6202 - accuracy: 0.6250 - val_loss: 0.6262 - val_accuracy: 0.6316
# Epoch 37/200
# 2/2 [==============================] - 0s 52ms/step - loss: 0.6986 - accuracy: 0.5500 - val_loss: 0.6222 - val_accuracy: 0.6316
# Epoch 38/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.6613 - accuracy: 0.5250 - val_loss: 0.6050 - val_accuracy: 0.6316
# Epoch 39/200
# 2/2 [==============================] - 0s 72ms/step - loss: 0.6415 - accuracy: 0.6500 - val_loss: 0.5893 - val_accuracy: 0.6316
# Epoch 40/200
# 2/2 [==============================] - 0s 78ms/step - loss: 0.5988 - accuracy: 0.7250 - val_loss: 0.5881 - val_accuracy: 0.6316
# Epoch 41/200
# 2/2 [==============================] - 0s 72ms/step - loss: 0.5841 - accuracy: 0.7000 - val_loss: 0.5929 - val_accuracy: 0.6316
# Epoch 42/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6050 - accuracy: 0.6500 - val_loss: 0.6152 - val_accuracy: 0.6316
# Epoch 43/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.6488 - accuracy: 0.5750 - val_loss: 0.6658 - val_accuracy: 0.6316
# Epoch 44/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.6917 - accuracy: 0.5500 - val_loss: 0.6823 - val_accuracy: 0.6316
# Epoch 45/200
# 2/2 [==============================] - 0s 77ms/step - loss: 0.6003 - accuracy: 0.6500 - val_loss: 0.6305 - val_accuracy: 0.6316
# Epoch 46/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.6318 - accuracy: 0.5938 - val_loss: 0.5989 - val_accuracy: 0.6316
# Epoch 47/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6062 - accuracy: 0.6250 - val_loss: 0.5849 - val_accuracy: 0.6316
# Epoch 48/200
# 2/2 [==============================] - 0s 72ms/step - loss: 0.6295 - accuracy: 0.6406 - val_loss: 0.5750 - val_accuracy: 0.6316
# Epoch 49/200
# 2/2 [==============================] - 0s 52ms/step - loss: 0.6132 - accuracy: 0.6250 - val_loss: 0.5715 - val_accuracy: 0.6316
# Epoch 50/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.6268 - accuracy: 0.5938 - val_loss: 0.5700 - val_accuracy: 0.6316
# Epoch 51/200
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5916 - accuracy: 0.6875 - val_loss: 0.5747 - val_accuracy: 0.6316
# Epoch 52/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6065 - accuracy: 0.6250 - val_loss: 0.5741 - val_accuracy: 0.6316
# Epoch 53/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.5582 - accuracy: 0.6750 - val_loss: 0.5770 - val_accuracy: 0.6316
# Epoch 54/200
# 2/2 [==============================] - 0s 72ms/step - loss: 0.6353 - accuracy: 0.5750 - val_loss: 0.5822 - val_accuracy: 0.6316
# Epoch 55/200
# 2/2 [==============================] - 0s 73ms/step - loss: 0.6255 - accuracy: 0.6094 - val_loss: 0.5699 - val_accuracy: 0.6316
# Epoch 56/200
# 2/2 [==============================] - 0s 69ms/step - loss: 0.6103 - accuracy: 0.6094 - val_loss: 0.5583 - val_accuracy: 0.6316
# Epoch 57/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.5942 - accuracy: 0.6719 - val_loss: 0.5537 - val_accuracy: 0.6316
# Epoch 58/200
# 2/2 [==============================] - 0s 52ms/step - loss: 0.5418 - accuracy: 0.7000 - val_loss: 0.5450 - val_accuracy: 0.6316
# Epoch 59/200
# 2/2 [==============================] - 0s 76ms/step - loss: 0.5850 - accuracy: 0.7500 - val_loss: 0.5309 - val_accuracy: 0.5789
# Epoch 60/200
# 2/2 [==============================] - 0s 74ms/step - loss: 0.5928 - accuracy: 0.7250 - val_loss: 0.5343 - val_accuracy: 0.5789
# Epoch 61/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.5962 - accuracy: 0.6500 - val_loss: 0.5437 - val_accuracy: 0.5789
# Epoch 62/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.5863 - accuracy: 0.6406 - val_loss: 0.5314 - val_accuracy: 0.5789
# Epoch 63/200
# 2/2 [==============================] - 0s 76ms/step - loss: 0.5906 - accuracy: 0.7000 - val_loss: 0.5040 - val_accuracy: 0.6316
# Epoch 64/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.5685 - accuracy: 0.7500 - val_loss: 0.5236 - val_accuracy: 0.6316
# Epoch 65/200
# 2/2 [==============================] - 0s 73ms/step - loss: 0.5198 - accuracy: 0.7250 - val_loss: 0.5650 - val_accuracy: 0.5789
# Epoch 66/200
# 2/2 [==============================] - 0s 77ms/step - loss: 0.5815 - accuracy: 0.6250 - val_loss: 0.4797 - val_accuracy: 0.6316
# Epoch 67/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.5775 - accuracy: 0.7969 - val_loss: 0.4583 - val_accuracy: 0.6842
# Epoch 68/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.5212 - accuracy: 0.8500 - val_loss: 0.4560 - val_accuracy: 0.6842
# Epoch 69/200
# 2/2 [==============================] - 0s 84ms/step - loss: 0.5604 - accuracy: 0.7031 - val_loss: 0.4912 - val_accuracy: 0.6316
# Epoch 70/200
# 2/2 [==============================] - 0s 52ms/step - loss: 0.5487 - accuracy: 0.7750 - val_loss: 0.5546 - val_accuracy: 0.6316
# Epoch 71/200
# 2/2 [==============================] - 0s 77ms/step - loss: 0.5776 - accuracy: 0.7000 - val_loss: 0.5951 - val_accuracy: 0.6316
# Epoch 72/200
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5059 - accuracy: 0.7188 - val_loss: 0.4810 - val_accuracy: 0.6316
# Epoch 73/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.4476 - accuracy: 0.8250 - val_loss: 0.4225 - val_accuracy: 0.6842
# Epoch 74/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.5337 - accuracy: 0.8281 - val_loss: 0.4071 - val_accuracy: 0.7368
# Epoch 75/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.4689 - accuracy: 0.8750 - val_loss: 0.4500 - val_accuracy: 0.6842
# Epoch 76/200
# 2/2 [==============================] - 0s 65ms/step - loss: 0.5393 - accuracy: 0.6250 - val_loss: 0.5218 - val_accuracy: 0.6316
# Epoch 77/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.4526 - accuracy: 0.8281 - val_loss: 0.5518 - val_accuracy: 0.6316
# Epoch 78/200
# 2/2 [==============================] - 0s 73ms/step - loss: 0.5916 - accuracy: 0.6750 - val_loss: 0.4071 - val_accuracy: 0.6842
# Epoch 79/200
# 2/2 [==============================] - 0s 52ms/step - loss: 0.5299 - accuracy: 0.7750 - val_loss: 0.3820 - val_accuracy: 0.8421
# Epoch 80/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.5729 - accuracy: 0.7250 - val_loss: 0.4052 - val_accuracy: 0.6842
# Epoch 81/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.5081 - accuracy: 0.7750 - val_loss: 0.5119 - val_accuracy: 0.6842
# Epoch 82/200
# 2/2 [==============================] - 0s 77ms/step - loss: 0.5261 - accuracy: 0.7250 - val_loss: 0.6880 - val_accuracy: 0.6316
# Epoch 83/200
# 2/2 [==============================] - 0s 72ms/step - loss: 0.4483 - accuracy: 0.8500 - val_loss: 0.5582 - val_accuracy: 0.6316
# Epoch 84/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.4143 - accuracy: 0.8750 - val_loss: 0.4689 - val_accuracy: 0.6842
# Epoch 85/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.4723 - accuracy: 0.7812 - val_loss: 0.4471 - val_accuracy: 0.6842
# Epoch 86/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.4402 - accuracy: 0.8250 - val_loss: 0.4485 - val_accuracy: 0.6842
# Epoch 87/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.3238 - accuracy: 0.9500 - val_loss: 0.5054 - val_accuracy: 0.6842
# Epoch 88/200
# 2/2 [==============================] - 0s 69ms/step - loss: 0.4235 - accuracy: 0.7812 - val_loss: 0.5491 - val_accuracy: 0.6842
# Epoch 89/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.4590 - accuracy: 0.7250 - val_loss: 0.5006 - val_accuracy: 0.6842
# Epoch 90/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.4409 - accuracy: 0.8750 - val_loss: 0.4967 - val_accuracy: 0.6842
# Epoch 91/200
# 2/2 [==============================] - 0s 52ms/step - loss: 0.4344 - accuracy: 0.7750 - val_loss: 0.4278 - val_accuracy: 0.7368
# Epoch 92/200
# 2/2 [==============================] - 0s 77ms/step - loss: 0.3886 - accuracy: 0.8500 - val_loss: 0.4357 - val_accuracy: 0.7368
# Epoch 93/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.3704 - accuracy: 0.8500 - val_loss: 0.4814 - val_accuracy: 0.6842
# Epoch 94/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.3860 - accuracy: 0.8594 - val_loss: 0.4310 - val_accuracy: 0.7368
# Epoch 95/200
# 2/2 [==============================] - 0s 73ms/step - loss: 0.4469 - accuracy: 0.8000 - val_loss: 0.4954 - val_accuracy: 0.6842
# Epoch 96/200
# 2/2 [==============================] - 0s 76ms/step - loss: 0.4781 - accuracy: 0.7750 - val_loss: 0.3926 - val_accuracy: 0.7368
# Epoch 97/200
# 2/2 [==============================] - 0s 73ms/step - loss: 0.4415 - accuracy: 0.8500 - val_loss: 0.3338 - val_accuracy: 0.8421
# Epoch 98/200
# 2/2 [==============================] - 0s 70ms/step - loss: 0.3777 - accuracy: 0.8438 - val_loss: 0.3967 - val_accuracy: 0.7368
# Epoch 99/200
# 2/2 [==============================] - 0s 70ms/step - loss: 0.4030 - accuracy: 0.8125 - val_loss: 0.3833 - val_accuracy: 0.7368
# Epoch 100/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.3753 - accuracy: 0.8000 - val_loss: 0.4732 - val_accuracy: 0.6842
# Epoch 101/200
# 2/2 [==============================] - 0s 70ms/step - loss: 0.4478 - accuracy: 0.7500 - val_loss: 0.4134 - val_accuracy: 0.7368
# Epoch 102/200
# 2/2 [==============================] - 0s 70ms/step - loss: 0.3577 - accuracy: 0.9062 - val_loss: 0.4019 - val_accuracy: 0.7368
# Epoch 103/200
# 2/2 [==============================] - 0s 77ms/step - loss: 0.3895 - accuracy: 0.8500 - val_loss: 0.3681 - val_accuracy: 0.7368
# Epoch 104/200
# 2/2 [==============================] - 0s 52ms/step - loss: 0.4261 - accuracy: 0.8250 - val_loss: 0.5431 - val_accuracy: 0.6842
# Epoch 105/200
# 2/2 [==============================] - 0s 73ms/step - loss: 0.4445 - accuracy: 0.8000 - val_loss: 0.4023 - val_accuracy: 0.7368
# Epoch 106/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.3635 - accuracy: 0.8750 - val_loss: 0.2867 - val_accuracy: 0.8421
# Epoch 107/200
# 2/2 [==============================] - 0s 76ms/step - loss: 0.5189 - accuracy: 0.7500 - val_loss: 0.2632 - val_accuracy: 0.8947
# Epoch 108/200
# 2/2 [==============================] - 0s 70ms/step - loss: 0.4420 - accuracy: 0.8125 - val_loss: 0.4143 - val_accuracy: 0.7895
# Epoch 109/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.3354 - accuracy: 0.8906 - val_loss: 0.6300 - val_accuracy: 0.6842
# Epoch 110/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.3906 - accuracy: 0.8438 - val_loss: 0.4459 - val_accuracy: 0.7368
# Epoch 111/200
# 2/2 [==============================] - 0s 55ms/step - loss: 0.3564 - accuracy: 0.8250 - val_loss: 0.3114 - val_accuracy: 0.7368
# Epoch 112/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.4433 - accuracy: 0.8250 - val_loss: 0.2873 - val_accuracy: 0.8421
# Epoch 113/200
# 2/2 [==============================] - 0s 78ms/step - loss: 0.3422 - accuracy: 0.8250 - val_loss: 0.3976 - val_accuracy: 0.7895
# Epoch 114/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.2534 - accuracy: 0.9750 - val_loss: 0.7772 - val_accuracy: 0.6842
# Epoch 115/200
# 2/2 [==============================] - 0s 74ms/step - loss: 0.4909 - accuracy: 0.7000 - val_loss: 0.8725 - val_accuracy: 0.6842
# Epoch 116/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.4672 - accuracy: 0.7750 - val_loss: 0.2958 - val_accuracy: 0.8421
# Epoch 117/200
# 2/2 [==============================] - 0s 78ms/step - loss: 0.4204 - accuracy: 0.8500 - val_loss: 0.2457 - val_accuracy: 0.8947
# Epoch 118/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.5186 - accuracy: 0.7188 - val_loss: 0.2441 - val_accuracy: 0.8947
# Epoch 119/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.5675 - accuracy: 0.6500 - val_loss: 0.2595 - val_accuracy: 0.8421
# Epoch 120/200
# 2/2 [==============================] - 0s 73ms/step - loss: 0.4225 - accuracy: 0.8500 - val_loss: 0.3914 - val_accuracy: 0.7368
# Epoch 121/200
# 2/2 [==============================] - 0s 78ms/step - loss: 0.3278 - accuracy: 0.8750 - val_loss: 0.5746 - val_accuracy: 0.7368
# Epoch 122/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.4751 - accuracy: 0.7500 - val_loss: 0.5274 - val_accuracy: 0.7368
# Epoch 123/200
# 2/2 [==============================] - 0s 70ms/step - loss: 0.3392 - accuracy: 0.9219 - val_loss: 0.3862 - val_accuracy: 0.7895
# Epoch 124/200
# 2/2 [==============================] - 0s 70ms/step - loss: 0.3179 - accuracy: 0.9219 - val_loss: 0.3305 - val_accuracy: 0.7895
# Epoch 125/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.4191 - accuracy: 0.8750 - val_loss: 0.3358 - val_accuracy: 0.7895
# Epoch 126/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.3423 - accuracy: 0.8750 - val_loss: 0.4055 - val_accuracy: 0.7895
# Epoch 127/200
# 2/2 [==============================] - 0s 70ms/step - loss: 0.3305 - accuracy: 0.8281 - val_loss: 0.5424 - val_accuracy: 0.7368
# Epoch 128/200
# 2/2 [==============================] - 0s 76ms/step - loss: 0.3519 - accuracy: 0.8500 - val_loss: 0.4870 - val_accuracy: 0.7895
# Epoch 129/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.3575 - accuracy: 0.8750 - val_loss: 0.4073 - val_accuracy: 0.7895
# Epoch 130/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.3348 - accuracy: 0.8906 - val_loss: 0.3577 - val_accuracy: 0.7895
# Epoch 131/200
# 2/2 [==============================] - 0s 77ms/step - loss: 0.3400 - accuracy: 0.8906 - val_loss: 0.3521 - val_accuracy: 0.7368
# Epoch 132/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.3726 - accuracy: 0.8750 - val_loss: 0.3556 - val_accuracy: 0.7895
# Epoch 133/200
# 2/2 [==============================] - 0s 63ms/step - loss: 0.3378 - accuracy: 0.8500 - val_loss: 0.3672 - val_accuracy: 0.7895
# Epoch 134/200
# 2/2 [==============================] - 0s 76ms/step - loss: 0.2955 - accuracy: 0.9000 - val_loss: 0.4630 - val_accuracy: 0.7895
# Epoch 135/200
# 2/2 [==============================] - 0s 72ms/step - loss: 0.2969 - accuracy: 0.8750 - val_loss: 0.5060 - val_accuracy: 0.7895
# Epoch 136/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.3287 - accuracy: 0.8438 - val_loss: 0.5791 - val_accuracy: 0.7895
# Epoch 137/200
# 2/2 [==============================] - 0s 78ms/step - loss: 0.3754 - accuracy: 0.8750 - val_loss: 0.5188 - val_accuracy: 0.7895
# Epoch 138/200
# 2/2 [==============================] - 0s 53ms/step - loss: 0.3556 - accuracy: 0.9000 - val_loss: 0.3312 - val_accuracy: 0.8421
# Epoch 139/200
# 2/2 [==============================] - 0s 74ms/step - loss: 0.3020 - accuracy: 0.8750 - val_loss: 0.3206 - val_accuracy: 0.8421
# Epoch 140/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.3151 - accuracy: 0.8000 - val_loss: 0.4231 - val_accuracy: 0.7895
# Epoch 141/200
# 2/2 [==============================] - 0s 52ms/step - loss: 0.2795 - accuracy: 0.8500 - val_loss: 0.4570 - val_accuracy: 0.7895
# Epoch 142/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.2683 - accuracy: 0.8750 - val_loss: 0.3838 - val_accuracy: 0.7895
# Epoch 143/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.3801 - accuracy: 0.8438 - val_loss: 0.3747 - val_accuracy: 0.7895
# Epoch 144/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.3058 - accuracy: 0.8750 - val_loss: 0.4531 - val_accuracy: 0.7895
# Epoch 145/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.3093 - accuracy: 0.8594 - val_loss: 0.4168 - val_accuracy: 0.7895
# Epoch 146/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.2961 - accuracy: 0.9000 - val_loss: 0.3952 - val_accuracy: 0.7895
# Epoch 147/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.2645 - accuracy: 0.9531 - val_loss: 0.3930 - val_accuracy: 0.7895
# Epoch 148/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.3351 - accuracy: 0.9000 - val_loss: 0.3040 - val_accuracy: 0.8421
# Epoch 149/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.2785 - accuracy: 0.8750 - val_loss: 0.2879 - val_accuracy: 0.8421
# Epoch 150/200
# 2/2 [==============================] - 0s 79ms/step - loss: 0.4309 - accuracy: 0.8500 - val_loss: 0.4571 - val_accuracy: 0.7895
# Epoch 151/200
# 2/2 [==============================] - 0s 54ms/step - loss: 0.3297 - accuracy: 0.9000 - val_loss: 0.6128 - val_accuracy: 0.7368
# Epoch 152/200
# 2/2 [==============================] - 0s 73ms/step - loss: 0.3287 - accuracy: 0.8594 - val_loss: 0.3299 - val_accuracy: 0.8421
# Epoch 153/200
# 2/2 [==============================] - 0s 52ms/step - loss: 0.3298 - accuracy: 0.8750 - val_loss: 0.3148 - val_accuracy: 0.8421
# Epoch 154/200
# 2/2 [==============================] - 0s 52ms/step - loss: 0.4907 - accuracy: 0.7750 - val_loss: 0.3479 - val_accuracy: 0.7895
# Epoch 155/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.3290 - accuracy: 0.8750 - val_loss: 0.3507 - val_accuracy: 0.7895
# Epoch 156/200
# 2/2 [==============================] - 0s 79ms/step - loss: 0.2570 - accuracy: 0.9250 - val_loss: 0.3410 - val_accuracy: 0.7895
# Epoch 157/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.2738 - accuracy: 0.9219 - val_loss: 0.4253 - val_accuracy: 0.7895
# Epoch 158/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.2764 - accuracy: 0.9375 - val_loss: 0.4978 - val_accuracy: 0.7895
# Epoch 159/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.3705 - accuracy: 0.9000 - val_loss: 0.3911 - val_accuracy: 0.7895
# Epoch 160/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.2278 - accuracy: 0.9531 - val_loss: 0.3472 - val_accuracy: 0.7895
# Epoch 161/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.2720 - accuracy: 0.8750 - val_loss: 0.3290 - val_accuracy: 0.8421
# Epoch 162/200
# 2/2 [==============================] - 0s 74ms/step - loss: 0.2646 - accuracy: 0.9000 - val_loss: 0.3484 - val_accuracy: 0.8421
# Epoch 163/200
# 2/2 [==============================] - 0s 77ms/step - loss: 0.2025 - accuracy: 0.9000 - val_loss: 0.4853 - val_accuracy: 0.7895
# Epoch 164/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.2498 - accuracy: 0.9375 - val_loss: 0.3927 - val_accuracy: 0.7895
# Epoch 165/200
# 2/2 [==============================] - 0s 70ms/step - loss: 0.2837 - accuracy: 0.8750 - val_loss: 0.3083 - val_accuracy: 0.8421
# Epoch 166/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.2647 - accuracy: 0.8750 - val_loss: 0.3051 - val_accuracy: 0.8421
# Epoch 167/200
# 2/2 [==============================] - 0s 78ms/step - loss: 0.2371 - accuracy: 0.8750 - val_loss: 0.3804 - val_accuracy: 0.7895
# Epoch 168/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.2927 - accuracy: 0.9000 - val_loss: 0.4172 - val_accuracy: 0.7895
# Epoch 169/200
# 2/2 [==============================] - 0s 78ms/step - loss: 0.3267 - accuracy: 0.8750 - val_loss: 0.3255 - val_accuracy: 0.8421
# Epoch 170/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.2197 - accuracy: 0.9219 - val_loss: 0.3958 - val_accuracy: 0.7895
# Epoch 171/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.2619 - accuracy: 0.8750 - val_loss: 0.4569 - val_accuracy: 0.7895
# Epoch 172/200
# 2/2 [==============================] - 0s 77ms/step - loss: 0.1899 - accuracy: 0.9250 - val_loss: 0.3788 - val_accuracy: 0.7895
# Epoch 173/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.2910 - accuracy: 0.8500 - val_loss: 0.5150 - val_accuracy: 0.7895
# Epoch 174/200
# 2/2 [==============================] - 0s 77ms/step - loss: 0.2029 - accuracy: 0.9250 - val_loss: 0.3694 - val_accuracy: 0.7895
# Epoch 175/200
# 2/2 [==============================] - 0s 74ms/step - loss: 0.3129 - accuracy: 0.8250 - val_loss: 0.3650 - val_accuracy: 0.7895
# Epoch 176/200
# 2/2 [==============================] - 0s 76ms/step - loss: 0.1831 - accuracy: 0.9250 - val_loss: 0.3215 - val_accuracy: 0.8421
# Epoch 177/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.2887 - accuracy: 0.8500 - val_loss: 0.5023 - val_accuracy: 0.7895
# Epoch 178/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.2589 - accuracy: 0.9250 - val_loss: 0.8488 - val_accuracy: 0.7368
# Epoch 179/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.3023 - accuracy: 0.8750 - val_loss: 0.5105 - val_accuracy: 0.7895
# Epoch 180/200
# 2/2 [==============================] - 0s 76ms/step - loss: 0.3296 - accuracy: 0.8500 - val_loss: 0.1521 - val_accuracy: 0.9474
# Epoch 181/200
# 2/2 [==============================] - 0s 55ms/step - loss: 0.3027 - accuracy: 0.9000 - val_loss: 0.2274 - val_accuracy: 0.8947
# Epoch 182/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.3283 - accuracy: 0.8500 - val_loss: 0.6066 - val_accuracy: 0.7368
# Epoch 183/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.3727 - accuracy: 0.9000 - val_loss: 0.3918 - val_accuracy: 0.7895
# Epoch 184/200
# 2/2 [==============================] - 0s 76ms/step - loss: 0.1733 - accuracy: 0.9750 - val_loss: 0.2899 - val_accuracy: 0.8947
# Epoch 185/200
# 2/2 [==============================] - 0s 72ms/step - loss: 0.2346 - accuracy: 0.9219 - val_loss: 0.3085 - val_accuracy: 0.8947
# Epoch 186/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.2395 - accuracy: 0.9250 - val_loss: 0.4607 - val_accuracy: 0.7895
# Epoch 187/200
# 2/2 [==============================] - 0s 52ms/step - loss: 0.2837 - accuracy: 0.9000 - val_loss: 0.4644 - val_accuracy: 0.7895
# Epoch 188/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.2814 - accuracy: 0.9000 - val_loss: 0.2873 - val_accuracy: 0.8947
# Epoch 189/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.1680 - accuracy: 0.9500 - val_loss: 0.2353 - val_accuracy: 0.8947
# Epoch 190/200
# 2/2 [==============================] - 0s 72ms/step - loss: 0.2776 - accuracy: 0.8906 - val_loss: 0.3075 - val_accuracy: 0.8421
# Epoch 191/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.3638 - accuracy: 0.8250 - val_loss: 0.5041 - val_accuracy: 0.7895
# Epoch 192/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.3579 - accuracy: 0.8500 - val_loss: 0.3902 - val_accuracy: 0.8421
# Epoch 193/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.1378 - accuracy: 0.9250 - val_loss: 0.3770 - val_accuracy: 0.8421
# Epoch 194/200
# 2/2 [==============================] - 0s 70ms/step - loss: 0.2309 - accuracy: 0.9062 - val_loss: 0.3563 - val_accuracy: 0.8421
# Epoch 195/200
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1645 - accuracy: 0.9000 - val_loss: 0.4522 - val_accuracy: 0.7895
# Epoch 196/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.3497 - accuracy: 0.8750 - val_loss: 0.3421 - val_accuracy: 0.8947
# Epoch 197/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.2538 - accuracy: 0.8500 - val_loss: 0.2871 - val_accuracy: 0.8947
# Epoch 198/200
# 2/2 [==============================] - 0s 83ms/step - loss: 0.3032 - accuracy: 0.9000 - val_loss: 0.2607 - val_accuracy: 0.8947
# Epoch 199/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.2771 - accuracy: 0.9250 - val_loss: 0.3380 - val_accuracy: 0.8947
# Epoch 200/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.2237 - accuracy: 0.9000 - val_loss: 0.5999 - val_accuracy: 0.7368
# /Users/educarrascovidal/anaconda3/envs/tensorflow/lib/python3.11/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ## Obtenemos las métricas de entrenamiento y validación, luego graficamos

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

def metricas(clases_reales, clases_predichas):
    matriz_conf=confusion_matrix(clases_reales, clases_predichas)
    accuracy=accuracy_score(clases_reales,clases_predichas)
    precision=precision_score(clases_reales,clases_predichas)
    recall=recall_score(clases_reales,clases_predichas)
    f1=f1_score(clases_reales,clases_predichas)
    return matriz_conf, accuracy, recall, precision, f1

def visualizar_metricas(clases_reales,clases_predichas, titulo):
    #Calculamos metricas con la funcion previa
    matriz, accuracy, recall, precision, f1=metricas(clases_reales,clases_predichas)

    #Graficamos
    plt.figure(figsize=(3,3))
    matriz=pd.DataFrame(matriz,columns=['0: Mercante', '1: Otro'])
    plt.matshow(matriz, cmap="Blues", vmin=0, vmax=10, fignum=1)
    plt.title("Reales")
    plt.ylabel("Predichas")
    plt.xticks(range(len(matriz.columns)), matriz.columns, rotation=45)
    plt.yticks(range(len(matriz.columns)), matriz.columns)
    etiquetas = (("Verdaderos\nnegativos", "Falsos\npositivos"),
                 ("Falsos\nnegativos", "Verdaderos\npositivos"))
    for i in range(len(matriz.columns)):
        for j in range(len(matriz.columns)):
            plt.text(i, j + 0.14, str(matriz.iloc[i, j]),
                     fontsize=30, ha="center", va="center")
            plt.text(i, j - 0.25, etiquetas[i][j],
                     fontsize=11.5, ha="center", va="center")           
    plt.text(1.60, -0.30, titulo, fontsize=25, c="red")
    plt.text(2.1, 0.10, "Accuracy: %0.2f" % accuracy, fontsize=20)
    plt.text(2.1, 0.40, "Precision: %0.2f" % precision, fontsize=20)
    plt.text(2.1, 0.70, "Recall: %0.2f" % recall, fontsize=20)
    plt.text(2.1, 1.00, "F1: %0.2f" % f1, fontsize=20)    
    plt.show()
    print("\n")

print("\n")

reales=[1,1,0,0,0,0,1,1]
predichas=[1,1,0,1,0,1,1,1]

visualizar_metricas(reales,predichas,'Métricas')

# %%
# Obtener las métricas de entrenamiento y validación
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(1, epochs + 1)

# Gráfica de precisión (accuracy)
plt.figure(figsize=(8, 5))
plt.plot(epochs_range, train_accuracy, label='Training Accuracy', color='blue')
plt.plot(epochs_range, val_accuracy, label='Validation Accuracy', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Gráfica de pérdida (loss)
plt.figure(figsize=(8, 5))
plt.plot(epochs_range, train_loss, label='Training Loss', color='blue')
plt.plot(epochs_range, val_loss, label='Validation Loss', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Probamos la red

# %%
# Muestra de Etiqueta Mercante:
import matplotlib.pyplot as plt
plt.imshow(plt.imread('prueba/4.jpg'))

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

directorio_imagen_prueba='./prueba/4.jpg'
# Carga la imagen de prueba
imagen_prueba = cv2.imread(directorio_imagen_prueba)
imagen_prueba = cv2.resize(imagen_prueba, (100, 100))

# OpenCV lee las imágenes en formato BGR, pero los modelos de Keras están entrenados con imágenes en formato RGB, por lo que es necesario convertir la imagen de BGR a RGB
imagen_prueba = cv2.cvtColor(imagen_prueba, cv2.COLOR_BGR2RGB)

# Convertir a float32 y normalizar
imagen_prueba = imagen_prueba.astype('float32') / 255.0

# Ajusta las dimensiones de la imagen para que sea compatible con la entrada del modelo
imagen_prueba = np.expand_dims(imagen_prueba, axis=0)

# Obtén las predicciones utilizando el modelo entrenado
predicciones = modelo.predict(imagen_prueba)

# Las predicciones son un arreglo de probabilidades, conviértelas a una clase
clase_predicha = np.argmax(predicciones[0])

# Obten la clase correspondiente al índice
clase = classes[clase_predicha]

# Obten el porcentaje de confianza para la clase predicha
porcentaje_confianza = predicciones[0][clase_predicha] * 100

# Carga la imagen de nuevo para mostrarla (esta vez en formato RGB para matplotlib)
imagen_prueba = cv2.cvtColor(cv2.imread(directorio_imagen_prueba), cv2.COLOR_BGR2RGB)
imagen_prueba = cv2.resize(imagen_prueba, (100, 100))

plt.imshow(imagen_prueba)
plt.title("La imagen es de clase: {} con un porcentaje de confianza de: {:.2f}%".format(clase, porcentaje_confianza))
plt.show()
# Out:
# 1/1 [==============================] - 0s 80ms/step
# 2023-07-29 18:38:34.562638: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
def prueba_modelo(modelo, directorio, altura, longitud, classes):
    resultados = []
    for archivo in os.listdir(directorio):
        ruta_imagen = os.path.join(directorio, archivo)
        # Carga la imagen de prueba
        imagen_prueba = cv2.imread(ruta_imagen)
        imagen_prueba = cv2.resize(imagen_prueba, (altura, longitud))

        # OpenCV lee las imágenes en formato BGR, pero los modelos de Keras están entrenados con imágenes en formato RGB, por lo que es necesario convertir la imagen de BGR a RGB
        imagen_prueba = cv2.cvtColor(imagen_prueba, cv2.COLOR_BGR2RGB)

        # Convertir a float32 y normalizar
        imagen_prueba = imagen_prueba.astype('float32') / 255.0

        # Ajusta las dimensiones de la imagen para que sea compatible con la entrada del modelo
        imagen_prueba = np.expand_dims(imagen_prueba, axis=0)

        # Obtén las predicciones utilizando el modelo entrenado
        predicciones = modelo.predict(imagen_prueba)

        # Las predicciones son un arreglo de probabilidades, conviértelas a una clase
        clase_predicha = np.argmax(predicciones[0])

        # Obten la clase correspondiente al índice
        clase = classes[clase_predicha]

        resultados.append((archivo, clase))

    return resultados

# Uso de la función prueba_modelo
directorio_imagenes = './prueba'
resultados = prueba_modelo(modelo, directorio_imagenes, altura, longitud, classes)

# Mostrar resultados
for archivo, clase in resultados:
    print(f"La imagen {archivo} es de clase: {clase}")
# Out:
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# La imagen 8.jpg es de clase: 0
# La imagen 4.jpg es de clase: 0
# La imagen 5.jpg es de clase: 0
# La imagen 7.jpg es de clase: 0
# La imagen 6.jpg es de clase: 0
# La imagen 2.png es de clase: 0
# La imagen 3.jpg es de clase: 0
# La imagen 1.jpg es de clase: 0
