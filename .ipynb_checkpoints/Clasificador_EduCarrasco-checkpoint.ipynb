# %% [markdown]
# # Código Clasificación buques mercantes utilizando CNN.
# Cristóbal Balmelli

# %% [markdown]
# #### Modificaciones Eduardo Carrasco
# Descripción Máquina en la que se está corriendo

# %%
### Conocer version de paquetes y Hardware en uso
#------------------------------------------------------
#------------------------------------------------------
import sys
import tensorflow.keras
import pandas as pd
import sklearn as sk
import tensorflow as tf
import platform

print(f"Plataforma (Software-Hardware): {platform.platform()}")
print(f"Versión de Python {sys.version}")
print(f"Versión de TensorFlow: {tf.__version__}")
print(f"Versión de Keras: {tensorflow.keras.__version__}")
print(f"versión de Pandas {pd.__version__}")
print(f"Versión de Scikit-Learn {sk.__version__}")
gpu = len(tf.config.list_physical_devices('GPU'))>0
print("GPU está", "Disponible" if gpu else "No Disponible")
#---------------------------------------------------------
# Out:
# Plataforma (Software-Hardware): macOS-13.4.1-arm64-i386-64bit
# Versión de Python 3.9.13 | packaged by conda-forge | (main, May 27 2022, 17:01:00)
# [Clang 13.0.1 ]
# Versión de TensorFlow: 2.10.0
# Versión de Keras: 2.10.0
# versión de Pandas 1.5.1
# Versión de Scikit-Learn 1.1.3
# GPU está Disponible

# %% [markdown]
# ## Cargamos las librerias necesarias

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import keras
from keras.utils import to_categorical
from keras.models import Sequential,Model
from tensorflow.keras.layers import Input
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Convolution2D, MaxPooling2D
from tensorflow.keras.activations import relu
from PIL import Image
import imghdr #verificar porque es deprecated
import seaborn as sns #Borrar
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## Cargamos las imagenes

# %%
dirname = os.path.join(os.getcwd(), 'datos')
imgpath = dirname + os.sep 

altura,longitud=100,100 #tamaño pixeles de las imagenes... OJO CON LA CANTIDAD DE PIXELES

directories = []
dircount = []
prevRoot=''
cant=0
 
print("leyendo imagenes de ",imgpath)

for root, dirnames, filenames in os.walk(imgpath):
    for filename in filenames:
        if re.search("\.(jpg|jpeg|png|bmp|tiff)$", filename):
            cant=cant+1
            filepath = os.path.join(root, filename)
            b = "Leyendo..." + str(cant)
            print (b, end="\r")
            if prevRoot !=root:
                print(root, cant)
                prevRoot=root
                directories.append(root)
                dircount.append(cant)
                cant=0
dircount.append(cant)

def cargar_y_redimensionar_imagenes(ruta):
    imagenes_redimensionadas = []
    for archivo in os.listdir(ruta):
        # Verificamos si el archivo es una imagen válida antes de abrirlo
        tipo_imagen = imghdr.what(os.path.join(ruta, archivo))
        if tipo_imagen in ['jpeg', 'png', 'bmp', 'gif']:
            imagen = Image.open(os.path.join(ruta, archivo))
            imagen = imagen.resize((altura, longitud))
            imagen_array = np.array(imagen)
            # Verificamos que la imagen tenga 3 canales (RGB) antes de agregarla
            if len(imagen_array.shape) == 3 and imagen_array.shape[2] == 3:
                imagenes_redimensionadas.append(imagen_array)
    return imagenes_redimensionadas

# Rutas de los directorios de imágenes
ruta_mercantes = './datos/mercantes'
ruta_otros = './datos/otros'

# Cargar y redimensionar imágenes de mercantes y otros
imagenes_mercantes = cargar_y_redimensionar_imagenes(ruta_mercantes)
imagenes_otros = cargar_y_redimensionar_imagenes(ruta_otros)

dircount = dircount[1:]
dircount[0]=dircount[0]+1
print('Directorios leidos:',len(directories))
print("Imagenes en cada directorio", dircount)
print('suma Total de imagenes en subdirs:',sum(dircount))
# Out:
# leyendo imagenes de  /Users/educarrascovidal/Documents/GitHub/ClasificadorSAR/datos/
# /Users/educarrascovidal/Documents/GitHub/ClasificadorSAR/datos/mercantes 1
# /Users/educarrascovidal/Documents/GitHub/ClasificadorSAR/datos/otros 54
# Directorios leidos: 2
# Imagenes en cada directorio [55, 34]
# suma Total de imagenes en subdirs: 89

# %% [markdown]
# ## Crear etiquetas y clases
#
# **Creamos los labels con valor 1 para mercante y 0 para otros**

# %%
# Crear una lista de etiquetas (0 para mercantes, 1 para otros)
etiquetas_mercantes = [1] * len(imagenes_mercantes)
etiquetas_otros = [0] * len(imagenes_otros)

# Combinar las imágenes y etiquetas en un solo conjunto de datos
imagenes = imagenes_mercantes + imagenes_otros
etiquetas = etiquetas_mercantes + etiquetas_otros

# %% [markdown]
# ## Muestra de Imágenes:

# %%
# Muestra de Etiqueta Mercante:
import matplotlib.pyplot as plt
plt.imshow(plt.imread('datos/mercantes/10.jpg'))

# %%
# Muestra de Etiqueta Otros:
import matplotlib.pyplot as plt
plt.imshow(plt.imread('datos/otros/11.jpg'))

# %% [markdown]
# ## Creamos sets de Entrenamiento y Test

# %%
# Convertir a arreglos NumPy
X = np.array(imagenes, dtype=np.uint8)
y = np.array(etiquetas)

# Dividir los datos en conjuntos de entrenamiento y validación (80% para entrenamiento, 20% para validación)
train_X, valid_X, train_label, valid_label = train_test_split(X, y, test_size=0.2, random_state=218) #num de cadete

train_X = train_X / 255.
valid_X = valid_X / 255.

# Find the unique numbers from the train labels
classes = np.unique(train_label)
nClasses = len(classes)
print('Total number of outputs:', nClasses)
print('Output classes:', classes)

train_label_one_hot = to_categorical(train_label, num_classes=nClasses)
valid_label_one_hot = to_categorical(valid_label, num_classes=nClasses)
# Out:
# Total number of outputs: 2
# Output classes: [0 1]

# %% [markdown]
# ## Data augmentation

# %%
# Configurar las transformaciones de data augmentation
data_augmentation = ImageDataGenerator(
    rotation_range=20,         # Rango de rotación aleatoria (en grados)
    width_shift_range=0.2,     # Rango de traslación horizontal aleatoria (como fracción del ancho total)
    height_shift_range=0.2,    # Rango de traslación vertical aleatoria (como fracción del alto total)
    shear_range=0.2,           # Rango de cizallamiento (shear) aleatorio
    zoom_range=0.2,            # Rango de zoom aleatorio
    horizontal_flip=True,      # Volteo horizontal aleatorio
    fill_mode='nearest'        # Modo de rellenado para las transformaciones
)

# %% [markdown]
# ## Creamos la red neuronal

# %% [markdown]
# ### 1RA PROPUESTA

# %%
INIT_LR = 0.0001#1e-3 

filtrosConv1=32 #despoues de la 1ra conv, la imagen va a tener prof de 32
filtrosConv2=64 #despjes de la 2da, tendra 64
filtrosConv3=128
tamano_filtro1=(3,3)
tamano_filtro2=(2,2)
tamano_pool=(2,2)

modelo = Sequential(name='modelo_edu')
modelo.add(Convolution2D(filtrosConv1, tamano_filtro1, padding='same', input_shape=(altura,longitud,3),activation='relu'))
modelo.add(MaxPooling2D(pool_size=tamano_pool))

#segunda capa de convolucion (), seguida de una capa de max pooling
modelo.add(Convolution2D(filtrosConv2, tamano_filtro2, padding='same', activation='relu'))
modelo.add(MaxPooling2D(pool_size=tamano_pool))

#tercera capa de convolucion
modelo.add(Convolution2D(filtrosConv3, tamano_filtro2, padding='same', activation='relu'))

#capa que aplana la imagen (1D)
modelo.add(Flatten())

#capa normal, de 256 neuronas
modelo.add(Dense(256,activation='relu'))

#capa que apagara el 50% de las neuronas en cada paso, para evitar el overfitting
modelo.add(Dropout(0.5))

#ultima capa, que son 2 neuronas (una por clase) donde dara % prob da cada clase
modelo.add(Dense(nClasses,activation='softmax'))

#con Graphviz se puede hacer un diagrama de flujo para ver la logica del sistema
modelo.summary()

modelo.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adam(learning_rate=INIT_LR),metrics=['accuracy'])
# Out:
# Model: "modelo_edu"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 100, 100, 32)      896
#
#  max_pooling2d_2 (MaxPooling  (None, 50, 50, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 50, 50, 64)        8256
#
#  max_pooling2d_3 (MaxPooling  (None, 25, 25, 64)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 25, 25, 128)       32896
#
#  flatten_1 (Flatten)         (None, 80000)             0
#
#  dense_2 (Dense)             (None, 256)               20480256
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 20,522,818
# Trainable params: 20,522,818
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Cristóbal, Aprender esta tabla que explica como se calcula todo en el modelo anterior:**
#
# | Layer (type) | Param Definition | Input Shape | Output Shape | Param Calculation (Formula and Values) | Param # |
# | --- | --- | --- | --- | --- | --- |
# | Conv2D | Kernel: (3,3) | (100, 100, 3) | (100, 100, 32) | (altura x ancho x canales_entrada + 1 bias) x filtros = (3x3x3+1) x 32 | 896 |
# | MaxPooling2D | Tamaño del Pool: (2,2) | (100, 100, 32) | (50, 50, 32) | 0 (No hay parámetros en las capas de pooling) | 0 |
# | Conv2D | Kernel: (2,2) | (50, 50, 32) | (50, 50, 64) | (altura x ancho x canales_entrada + 1 bias) x filtros = (2x2x32+1) x 64 | 8,256 |
# | MaxPooling2D | Tamaño del Pool: (2,2) | (50, 50, 64) | (25, 25, 64) | 0 (No hay parámetros en las capas de pooling) | 0 |
# | Flatten | N/A | (25, 25, 64) | (40,000) | 0 (No hay parámetros en las capas flatten) | 0 |
# | Dense | Unidades: 256 | (40,000) | (256) | (entrada x salida + 1 bias por unidad salida) = (40,000 x 256) + 256 | 10,240,256 |
# | Dropout | Rate: 0.5 | (256) | (256) | 0 (No hay parámetros en las capas de dropout) | 0 |
# | Dense | Unidades: 2 | (256) | (2) | (entrada x salida + 1 bias por unidad salida) = (256 x 2) + 2 | 514 |

# %% [markdown]
# ## Entrenamos la red
# Con los datos de data augmentation

# %%
epochs = 200
batch_size = 32

# Crear el generador de datos para el conjunto de entrenamiento con data augmentation
train_data_generator = data_augmentation.flow(train_X, train_label_one_hot, batch_size=batch_size)

## Modifica el train_x para incluir las imagenes del train_data_generator
history=modelo.fit(train_data_generator, steps_per_epoch=len(train_X) // batch_size, epochs=epochs, verbose=1, validation_data=(valid_X, valid_label_one_hot))
# history=modelo.fit(train_X, train_label_one_hot, batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(valid_X, valid_label_one_hot))

# guardamos la red, para reutilizarla en el futuro, sin tener que volver a entrenar
dir='./modelo/'

if not os.path.exists(dir):
    os.mkdir(dir)
modelo.save('./modelo/modelo.h5')
modelo.save_weights('./modelo/pesos.h5')
# Out:
# Epoch 1/200
# 2023-07-29 14:04:46.677520: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2/2 [==============================] - 1s 192ms/step - loss: 0.6989 - accuracy: 0.5781 - val_loss: 0.7411 - val_accuracy: 0.5556
# Epoch 2/200
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6480 - accuracy: 0.6250
# 2023-07-29 14:04:47.003588: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2/2 [==============================] - 0s 108ms/step - loss: 0.6500 - accuracy: 0.6316 - val_loss: 0.7252 - val_accuracy: 0.5556
# Epoch 3/200
# 2/2 [==============================] - 0s 80ms/step - loss: 0.7010 - accuracy: 0.5000 - val_loss: 0.6861 - val_accuracy: 0.5556
# Epoch 4/200
# 2/2 [==============================] - 0s 54ms/step - loss: 0.6875 - accuracy: 0.5263 - val_loss: 0.6855 - val_accuracy: 0.5556
# Epoch 5/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6924 - accuracy: 0.5000 - val_loss: 0.6971 - val_accuracy: 0.5556
# Epoch 6/200
# 2/2 [==============================] - 0s 54ms/step - loss: 0.7021 - accuracy: 0.5263 - val_loss: 0.7145 - val_accuracy: 0.5556
# Epoch 7/200
# 2/2 [==============================] - 0s 74ms/step - loss: 0.6799 - accuracy: 0.6250 - val_loss: 0.7315 - val_accuracy: 0.5556
# Epoch 8/200
# 2/2 [==============================] - 0s 81ms/step - loss: 0.6047 - accuracy: 0.6316 - val_loss: 0.7190 - val_accuracy: 0.5556
# Epoch 9/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.6506 - accuracy: 0.5789 - val_loss: 0.7047 - val_accuracy: 0.5556
# Epoch 10/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6058 - accuracy: 0.7368 - val_loss: 0.6974 - val_accuracy: 0.5556
# Epoch 11/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.6696 - accuracy: 0.6316 - val_loss: 0.6887 - val_accuracy: 0.5556
# Epoch 12/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.6541 - accuracy: 0.6842 - val_loss: 0.6811 - val_accuracy: 0.5556
# Epoch 13/200
# 2/2 [==============================] - 0s 67ms/step - loss: 0.6651 - accuracy: 0.6250 - val_loss: 0.6770 - val_accuracy: 0.5556
# Epoch 14/200
# 2/2 [==============================] - 0s 70ms/step - loss: 0.7124 - accuracy: 0.6316 - val_loss: 0.6816 - val_accuracy: 0.5556
# Epoch 15/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.6170 - accuracy: 0.6316 - val_loss: 0.6938 - val_accuracy: 0.5556
# Epoch 16/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.6402 - accuracy: 0.6316 - val_loss: 0.7153 - val_accuracy: 0.5556
# Epoch 17/200
# 2/2 [==============================] - 0s 66ms/step - loss: 0.6553 - accuracy: 0.5938 - val_loss: 0.7182 - val_accuracy: 0.5556
# Epoch 18/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6767 - accuracy: 0.7105 - val_loss: 0.7042 - val_accuracy: 0.5556
# Epoch 19/200
# 2/2 [==============================] - 0s 90ms/step - loss: 0.6468 - accuracy: 0.6053 - val_loss: 0.6900 - val_accuracy: 0.5556
# Epoch 20/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6198 - accuracy: 0.6316 - val_loss: 0.6683 - val_accuracy: 0.5556
# Epoch 21/200
# 2/2 [==============================] - 0s 69ms/step - loss: 0.6106 - accuracy: 0.6719 - val_loss: 0.6544 - val_accuracy: 0.6111
# Epoch 22/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.6798 - accuracy: 0.6316 - val_loss: 0.6454 - val_accuracy: 0.7222
# Epoch 23/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.6449 - accuracy: 0.6562 - val_loss: 0.6442 - val_accuracy: 0.7778
# Epoch 24/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.6556 - accuracy: 0.5526 - val_loss: 0.6409 - val_accuracy: 0.7778
# Epoch 25/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.6564 - accuracy: 0.7188 - val_loss: 0.6408 - val_accuracy: 0.6111
# Epoch 26/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.6515 - accuracy: 0.4737 - val_loss: 0.6646 - val_accuracy: 0.6111
# Epoch 27/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.6313 - accuracy: 0.6875 - val_loss: 0.7149 - val_accuracy: 0.5556
# Epoch 28/200
# 2/2 [==============================] - 0s 74ms/step - loss: 0.5986 - accuracy: 0.7105 - val_loss: 0.7792 - val_accuracy: 0.5556
# Epoch 29/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.7760 - accuracy: 0.5526 - val_loss: 0.8127 - val_accuracy: 0.5556
# Epoch 30/200
# 2/2 [==============================] - 0s 76ms/step - loss: 0.7185 - accuracy: 0.6053 - val_loss: 0.7290 - val_accuracy: 0.5556
# Epoch 31/200
# 2/2 [==============================] - 0s 67ms/step - loss: 0.6411 - accuracy: 0.6406 - val_loss: 0.6524 - val_accuracy: 0.6111
# Epoch 32/200
# 2/2 [==============================] - 0s 86ms/step - loss: 0.6854 - accuracy: 0.6053 - val_loss: 0.6167 - val_accuracy: 0.7222
# Epoch 33/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.6156 - accuracy: 0.6875 - val_loss: 0.6169 - val_accuracy: 0.7778
# Epoch 34/200
# 2/2 [==============================] - 0s 67ms/step - loss: 0.6587 - accuracy: 0.6250 - val_loss: 0.6205 - val_accuracy: 0.7222
# Epoch 35/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6622 - accuracy: 0.5789 - val_loss: 0.6129 - val_accuracy: 0.7778
# Epoch 36/200
# 2/2 [==============================] - 0s 78ms/step - loss: 0.6287 - accuracy: 0.7105 - val_loss: 0.6199 - val_accuracy: 0.6111
# Epoch 37/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.5931 - accuracy: 0.6579 - val_loss: 0.6510 - val_accuracy: 0.6111
# Epoch 38/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.5866 - accuracy: 0.7368 - val_loss: 0.6811 - val_accuracy: 0.5556
# Epoch 39/200
# 2/2 [==============================] - 0s 79ms/step - loss: 0.6544 - accuracy: 0.6053 - val_loss: 0.6620 - val_accuracy: 0.6111
# Epoch 40/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.6272 - accuracy: 0.6316 - val_loss: 0.6368 - val_accuracy: 0.6111
# Epoch 41/200
# 2/2 [==============================] - 0s 76ms/step - loss: 0.6013 - accuracy: 0.6842 - val_loss: 0.6205 - val_accuracy: 0.6111
# Epoch 42/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.6011 - accuracy: 0.7031 - val_loss: 0.6096 - val_accuracy: 0.6111
# Epoch 43/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.5892 - accuracy: 0.6842 - val_loss: 0.6051 - val_accuracy: 0.6111
# Epoch 44/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.5947 - accuracy: 0.7188 - val_loss: 0.6042 - val_accuracy: 0.6111
# Epoch 45/200
# 2/2 [==============================] - 0s 67ms/step - loss: 0.5969 - accuracy: 0.7188 - val_loss: 0.6077 - val_accuracy: 0.6111
# Epoch 46/200
# 2/2 [==============================] - 0s 67ms/step - loss: 0.6122 - accuracy: 0.6875 - val_loss: 0.6094 - val_accuracy: 0.6111
# Epoch 47/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6070 - accuracy: 0.6842 - val_loss: 0.6108 - val_accuracy: 0.6111
# Epoch 48/200
# 2/2 [==============================] - 0s 74ms/step - loss: 0.6599 - accuracy: 0.6579 - val_loss: 0.6011 - val_accuracy: 0.6111
# Epoch 49/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.5985 - accuracy: 0.6842 - val_loss: 0.5928 - val_accuracy: 0.6111
# Epoch 50/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.5794 - accuracy: 0.7368 - val_loss: 0.5911 - val_accuracy: 0.6111
# Epoch 51/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.5712 - accuracy: 0.7344 - val_loss: 0.5885 - val_accuracy: 0.6111
# Epoch 52/200
# 2/2 [==============================] - 0s 55ms/step - loss: 0.6043 - accuracy: 0.7105 - val_loss: 0.5842 - val_accuracy: 0.6111
# Epoch 53/200
# 2/2 [==============================] - 0s 67ms/step - loss: 0.6025 - accuracy: 0.6875 - val_loss: 0.5669 - val_accuracy: 0.6111
# Epoch 54/200
# 2/2 [==============================] - 0s 85ms/step - loss: 0.5577 - accuracy: 0.7895 - val_loss: 0.5562 - val_accuracy: 0.7222
# Epoch 55/200
# 2/2 [==============================] - 0s 67ms/step - loss: 0.5724 - accuracy: 0.7188 - val_loss: 0.5509 - val_accuracy: 0.7222
# Epoch 56/200
# 2/2 [==============================] - 0s 74ms/step - loss: 0.6064 - accuracy: 0.7368 - val_loss: 0.5451 - val_accuracy: 0.8333
# Epoch 57/200
# 2/2 [==============================] - 0s 74ms/step - loss: 0.5657 - accuracy: 0.7368 - val_loss: 0.5390 - val_accuracy: 0.8333
# Epoch 58/200
# 2/2 [==============================] - 0s 80ms/step - loss: 0.5768 - accuracy: 0.6719 - val_loss: 0.5372 - val_accuracy: 0.7222
# Epoch 59/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.5124 - accuracy: 0.7895 - val_loss: 0.5492 - val_accuracy: 0.6111
# Epoch 60/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.5919 - accuracy: 0.7031 - val_loss: 0.5858 - val_accuracy: 0.6111
# Epoch 61/200
# 2/2 [==============================] - 0s 76ms/step - loss: 0.5356 - accuracy: 0.7368 - val_loss: 0.6008 - val_accuracy: 0.6111
# Epoch 62/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.5931 - accuracy: 0.6579 - val_loss: 0.5691 - val_accuracy: 0.6111
# Epoch 63/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.5125 - accuracy: 0.7368 - val_loss: 0.5210 - val_accuracy: 0.6667
# Epoch 64/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.5416 - accuracy: 0.7031 - val_loss: 0.5110 - val_accuracy: 0.8889
# Epoch 65/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.5752 - accuracy: 0.7105 - val_loss: 0.5111 - val_accuracy: 0.8333
# Epoch 66/200
# 2/2 [==============================] - 0s 67ms/step - loss: 0.5878 - accuracy: 0.7188 - val_loss: 0.5024 - val_accuracy: 0.8889
# Epoch 67/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.5436 - accuracy: 0.7105 - val_loss: 0.5206 - val_accuracy: 0.6667
# Epoch 68/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.5012 - accuracy: 0.7500 - val_loss: 0.5538 - val_accuracy: 0.6111
# Epoch 69/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.5196 - accuracy: 0.7656 - val_loss: 0.5721 - val_accuracy: 0.6111
# Epoch 70/200
# 2/2 [==============================] - 0s 73ms/step - loss: 0.5508 - accuracy: 0.7368 - val_loss: 0.5404 - val_accuracy: 0.6111
# Epoch 71/200
# 2/2 [==============================] - 0s 73ms/step - loss: 0.4851 - accuracy: 0.7632 - val_loss: 0.5201 - val_accuracy: 0.6667
# Epoch 72/200
# 2/2 [==============================] - 0s 74ms/step - loss: 0.4821 - accuracy: 0.7632 - val_loss: 0.5192 - val_accuracy: 0.6667
# Epoch 73/200
# 2/2 [==============================] - 0s 66ms/step - loss: 0.4888 - accuracy: 0.7656 - val_loss: 0.5052 - val_accuracy: 0.6667
# Epoch 74/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.5527 - accuracy: 0.7105 - val_loss: 0.4900 - val_accuracy: 0.6667
# Epoch 75/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.5058 - accuracy: 0.8421 - val_loss: 0.4526 - val_accuracy: 0.8889
# Epoch 76/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.6248 - accuracy: 0.6579 - val_loss: 0.4571 - val_accuracy: 0.7778
# Epoch 77/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.5721 - accuracy: 0.7105 - val_loss: 0.4647 - val_accuracy: 0.6667
# Epoch 78/200
# 2/2 [==============================] - 0s 69ms/step - loss: 0.5276 - accuracy: 0.7188 - val_loss: 0.4661 - val_accuracy: 0.6667
# Epoch 79/200
# 2/2 [==============================] - 0s 69ms/step - loss: 0.5445 - accuracy: 0.6562 - val_loss: 0.4704 - val_accuracy: 0.6667
# Epoch 80/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.4494 - accuracy: 0.7632 - val_loss: 0.4882 - val_accuracy: 0.6667
# Epoch 81/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.5698 - accuracy: 0.6579 - val_loss: 0.4593 - val_accuracy: 0.6667
# Epoch 82/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.5001 - accuracy: 0.7656 - val_loss: 0.4396 - val_accuracy: 0.8889
# Epoch 83/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.5428 - accuracy: 0.7031 - val_loss: 0.4462 - val_accuracy: 0.8889
# Epoch 84/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.4515 - accuracy: 0.8158 - val_loss: 0.4682 - val_accuracy: 0.6667
# Epoch 85/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.5326 - accuracy: 0.6842 - val_loss: 0.4837 - val_accuracy: 0.6667
# Epoch 86/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.5102 - accuracy: 0.7632 - val_loss: 0.5037 - val_accuracy: 0.6667
# Epoch 87/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.5039 - accuracy: 0.7368 - val_loss: 0.4940 - val_accuracy: 0.6667
# Epoch 88/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.5107 - accuracy: 0.7344 - val_loss: 0.4569 - val_accuracy: 0.6667
# Epoch 89/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.4660 - accuracy: 0.7895 - val_loss: 0.4205 - val_accuracy: 0.8889
# Epoch 90/200
# 2/2 [==============================] - 0s 69ms/step - loss: 0.4870 - accuracy: 0.7500 - val_loss: 0.4168 - val_accuracy: 0.8889
# Epoch 91/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.4831 - accuracy: 0.7188 - val_loss: 0.4368 - val_accuracy: 0.7222
# Epoch 92/200
# 2/2 [==============================] - 0s 74ms/step - loss: 0.4830 - accuracy: 0.7368 - val_loss: 0.5226 - val_accuracy: 0.6667
# Epoch 93/200
# 2/2 [==============================] - 0s 67ms/step - loss: 0.5112 - accuracy: 0.7344 - val_loss: 0.5430 - val_accuracy: 0.6111
# Epoch 94/200
# 2/2 [==============================] - 0s 69ms/step - loss: 0.5232 - accuracy: 0.7344 - val_loss: 0.4835 - val_accuracy: 0.6667
# Epoch 95/200
# 2/2 [==============================] - 0s 74ms/step - loss: 0.4976 - accuracy: 0.7632 - val_loss: 0.4522 - val_accuracy: 0.7222
# Epoch 96/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.5006 - accuracy: 0.7344 - val_loss: 0.4058 - val_accuracy: 0.8333
# Epoch 97/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.5586 - accuracy: 0.6579 - val_loss: 0.4015 - val_accuracy: 0.8333
# Epoch 98/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.4149 - accuracy: 0.8158 - val_loss: 0.4446 - val_accuracy: 0.7222
# Epoch 99/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.5147 - accuracy: 0.6842 - val_loss: 0.4363 - val_accuracy: 0.7222
# Epoch 100/200
# 2/2 [==============================] - 0s 66ms/step - loss: 0.4331 - accuracy: 0.7500 - val_loss: 0.4113 - val_accuracy: 0.8333
# Epoch 101/200
# 2/2 [==============================] - 0s 66ms/step - loss: 0.4611 - accuracy: 0.8125 - val_loss: 0.3949 - val_accuracy: 0.8889
# Epoch 102/200
# 2/2 [==============================] - 0s 67ms/step - loss: 0.4376 - accuracy: 0.7656 - val_loss: 0.4067 - val_accuracy: 0.8333
# Epoch 103/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.4390 - accuracy: 0.7812 - val_loss: 0.4461 - val_accuracy: 0.6667
# Epoch 104/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.4790 - accuracy: 0.7344 - val_loss: 0.5046 - val_accuracy: 0.6667
# Epoch 105/200
# 2/2 [==============================] - 0s 76ms/step - loss: 0.5685 - accuracy: 0.7105 - val_loss: 0.3694 - val_accuracy: 0.8889
# Epoch 106/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.5020 - accuracy: 0.7188 - val_loss: 0.3554 - val_accuracy: 0.9444
# Epoch 107/200
# 2/2 [==============================] - 0s 78ms/step - loss: 0.4278 - accuracy: 0.7632 - val_loss: 0.3728 - val_accuracy: 0.8889
# Epoch 108/200
# 2/2 [==============================] - 0s 84ms/step - loss: 0.5002 - accuracy: 0.7105 - val_loss: 0.4639 - val_accuracy: 0.6667
# Epoch 109/200
# 2/2 [==============================] - 0s 69ms/step - loss: 0.4786 - accuracy: 0.7500 - val_loss: 0.4927 - val_accuracy: 0.6667
# Epoch 110/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.4151 - accuracy: 0.8158 - val_loss: 0.4099 - val_accuracy: 0.8333
# Epoch 111/200
# 2/2 [==============================] - 0s 76ms/step - loss: 0.4582 - accuracy: 0.7895 - val_loss: 0.3480 - val_accuracy: 0.9444
# Epoch 112/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.4151 - accuracy: 0.8158 - val_loss: 0.3483 - val_accuracy: 0.9444
# Epoch 113/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.4634 - accuracy: 0.7895 - val_loss: 0.3923 - val_accuracy: 0.8889
# Epoch 114/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.4247 - accuracy: 0.7812 - val_loss: 0.4519 - val_accuracy: 0.6667
# Epoch 115/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.5056 - accuracy: 0.7632 - val_loss: 0.4647 - val_accuracy: 0.6667
# Epoch 116/200
# 2/2 [==============================] - 0s 76ms/step - loss: 0.4703 - accuracy: 0.7895 - val_loss: 0.4113 - val_accuracy: 0.8333
# Epoch 117/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.4360 - accuracy: 0.7969 - val_loss: 0.3901 - val_accuracy: 0.8333
# Epoch 118/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.4147 - accuracy: 0.8281 - val_loss: 0.4006 - val_accuracy: 0.8333
# Epoch 119/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.3907 - accuracy: 0.8421 - val_loss: 0.4414 - val_accuracy: 0.6667
# Epoch 120/200
# 2/2 [==============================] - 0s 76ms/step - loss: 0.4074 - accuracy: 0.6842 - val_loss: 0.5489 - val_accuracy: 0.6111
# Epoch 121/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.4942 - accuracy: 0.7105 - val_loss: 0.4922 - val_accuracy: 0.6667
# Epoch 122/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.4216 - accuracy: 0.7895 - val_loss: 0.3558 - val_accuracy: 0.9444
# Epoch 123/200
# 2/2 [==============================] - 0s 67ms/step - loss: 0.4424 - accuracy: 0.8125 - val_loss: 0.3427 - val_accuracy: 0.9444
# Epoch 124/200
# 2/2 [==============================] - 0s 72ms/step - loss: 0.5502 - accuracy: 0.6053 - val_loss: 0.4761 - val_accuracy: 0.6667
# Epoch 125/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.4086 - accuracy: 0.8158 - val_loss: 0.6859 - val_accuracy: 0.6111
# Epoch 126/200
# 2/2 [==============================] - 0s 69ms/step - loss: 0.5540 - accuracy: 0.7031 - val_loss: 0.5706 - val_accuracy: 0.6111
# Epoch 127/200
# 2/2 [==============================] - 0s 67ms/step - loss: 0.4391 - accuracy: 0.7656 - val_loss: 0.4014 - val_accuracy: 0.8333
# Epoch 128/200
# 2/2 [==============================] - 0s 54ms/step - loss: 0.3953 - accuracy: 0.8421 - val_loss: 0.3392 - val_accuracy: 0.9444
# Epoch 129/200
# 2/2 [==============================] - 0s 76ms/step - loss: 0.4472 - accuracy: 0.8281 - val_loss: 0.3310 - val_accuracy: 0.9444
# Epoch 130/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.4203 - accuracy: 0.8947 - val_loss: 0.3461 - val_accuracy: 0.9444
# Epoch 131/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.3991 - accuracy: 0.8947 - val_loss: 0.3839 - val_accuracy: 0.8333
# Epoch 132/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.4240 - accuracy: 0.7656 - val_loss: 0.4316 - val_accuracy: 0.7222
# Epoch 133/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.3861 - accuracy: 0.8684 - val_loss: 0.3792 - val_accuracy: 0.7778
# Epoch 134/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.3378 - accuracy: 0.8684 - val_loss: 0.3738 - val_accuracy: 0.7778
# Epoch 135/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.3831 - accuracy: 0.7895 - val_loss: 0.3918 - val_accuracy: 0.7222
# Epoch 136/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.3499 - accuracy: 0.8421 - val_loss: 0.4431 - val_accuracy: 0.7222
# Epoch 137/200
# 2/2 [==============================] - 0s 67ms/step - loss: 0.4032 - accuracy: 0.8438 - val_loss: 0.4486 - val_accuracy: 0.7222
# Epoch 138/200
# 2/2 [==============================] - 0s 72ms/step - loss: 0.5583 - accuracy: 0.6842 - val_loss: 0.4750 - val_accuracy: 0.6667
# Epoch 139/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.4063 - accuracy: 0.7895 - val_loss: 0.3656 - val_accuracy: 0.7778
# Epoch 140/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.4032 - accuracy: 0.7895 - val_loss: 0.3096 - val_accuracy: 0.8889
# Epoch 141/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.3679 - accuracy: 0.8158 - val_loss: 0.2866 - val_accuracy: 0.8889
# Epoch 142/200
# 2/2 [==============================] - 0s 73ms/step - loss: 0.4426 - accuracy: 0.7031 - val_loss: 0.3005 - val_accuracy: 0.8889
# Epoch 143/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.3771 - accuracy: 0.8158 - val_loss: 0.3703 - val_accuracy: 0.7778
# Epoch 144/200
# 2/2 [==============================] - 0s 52ms/step - loss: 0.3745 - accuracy: 0.8684 - val_loss: 0.5308 - val_accuracy: 0.6667
# Epoch 145/200
# 2/2 [==============================] - 0s 54ms/step - loss: 0.4427 - accuracy: 0.7895 - val_loss: 0.4768 - val_accuracy: 0.6667
# Epoch 146/200
# 2/2 [==============================] - 0s 70ms/step - loss: 0.4380 - accuracy: 0.7656 - val_loss: 0.2823 - val_accuracy: 0.9444
# Epoch 147/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.3943 - accuracy: 0.8421 - val_loss: 0.2785 - val_accuracy: 0.9444
# Epoch 148/200
# 2/2 [==============================] - 0s 67ms/step - loss: 0.5435 - accuracy: 0.7500 - val_loss: 0.2803 - val_accuracy: 0.9444
# Epoch 149/200
# 2/2 [==============================] - 0s 74ms/step - loss: 0.4174 - accuracy: 0.7632 - val_loss: 0.2774 - val_accuracy: 0.9444
# Epoch 150/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.4507 - accuracy: 0.7632 - val_loss: 0.4243 - val_accuracy: 0.7222
# Epoch 151/200
# 2/2 [==============================] - 0s 76ms/step - loss: 0.4758 - accuracy: 0.7632 - val_loss: 0.4997 - val_accuracy: 0.6667
# Epoch 152/200
# 2/2 [==============================] - 0s 67ms/step - loss: 0.4293 - accuracy: 0.7656 - val_loss: 0.3772 - val_accuracy: 0.7778
# Epoch 153/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.3219 - accuracy: 0.8947 - val_loss: 0.3088 - val_accuracy: 0.8889
# Epoch 154/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.3677 - accuracy: 0.8684 - val_loss: 0.2919 - val_accuracy: 0.9444
# Epoch 155/200
# 2/2 [==============================] - 0s 67ms/step - loss: 0.4015 - accuracy: 0.7969 - val_loss: 0.2958 - val_accuracy: 0.9444
# Epoch 156/200
# 2/2 [==============================] - 0s 67ms/step - loss: 0.4132 - accuracy: 0.7656 - val_loss: 0.3282 - val_accuracy: 0.8889
# Epoch 157/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.3742 - accuracy: 0.8158 - val_loss: 0.3663 - val_accuracy: 0.8889
# Epoch 158/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.3329 - accuracy: 0.8438 - val_loss: 0.3745 - val_accuracy: 0.8889
# Epoch 159/200
# 2/2 [==============================] - 0s 74ms/step - loss: 0.3419 - accuracy: 0.8421 - val_loss: 0.4327 - val_accuracy: 0.7222
# Epoch 160/200
# 2/2 [==============================] - 0s 67ms/step - loss: 0.3750 - accuracy: 0.7969 - val_loss: 0.3846 - val_accuracy: 0.8333
# Epoch 161/200
# 2/2 [==============================] - 0s 66ms/step - loss: 0.3505 - accuracy: 0.8125 - val_loss: 0.3184 - val_accuracy: 0.9444
# Epoch 162/200
# 2/2 [==============================] - 0s 67ms/step - loss: 0.4018 - accuracy: 0.8281 - val_loss: 0.3175 - val_accuracy: 0.9444
# Epoch 163/200
# 2/2 [==============================] - 0s 76ms/step - loss: 0.3299 - accuracy: 0.8158 - val_loss: 0.4130 - val_accuracy: 0.8333
# Epoch 164/200
# 2/2 [==============================] - 0s 72ms/step - loss: 0.4775 - accuracy: 0.7368 - val_loss: 0.3338 - val_accuracy: 0.9444
# Epoch 165/200
# 2/2 [==============================] - 0s 74ms/step - loss: 0.4416 - accuracy: 0.7895 - val_loss: 0.2757 - val_accuracy: 0.9444
# Epoch 166/200
# 2/2 [==============================] - 0s 76ms/step - loss: 0.3304 - accuracy: 0.8684 - val_loss: 0.2514 - val_accuracy: 0.9444
# Epoch 167/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.5308 - accuracy: 0.7105 - val_loss: 0.3013 - val_accuracy: 0.9444
# Epoch 168/200
# 2/2 [==============================] - 0s 53ms/step - loss: 0.4175 - accuracy: 0.7632 - val_loss: 0.5088 - val_accuracy: 0.6667
# Epoch 169/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.3568 - accuracy: 0.8421 - val_loss: 0.7697 - val_accuracy: 0.5556
# Epoch 170/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.5395 - accuracy: 0.7105 - val_loss: 0.5269 - val_accuracy: 0.6667
# Epoch 171/200
# 2/2 [==============================] - 0s 76ms/step - loss: 0.3094 - accuracy: 0.8158 - val_loss: 0.3494 - val_accuracy: 0.9444
# Epoch 172/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.3761 - accuracy: 0.8421 - val_loss: 0.2819 - val_accuracy: 0.9444
# Epoch 173/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.3731 - accuracy: 0.8947 - val_loss: 0.2721 - val_accuracy: 0.9444
# Epoch 174/200
# 2/2 [==============================] - 0s 72ms/step - loss: 0.3417 - accuracy: 0.8947 - val_loss: 0.3283 - val_accuracy: 0.9444
# Epoch 175/200
# 2/2 [==============================] - 0s 77ms/step - loss: 0.4245 - accuracy: 0.8158 - val_loss: 0.4575 - val_accuracy: 0.6667
# Epoch 176/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.3569 - accuracy: 0.7969 - val_loss: 0.4893 - val_accuracy: 0.6667
# Epoch 177/200
# 2/2 [==============================] - 0s 67ms/step - loss: 0.3947 - accuracy: 0.7969 - val_loss: 0.4327 - val_accuracy: 0.6667
# Epoch 178/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.3431 - accuracy: 0.8158 - val_loss: 0.3577 - val_accuracy: 0.8333
# Epoch 179/200
# 2/2 [==============================] - 0s 52ms/step - loss: 0.3333 - accuracy: 0.8684 - val_loss: 0.3055 - val_accuracy: 0.9444
# Epoch 180/200
# 2/2 [==============================] - 0s 52ms/step - loss: 0.2708 - accuracy: 0.9211 - val_loss: 0.2782 - val_accuracy: 0.9444
# Epoch 181/200
# 2/2 [==============================] - 0s 53ms/step - loss: 0.3776 - accuracy: 0.8421 - val_loss: 0.3002 - val_accuracy: 0.9444
# Epoch 182/200
# 2/2 [==============================] - 0s 77ms/step - loss: 0.3562 - accuracy: 0.8125 - val_loss: 0.3707 - val_accuracy: 0.8889
# Epoch 183/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.4075 - accuracy: 0.7632 - val_loss: 0.4806 - val_accuracy: 0.6667
# Epoch 184/200
# 2/2 [==============================] - 0s 76ms/step - loss: 0.4222 - accuracy: 0.7368 - val_loss: 0.5929 - val_accuracy: 0.6111
# Epoch 185/200
# 2/2 [==============================] - 0s 66ms/step - loss: 0.4222 - accuracy: 0.7656 - val_loss: 0.4286 - val_accuracy: 0.8333
# Epoch 186/200
# 2/2 [==============================] - 0s 76ms/step - loss: 0.2874 - accuracy: 0.9211 - val_loss: 0.3134 - val_accuracy: 0.9444
# Epoch 187/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.3385 - accuracy: 0.8750 - val_loss: 0.2565 - val_accuracy: 0.9444
# Epoch 188/200
# 2/2 [==============================] - 0s 74ms/step - loss: 0.4676 - accuracy: 0.8158 - val_loss: 0.2271 - val_accuracy: 0.9444
# Epoch 189/200
# 2/2 [==============================] - 0s 78ms/step - loss: 0.4036 - accuracy: 0.8158 - val_loss: 0.2213 - val_accuracy: 0.9444
# Epoch 190/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.4167 - accuracy: 0.8281 - val_loss: 0.2530 - val_accuracy: 0.9444
# Epoch 191/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.3155 - accuracy: 0.8906 - val_loss: 0.4390 - val_accuracy: 0.8889
# Epoch 192/200
# 2/2 [==============================] - 0s 74ms/step - loss: 0.3032 - accuracy: 0.8684 - val_loss: 0.5427 - val_accuracy: 0.6667
# Epoch 193/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.3868 - accuracy: 0.7656 - val_loss: 0.4287 - val_accuracy: 0.8889
# Epoch 194/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.3579 - accuracy: 0.7895 - val_loss: 0.2526 - val_accuracy: 0.9444
# Epoch 195/200
# 2/2 [==============================] - 0s 75ms/step - loss: 0.4412 - accuracy: 0.7368 - val_loss: 0.2187 - val_accuracy: 0.9444
# Epoch 196/200
# 2/2 [==============================] - 0s 74ms/step - loss: 0.4233 - accuracy: 0.8421 - val_loss: 0.2318 - val_accuracy: 0.9444
# Epoch 197/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.3824 - accuracy: 0.8421 - val_loss: 0.3198 - val_accuracy: 0.9444
# Epoch 198/200
# 2/2 [==============================] - 0s 72ms/step - loss: 0.3325 - accuracy: 0.8158 - val_loss: 0.4701 - val_accuracy: 0.7222
# Epoch 199/200
# 2/2 [==============================] - 0s 73ms/step - loss: 0.3325 - accuracy: 0.8421 - val_loss: 0.5400 - val_accuracy: 0.6667
# Epoch 200/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.3602 - accuracy: 0.8158 - val_loss: 0.4777 - val_accuracy: 0.7222

# %% [markdown]
# ## Obtenemos las métricas de entrenamiento y validación, luego graficamos

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

def metricas(clases_reales, clases_predichas):
    matriz_conf=confusion_matrix(clases_reales, clases_predichas)
    accuracy=accuracy_score(clases_reales,clases_predichas)
    precision=precision_score(clases_reales,clases_predichas)
    recall=recall_score(clases_reales,clases_predichas)
    f1=f1_score(clases_reales,clases_predichas)
    return matriz_conf, accuracy, recall, precision, f1

def visualizar_metricas(clases_reales,clases_predichas, titulo):
    #Calculamos metricas con la funcion previa
    matriz, accuracy, recall, precision, f1=metricas(clases_reales,clases_predichas)

    #Graficamos
    plt.figure(figsize=(3,3))
    matriz=pd.DataFrame(matriz,columns=['0: Mercante', '1: Otro'])
    plt.matshow(matriz, cmap="Blues", vmin=0, vmax=10, fignum=1)
    plt.title("Reales")
    plt.ylabel("Predichas")
    plt.xticks(range(len(matriz.columns)), matriz.columns, rotation=45)
    plt.yticks(range(len(matriz.columns)), matriz.columns)
    etiquetas = (("Verdaderos\nnegativos", "Falsos\npositivos"),
                 ("Falsos\nnegativos", "Verdaderos\npositivos"))
    for i in range(len(matriz.columns)):
        for j in range(len(matriz.columns)):
            plt.text(i, j + 0.14, str(matriz.iloc[i, j]),
                     fontsize=30, ha="center", va="center")
            plt.text(i, j - 0.25, etiquetas[i][j],
                     fontsize=11.5, ha="center", va="center")           
    plt.text(1.60, -0.30, titulo, fontsize=25, c="red")
    plt.text(2.1, 0.10, "Accuracy: %0.2f" % accuracy, fontsize=20)
    plt.text(2.1, 0.40, "Precision: %0.2f" % precision, fontsize=20)
    plt.text(2.1, 0.70, "Recall: %0.2f" % recall, fontsize=20)
    plt.text(2.1, 1.00, "F1: %0.2f" % f1, fontsize=20)    
    plt.show()
    print("\n")

print("\n")

reales=[1,1,0,0,0,0,1,1]
predichas=[1,1,0,1,0,1,1,1]

visualizar_metricas(reales,predichas,'Métricas')

# %%
# Obtener las métricas de entrenamiento y validación
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(1, epochs + 1)

# Gráfica de precisión (accuracy)
plt.figure(figsize=(12, 6))
plt.plot(epochs_range, train_accuracy, label='Training Accuracy', color='blue')
plt.plot(epochs_range, val_accuracy, label='Validation Accuracy', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Gráfica de pérdida (loss)
plt.figure(figsize=(12, 6))
plt.plot(epochs_range, train_loss, label='Training Loss', color='blue')
plt.plot(epochs_range, val_loss, label='Validation Loss', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Probamos la red

# %%
# Muestra de Etiqueta Mercante:
import matplotlib.pyplot as plt
plt.imshow(plt.imread('prueba/4.jpg'))

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

directorio_imagen_prueba='./prueba/4.jpg'
# Carga la imagen de prueba
imagen_prueba = cv2.imread(directorio_imagen_prueba)
imagen_prueba = cv2.resize(imagen_prueba, (100, 100))

# OpenCV lee las imágenes en formato BGR, pero los modelos de Keras están entrenados con imágenes en formato RGB, por lo que es necesario convertir la imagen de BGR a RGB
imagen_prueba = cv2.cvtColor(imagen_prueba, cv2.COLOR_BGR2RGB)

# Convertir a float32 y normalizar
imagen_prueba = imagen_prueba.astype('float32') / 255.0

# Ajusta las dimensiones de la imagen para que sea compatible con la entrada del modelo
imagen_prueba = np.expand_dims(imagen_prueba, axis=0)

# Obtén las predicciones utilizando el modelo entrenado
predicciones = modelo.predict(imagen_prueba)

# Las predicciones son un arreglo de probabilidades, conviértelas a una clase
clase_predicha = np.argmax(predicciones[0])

# Obten la clase correspondiente al índice
clase = classes[clase_predicha]

# Obten el porcentaje de confianza para la clase predicha
porcentaje_confianza = predicciones[0][clase_predicha] * 100

# Carga la imagen de nuevo para mostrarla (esta vez en formato RGB para matplotlib)
imagen_prueba = cv2.cvtColor(cv2.imread(directorio_imagen_prueba), cv2.COLOR_BGR2RGB)
imagen_prueba = cv2.resize(imagen_prueba, (100, 100))

plt.imshow(imagen_prueba)
plt.title("La imagen es de clase: {} con un porcentaje de confianza de: {:.2f}%".format(clase, porcentaje_confianza))
plt.show()
# Out:
# 1/1 [==============================] - 0s 14ms/step

# %%
def prueba_modelo(modelo, directorio, altura, longitud, classes):
    resultados = []
    for archivo in os.listdir(directorio):
        ruta_imagen = os.path.join(directorio, archivo)
        # Carga la imagen de prueba
        imagen_prueba = cv2.imread(ruta_imagen)
        imagen_prueba = cv2.resize(imagen_prueba, (altura, longitud))

        # OpenCV lee las imágenes en formato BGR, pero los modelos de Keras están entrenados con imágenes en formato RGB, por lo que es necesario convertir la imagen de BGR a RGB
        imagen_prueba = cv2.cvtColor(imagen_prueba, cv2.COLOR_BGR2RGB)

        # Convertir a float32 y normalizar
        imagen_prueba = imagen_prueba.astype('float32') / 255.0

        # Ajusta las dimensiones de la imagen para que sea compatible con la entrada del modelo
        imagen_prueba = np.expand_dims(imagen_prueba, axis=0)

        # Obtén las predicciones utilizando el modelo entrenado
        predicciones = modelo.predict(imagen_prueba)

        # Las predicciones son un arreglo de probabilidades, conviértelas a una clase
        clase_predicha = np.argmax(predicciones[0])

        # Obten la clase correspondiente al índice
        clase = classes[clase_predicha]

        resultados.append((archivo, clase))

    return resultados

# Uso de la función prueba_modelo
directorio_imagenes = './prueba'
resultados = prueba_modelo(modelo, directorio_imagenes, altura, longitud, classes)

# Mostrar resultados
for archivo, clase in resultados:
    print(f"La imagen {archivo} es de clase: {clase}")
# Out:
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# La imagen 8.jpg es de clase: 0
# La imagen 4.jpg es de clase: 1
# La imagen 5.jpg es de clase: 1
# La imagen 7.jpg es de clase: 0
# La imagen 6.jpg es de clase: 1
# La imagen 2.png es de clase: 1
# La imagen 3.jpg es de clase: 1
# La imagen 1.jpg es de clase: 0
