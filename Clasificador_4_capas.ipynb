# %% [markdown]
# # Código Clasificación buques mercantes utilizando 4 capas de CNN.

# %%
### Conocer version de paquetes y Hardware en uso
#------------------------------------------------------
#------------------------------------------------------
import sys
import tensorflow.keras
import keras
import pandas as pd
import sklearn as sk
import tensorflow as tf
import numpy as np
import platform

print(f"Plataforma (Software-Hardware): {platform.platform()}")
print(f"Versión de Python {sys.version}")
print(f"Versión de TensorFlow: {tf.__version__}")
print(f"versión de Pandas {pd.__version__}")
print(f"versión de Numpy {np.__version__}")
print(f"versión de Keras {keras.__version__}")
print(f"Versión de Scikit-Learn {sk.__version__}")
gpu = len(tf.config.list_physical_devices('GPU'))>0
print("GPU está", "Disponible" if gpu else "No Disponible")
#---------------------------------------------------------
# Out:
# Plataforma (Software-Hardware): Windows-10-10.0.19045-SP0
# Versión de Python 3.11.4 (tags/v3.11.4:d2340ef, Jun  7 2023, 05:45:37) [MSC v.1934 64 bit (AMD64)]
# Versión de TensorFlow: 2.13.0
# versión de Pandas 2.0.1
# versión de Numpy 1.23.5
# versión de Keras 2.13.1
# Versión de Scikit-Learn 1.2.2
# GPU está No Disponible

# %% [markdown]
# ## Cargamos las librerias necesarias

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import keras
from keras.utils import to_categorical
from keras.models import Sequential
from tensorflow.keras.layers import Input
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Convolution2D, MaxPooling2D
from tensorflow.keras.activations import relu
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## Cargamos las imagenes

# %%
import os
import cv2
import numpy as np
from PIL import Image

altura, longitud = 100, 100

def cargar_y_redimensionar_imagenes(ruta):
    imagenes_redimensionadas = []
    for archivo in os.listdir(ruta):
        archivo_ruta = os.path.join(ruta, archivo)
        # Verificamos si el archivo es una imagen válida antes de abrirlo con OpenCV
        imagen = cv2.imread(archivo_ruta)
        if imagen is not None and len(imagen.shape) == 3 and imagen.shape[2] == 3:
            imagen = cv2.resize(imagen, (altura, longitud))
            imagenes_redimensionadas.append(imagen)
    return imagenes_redimensionadas

# Rutas de los directorios de imágenes
ruta_mercantes = './datos/mercantes'
ruta_otros = './datos/otros'

# Cargar y redimensionar imágenes de mercantes y otros
imagenes_mercantes = cargar_y_redimensionar_imagenes(ruta_mercantes)
imagenes_otros = cargar_y_redimensionar_imagenes(ruta_otros)

# Obtener la cantidad de imágenes en cada directorio
dircount = [len(imagenes_mercantes), len(imagenes_otros)]

print('Imagenes en cada directorio:', dircount)
print('Suma Total de imagenes en subdirectorios:', sum(dircount))
# Out:
# Imagenes en cada directorio: [56, 35]
# Suma Total de imagenes en subdirectorios: 91

# %% [markdown]
# ## Crear etiquetas y clases
#
# **Creamos los labels con valor 1 para mercante y 0 para otros**

# %%
# Crear una lista de etiquetas (0 para mercantes, 1 para otros)
etiquetas_mercantes = [0] * len(imagenes_mercantes)
etiquetas_otros = [1] * len(imagenes_otros)

# Combinar las imágenes y etiquetas en un solo conjunto de datos
imagenes = imagenes_mercantes + imagenes_otros
etiquetas = etiquetas_mercantes + etiquetas_otros

# %% [markdown]
# ## Muestra de Imágenes:

# %%
# Muestra de Etiqueta Mercante:
import matplotlib.pyplot as plt
plt.imshow(plt.imread('datos/mercantes/10.jpg'))
plt.title("Imagen con etiqueta Mercante")
# Out:
# Text(0.5, 1.0, 'Imagen con etiqueta Mercante')

# %%
# Muestra de Etiqueta Otros:
import matplotlib.pyplot as plt
plt.imshow(plt.imread('datos/otros/11.jpg'))
plt.title("Imagen con etiqueta Otros")
# Out:
# Text(0.5, 1.0, 'Imagen con etiqueta Otros')

# %% [markdown]
# ## Creamos sets de Entrenamiento y Test

# %%
# Convertir a arreglos NumPy
X = np.array(imagenes, dtype=np.uint8)
y = np.array(etiquetas)

# Dividir los datos en conjuntos de entrenamiento y validación (80% para entrenamiento, 20% para validación)
train_X, valid_X, train_label, valid_label = train_test_split(X, y, test_size=0.3, random_state=218) #num de cadete

train_X = train_X / 255.
valid_X = valid_X / 255.

# Find the unique numbers from the train labels
classes = np.unique(train_label)
nClasses = len(classes)
print('Total number of outputs:', nClasses)
print('Output classes:', classes)

train_label_one_hot = to_categorical(train_label, num_classes=nClasses)
valid_label_one_hot = to_categorical(valid_label, num_classes=nClasses)
# Out:
# Total number of outputs: 2
# Output classes: [0 1]

# %% [markdown]
# ## Data augmentation

# %%
# Configurar las transformaciones de data augmentation
data_augmentation = ImageDataGenerator(
    rotation_range=20,         # Rango de rotación aleatoria (en grados)
    width_shift_range=0.2,     # Rango de traslación horizontal aleatoria (como fracción del ancho total)
    height_shift_range=0.2,    # Rango de traslación vertical aleatoria (como fracción del alto total)
    shear_range=0.2,           # Rango de cizallamiento (shear) aleatorio
    zoom_range=0.2,            # Rango de zoom aleatorio
    horizontal_flip=True,      # Volteo horizontal aleatorio
    fill_mode='nearest'        # Modo de rellenado para las transformaciones
)

# %% [markdown]
# ## Creamos la red neuronal de 4 capas

# %% [markdown]
# ### Dropout (0.3)

# %%
INIT_LR = 0.0001#1e-3 

filtrosConv1=32 #despoues de la 1ra conv, la imagen va a tener prof de 32
filtrosConv2=64 #despjes de la 2da, tendra 64
filtrosConv3=128
filtrosConv4=256
tamano_filtro1=(5,5)
tamano_filtro2=(5,5)
tamano_filtro3=(3,3)
tamano_filtro4=(3,3)
tamano_pool=(2,2)

modelo1 = Sequential(name='dropout_0.3')
modelo1.add(Convolution2D(filtrosConv1, tamano_filtro1, padding='same', input_shape=(altura,longitud,3),activation='relu'))
modelo1.add(MaxPooling2D(pool_size=tamano_pool))

#segunda capa de convolucion (), seguida de una capa de max pooling
modelo1.add(Convolution2D(filtrosConv2, tamano_filtro2, padding='same', activation='relu'))
modelo1.add(MaxPooling2D(pool_size=tamano_pool))

modelo1.add(Convolution2D(filtrosConv3, tamano_filtro3, padding='same', activation='relu'))
modelo1.add(MaxPooling2D(pool_size=tamano_pool))

modelo1.add(Convolution2D(filtrosConv4, tamano_filtro4, padding='same', activation='relu'))

#capa que aplana la imagen (1D)
modelo1.add(Flatten())

#capa normal, de 256 neuronas
modelo1.add(Dense(256,activation='relu'))

#capa que apagara el 50% de las neuronas en cada paso, para evitar el overfitting
modelo1.add(Dropout(0.3))

#ultima capa, que son 2 neuronas (una por clase) donde dara % prob da cada clase
modelo1.add(Dense(nClasses,activation='softmax'))

#con Graphviz se puede hacer un diagrama de flujo para ver la logica del sistema
modelo1.summary()

modelo1.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adam(learning_rate=INIT_LR),metrics=['accuracy'])
# Out:
# Model: "dropout_0.3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 100, 100, 32)      2432
#
#  max_pooling2d_9 (MaxPoolin  (None, 50, 50, 32)        0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 50, 50, 64)        51264
#
#  max_pooling2d_10 (MaxPooli  (None, 25, 25, 64)        0
#  ng2D)
#
#  conv2d_14 (Conv2D)          (None, 25, 25, 128)       73856
#
#  max_pooling2d_11 (MaxPooli  (None, 12, 12, 128)       0
#  ng2D)
#
#  conv2d_15 (Conv2D)          (None, 12, 12, 256)       295168
#
#  flatten_3 (Flatten)         (None, 36864)             0
#
#  dense_6 (Dense)             (None, 256)               9437440
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 9860674 (37.62 MB)
# Trainable params: 9860674 (37.62 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Dropout (0.5)

# %%
INIT_LR = 0.0001#1e-3 

filtrosConv1=32 #despoues de la 1ra conv, la imagen va a tener prof de 32
filtrosConv2=64 #despjes de la 2da, tendra 64
filtrosConv3=128
filtrosConv4=256
tamano_filtro1=(5,5)
tamano_filtro2=(5,5)
tamano_filtro3=(3,3)
tamano_filtro4=(3,3)
tamano_pool=(2,2)

modelo2 = Sequential(name='dropout_0.3')
modelo2.add(Convolution2D(filtrosConv1, tamano_filtro1, padding='same', input_shape=(altura,longitud,3),activation='relu'))
modelo2.add(MaxPooling2D(pool_size=tamano_pool))

#segunda capa de convolucion (), seguida de una capa de max pooling
modelo2.add(Convolution2D(filtrosConv2, tamano_filtro2, padding='same', activation='relu'))
modelo2.add(MaxPooling2D(pool_size=tamano_pool))

modelo2.add(Convolution2D(filtrosConv3, tamano_filtro3, padding='same', activation='relu'))
modelo2.add(MaxPooling2D(pool_size=tamano_pool))

modelo2.add(Convolution2D(filtrosConv4, tamano_filtro4, padding='same', activation='relu'))

#capa que aplana la imagen (1D)
modelo2.add(Flatten())

#capa normal, de 256 neuronas
modelo2.add(Dense(256,activation='relu'))

#capa que apagara el 50% de las neuronas en cada paso, para evitar el overfitting
modelo2.add(Dropout(0.5))

#ultima capa, que son 2 neuronas (una por clase) donde dara % prob da cada clase
modelo2.add(Dense(nClasses,activation='softmax'))

#con Graphviz se puede hacer un diagrama de flujo para ver la logica del sistema
modelo2.summary()

modelo2.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adam(learning_rate=INIT_LR),metrics=['accuracy'])
# Out:
# Model: "dropout_0.3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_16 (Conv2D)          (None, 100, 100, 32)      2432
#
#  max_pooling2d_12 (MaxPooli  (None, 50, 50, 32)        0
#  ng2D)
#
#  conv2d_17 (Conv2D)          (None, 50, 50, 64)        51264
#
#  max_pooling2d_13 (MaxPooli  (None, 25, 25, 64)        0
#  ng2D)
#
#  conv2d_18 (Conv2D)          (None, 25, 25, 128)       73856
#
#  max_pooling2d_14 (MaxPooli  (None, 12, 12, 128)       0
#  ng2D)
#
#  conv2d_19 (Conv2D)          (None, 12, 12, 256)       295168
#
#  flatten_4 (Flatten)         (None, 36864)             0
#
#  dense_8 (Dense)             (None, 256)               9437440
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_9 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 9860674 (37.62 MB)
# Trainable params: 9860674 (37.62 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Dropout (0.7)

# %%
INIT_LR = 0.0001#1e-3 

filtrosConv1=32 #despoues de la 1ra conv, la imagen va a tener prof de 32
filtrosConv2=64 #despues de la 2da, tendra 64
filtrosConv3=128
filtrosConv4=256
tamano_filtro1=(5,5)
tamano_filtro2=(5,5)
tamano_filtro3=(3,3)
tamano_filtro4=(3,3)
tamano_pool=(2,2)

modelo3 = Sequential(name='dropout_0.3')
modelo3.add(Convolution2D(filtrosConv1, tamano_filtro1, padding='same', input_shape=(altura,longitud,3),activation='relu'))
modelo3.add(MaxPooling2D(pool_size=tamano_pool))

#segunda capa de convolucion (), seguida de una capa de max pooling
modelo3.add(Convolution2D(filtrosConv2, tamano_filtro2, padding='same', activation='relu'))
modelo3.add(MaxPooling2D(pool_size=tamano_pool))

modelo3.add(Convolution2D(filtrosConv3, tamano_filtro3, padding='same', activation='relu'))
modelo3.add(MaxPooling2D(pool_size=tamano_pool))

modelo3.add(Convolution2D(filtrosConv4, tamano_filtro4, padding='same', activation='relu'))

#capa que aplana la imagen (1D)
modelo3.add(Flatten())

#capa normal, de 256 neuronas
modelo3.add(Dense(256,activation='relu'))

#capa que apagara el 70% de las neuronas en cada paso, para evitar el overfitting
modelo3.add(Dropout(0.8))

#ultima capa, que son 2 neuronas (una por clase) donde dara % prob da cada clase
modelo3.add(Dense(nClasses,activation='softmax'))

#con Graphviz se puede hacer un diagrama de flujo para ver la logica del sistema
modelo3.summary()

modelo3.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adam(learning_rate=INIT_LR),metrics=['accuracy'])
# Out:
# Model: "dropout_0.3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_32 (Conv2D)          (None, 100, 100, 32)      2432
#
#  max_pooling2d_24 (MaxPooli  (None, 50, 50, 32)        0
#  ng2D)
#
#  conv2d_33 (Conv2D)          (None, 50, 50, 64)        51264
#
#  max_pooling2d_25 (MaxPooli  (None, 25, 25, 64)        0
#  ng2D)
#
#  conv2d_34 (Conv2D)          (None, 25, 25, 128)       73856
#
#  max_pooling2d_26 (MaxPooli  (None, 12, 12, 128)       0
#  ng2D)
#
#  conv2d_35 (Conv2D)          (None, 12, 12, 256)       295168
#
#  flatten_8 (Flatten)         (None, 36864)             0
#
#  dense_16 (Dense)            (None, 256)               9437440
#
#  dropout_8 (Dropout)         (None, 256)               0
#
#  dense_17 (Dense)            (None, 2)                 514
#
# =================================================================
# Total params: 9860674 (37.62 MB)
# Trainable params: 9860674 (37.62 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Entrenamos la red

# %% [markdown]
# ### Dropout 0.3

# %%
epochs = 100
batch_size = 32

# Crear el generador de datos para el conjunto de entrenamiento con data augmentation
train_data_generator = data_augmentation.flow(train_X, train_label_one_hot, batch_size=batch_size)

## Modifica el train_x para incluir las imagenes del train_data_generator
history1=modelo1.fit(train_data_generator, steps_per_epoch=len(train_X) // batch_size, epochs=epochs, verbose=1, validation_data=(valid_X, valid_label_one_hot))
# Out:
# Epoch 1/200
# 1/1 [==============================] - 3s 3s/step - loss: 0.6899 - accuracy: 0.6250 - val_loss: 0.6669 - val_accuracy: 0.6364
# Epoch 2/200
# 1/1 [==============================] - 1s 659ms/step - loss: 0.6419 - accuracy: 0.7500 - val_loss: 0.6591 - val_accuracy: 0.6364
# Epoch 3/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6996 - accuracy: 0.5312 - val_loss: 0.6586 - val_accuracy: 0.6364
# Epoch 4/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6553 - accuracy: 0.6250 - val_loss: 0.6590 - val_accuracy: 0.6364
# Epoch 5/200
# 1/1 [==============================] - 1s 595ms/step - loss: 0.4167 - accuracy: 1.0000 - val_loss: 0.6728 - val_accuracy: 0.6364
# Epoch 6/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.7051 - accuracy: 0.5625 - val_loss: 0.6847 - val_accuracy: 0.6364
# Epoch 7/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6583 - accuracy: 0.6250 - val_loss: 0.6917 - val_accuracy: 0.6364
# Epoch 8/200
# 1/1 [==============================] - 1s 587ms/step - loss: 0.7881 - accuracy: 0.5000 - val_loss: 0.6838 - val_accuracy: 0.6364
# Epoch 9/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.7161 - accuracy: 0.5625 - val_loss: 0.6711 - val_accuracy: 0.6364
# Epoch 10/200
# 1/1 [==============================] - 1s 659ms/step - loss: 0.5385 - accuracy: 0.7500 - val_loss: 0.6660 - val_accuracy: 0.6364
# Epoch 11/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6722 - accuracy: 0.5938 - val_loss: 0.6600 - val_accuracy: 0.6364
# Epoch 12/200
# 1/1 [==============================] - 1s 591ms/step - loss: 0.5858 - accuracy: 0.7500 - val_loss: 0.6568 - val_accuracy: 0.6364
# Epoch 13/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6644 - accuracy: 0.5938 - val_loss: 0.6535 - val_accuracy: 0.6364
# Epoch 14/200
# 1/1 [==============================] - 1s 600ms/step - loss: 0.6094 - accuracy: 0.7500 - val_loss: 0.6522 - val_accuracy: 0.6364
# Epoch 15/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6891 - accuracy: 0.5312 - val_loss: 0.6498 - val_accuracy: 0.6364
# Epoch 16/200
# 1/1 [==============================] - 1s 664ms/step - loss: 0.7790 - accuracy: 0.5000 - val_loss: 0.6466 - val_accuracy: 0.6364
# Epoch 17/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6533 - accuracy: 0.5938 - val_loss: 0.6446 - val_accuracy: 0.6364
# Epoch 18/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6584 - accuracy: 0.5625 - val_loss: 0.6435 - val_accuracy: 0.6364
# Epoch 19/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6620 - accuracy: 0.5625 - val_loss: 0.6431 - val_accuracy: 0.6364
# Epoch 20/200
# 1/1 [==============================] - 1s 596ms/step - loss: 0.7004 - accuracy: 0.5000 - val_loss: 0.6434 - val_accuracy: 0.6364
# Epoch 21/200
# 1/1 [==============================] - 1s 605ms/step - loss: 0.6331 - accuracy: 0.7500 - val_loss: 0.6432 - val_accuracy: 0.6364
# Epoch 22/200
# 1/1 [==============================] - 1s 599ms/step - loss: 0.6670 - accuracy: 0.5000 - val_loss: 0.6425 - val_accuracy: 0.6364
# Epoch 23/200
# 1/1 [==============================] - 1s 625ms/step - loss: 0.6124 - accuracy: 0.7500 - val_loss: 0.6403 - val_accuracy: 0.6364
# Epoch 24/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6546 - accuracy: 0.5938 - val_loss: 0.6376 - val_accuracy: 0.6364
# Epoch 25/200
# 1/1 [==============================] - 1s 597ms/step - loss: 0.5817 - accuracy: 0.7500 - val_loss: 0.6337 - val_accuracy: 0.6364
# Epoch 26/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6545 - accuracy: 0.5625 - val_loss: 0.6309 - val_accuracy: 0.6364
# Epoch 27/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6256 - accuracy: 0.5938 - val_loss: 0.6298 - val_accuracy: 0.6364
# Epoch 28/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6261 - accuracy: 0.5938 - val_loss: 0.6305 - val_accuracy: 0.6364
# Epoch 29/200
# 1/1 [==============================] - 1s 593ms/step - loss: 0.6279 - accuracy: 0.5000 - val_loss: 0.6332 - val_accuracy: 0.6364
# Epoch 30/200
# 1/1 [==============================] - 1s 588ms/step - loss: 0.5378 - accuracy: 0.7500 - val_loss: 0.6433 - val_accuracy: 0.6364
# Epoch 31/200
# 1/1 [==============================] - 1s 602ms/step - loss: 0.8808 - accuracy: 0.2500 - val_loss: 0.6408 - val_accuracy: 0.6364
# Epoch 32/200
# 1/1 [==============================] - 1s 614ms/step - loss: 0.4259 - accuracy: 0.7500 - val_loss: 0.6437 - val_accuracy: 0.6364
# Epoch 33/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6147 - accuracy: 0.6250 - val_loss: 0.6436 - val_accuracy: 0.6364
# Epoch 34/200
# 1/1 [==============================] - 1s 608ms/step - loss: 0.6093 - accuracy: 0.5000 - val_loss: 0.6380 - val_accuracy: 0.6364
# Epoch 35/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6537 - accuracy: 0.5625 - val_loss: 0.6296 - val_accuracy: 0.6364
# Epoch 36/200
# 1/1 [==============================] - 1s 595ms/step - loss: 0.9045 - accuracy: 0.2500 - val_loss: 0.6206 - val_accuracy: 0.6364
# Epoch 37/200
# 1/1 [==============================] - 1s 643ms/step - loss: 0.5321 - accuracy: 0.7500 - val_loss: 0.6185 - val_accuracy: 0.6364
# Epoch 38/200
# 1/1 [==============================] - 1s 638ms/step - loss: 0.4736 - accuracy: 0.7500 - val_loss: 0.6178 - val_accuracy: 0.6364
# Epoch 39/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6111 - accuracy: 0.5938 - val_loss: 0.6171 - val_accuracy: 0.6364
# Epoch 40/200
# 1/1 [==============================] - 1s 611ms/step - loss: 0.5655 - accuracy: 0.7500 - val_loss: 0.6150 - val_accuracy: 0.6364
# Epoch 41/200
# 1/1 [==============================] - 1s 597ms/step - loss: 0.6844 - accuracy: 0.2500 - val_loss: 0.6132 - val_accuracy: 0.6364
# Epoch 42/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6570 - accuracy: 0.5312 - val_loss: 0.6110 - val_accuracy: 0.6364
# Epoch 43/200
# 1/1 [==============================] - 1s 607ms/step - loss: 0.6600 - accuracy: 0.5000 - val_loss: 0.6077 - val_accuracy: 0.6364
# Epoch 44/200
# 1/1 [==============================] - 1s 599ms/step - loss: 0.6210 - accuracy: 0.5000 - val_loss: 0.6041 - val_accuracy: 0.6364
# Epoch 45/200
# 1/1 [==============================] - 1s 605ms/step - loss: 0.5301 - accuracy: 0.7500 - val_loss: 0.6009 - val_accuracy: 0.6364
# Epoch 46/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6119 - accuracy: 0.5625 - val_loss: 0.5976 - val_accuracy: 0.6364
# Epoch 47/200
# 1/1 [==============================] - 1s 614ms/step - loss: 0.5144 - accuracy: 0.5000 - val_loss: 0.5939 - val_accuracy: 0.6364
# Epoch 48/200
# 1/1 [==============================] - 1s 602ms/step - loss: 0.5613 - accuracy: 0.7500 - val_loss: 0.5899 - val_accuracy: 0.6364
# Epoch 49/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.5912 - accuracy: 0.6562 - val_loss: 0.5869 - val_accuracy: 0.6364
# Epoch 50/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.5858 - accuracy: 0.6875 - val_loss: 0.5853 - val_accuracy: 0.6364
# Epoch 51/200
# 1/1 [==============================] - 1s 610ms/step - loss: 0.5901 - accuracy: 0.7500 - val_loss: 0.5920 - val_accuracy: 0.6364
# Epoch 52/200
# 1/1 [==============================] - 1s 652ms/step - loss: 0.6872 - accuracy: 0.2500 - val_loss: 0.5928 - val_accuracy: 0.6364
# Epoch 53/200
# 1/1 [==============================] - 1s 617ms/step - loss: 0.4983 - accuracy: 0.7500 - val_loss: 0.6061 - val_accuracy: 0.6364
# Epoch 54/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.5391 - accuracy: 0.6250 - val_loss: 0.6311 - val_accuracy: 0.6364
# Epoch 55/200
# 1/1 [==============================] - 1s 603ms/step - loss: 0.7428 - accuracy: 0.5000 - val_loss: 0.6037 - val_accuracy: 0.6364
# Epoch 56/200
# 1/1 [==============================] - 1s 650ms/step - loss: 0.5622 - accuracy: 0.7500 - val_loss: 0.5922 - val_accuracy: 0.6545
# Epoch 57/200
# 1/1 [==============================] - 1s 597ms/step - loss: 0.2911 - accuracy: 1.0000 - val_loss: 0.5894 - val_accuracy: 0.6545
# Epoch 58/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.5664 - accuracy: 0.5625 - val_loss: 0.5837 - val_accuracy: 0.6545
# Epoch 59/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.5724 - accuracy: 0.6562 - val_loss: 0.5756 - val_accuracy: 0.6545
# Epoch 60/200
# 1/1 [==============================] - 1s 607ms/step - loss: 0.3779 - accuracy: 0.7500 - val_loss: 0.5658 - val_accuracy: 0.6545
# Epoch 61/200
# 1/1 [==============================] - 1s 610ms/step - loss: 0.4375 - accuracy: 1.0000 - val_loss: 0.5752 - val_accuracy: 0.6545
# Epoch 62/200
# 1/1 [==============================] - 1s 602ms/step - loss: 0.3881 - accuracy: 0.7500 - val_loss: 0.6031 - val_accuracy: 0.6545
# Epoch 63/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.5586 - accuracy: 0.6250 - val_loss: 0.6323 - val_accuracy: 0.6545
# Epoch 64/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.5752 - accuracy: 0.5938 - val_loss: 0.6467 - val_accuracy: 0.6364
# Epoch 65/200
# 1/1 [==============================] - 1s 586ms/step - loss: 0.2147 - accuracy: 1.0000 - val_loss: 0.7025 - val_accuracy: 0.6364
# Epoch 66/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.5399 - accuracy: 0.5938 - val_loss: 0.7247 - val_accuracy: 0.6364
# Epoch 67/200
# 1/1 [==============================] - 1s 593ms/step - loss: 1.1478 - accuracy: 0.2500 - val_loss: 0.6269 - val_accuracy: 0.6545
# Epoch 68/200
# 1/1 [==============================] - 1s 623ms/step - loss: 1.0876 - accuracy: 0.2500 - val_loss: 0.5292 - val_accuracy: 0.6727
# Epoch 69/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.4804 - accuracy: 0.7500 - val_loss: 0.5133 - val_accuracy: 0.7818
# Epoch 70/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.4936 - accuracy: 0.9375 - val_loss: 0.5356 - val_accuracy: 0.7818
# Epoch 71/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.5325 - accuracy: 0.9688 - val_loss: 0.5655 - val_accuracy: 0.8364
# Epoch 72/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6129 - accuracy: 0.7188 - val_loss: 0.5891 - val_accuracy: 0.8000
# Epoch 73/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.5984 - accuracy: 0.7188 - val_loss: 0.5998 - val_accuracy: 0.8182
# Epoch 74/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6149 - accuracy: 0.6562 - val_loss: 0.6010 - val_accuracy: 0.8182
# Epoch 75/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6148 - accuracy: 0.6875 - val_loss: 0.5940 - val_accuracy: 0.8182
# Epoch 76/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6148 - accuracy: 0.6562 - val_loss: 0.5813 - val_accuracy: 0.8364
# Epoch 77/200
# 1/1 [==============================] - 1s 615ms/step - loss: 0.6297 - accuracy: 0.7500 - val_loss: 0.5638 - val_accuracy: 0.8182
# Epoch 78/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.5759 - accuracy: 0.8438 - val_loss: 0.5457 - val_accuracy: 0.7455
# Epoch 79/200
# 1/1 [==============================] - 1s 612ms/step - loss: 0.3879 - accuracy: 0.7500 - val_loss: 0.5323 - val_accuracy: 0.7273
# Epoch 80/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.5194 - accuracy: 0.9062 - val_loss: 0.5492 - val_accuracy: 0.6364
# Epoch 81/200
# 1/1 [==============================] - 1s 599ms/step - loss: 0.7333 - accuracy: 0.5000 - val_loss: 0.5697 - val_accuracy: 0.6182
# Epoch 82/200
# 1/1 [==============================] - 1s 604ms/step - loss: 0.2763 - accuracy: 1.0000 - val_loss: 0.6378 - val_accuracy: 0.6364
# Epoch 83/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6175 - accuracy: 0.5625 - val_loss: 0.6728 - val_accuracy: 0.6364
# Epoch 84/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6094 - accuracy: 0.5625 - val_loss: 0.6586 - val_accuracy: 0.6364
# Epoch 85/200
# 1/1 [==============================] - 1s 596ms/step - loss: 0.4277 - accuracy: 0.7500 - val_loss: 0.6402 - val_accuracy: 0.6364
# Epoch 86/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.5089 - accuracy: 0.6562 - val_loss: 0.6076 - val_accuracy: 0.6364
# Epoch 87/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6009 - accuracy: 0.5625 - val_loss: 0.5694 - val_accuracy: 0.6182
# Epoch 88/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.5192 - accuracy: 0.6250 - val_loss: 0.5434 - val_accuracy: 0.6364
# Epoch 89/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.4824 - accuracy: 0.6875 - val_loss: 0.5272 - val_accuracy: 0.6364
# Epoch 90/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.5104 - accuracy: 0.7188 - val_loss: 0.5159 - val_accuracy: 0.6545
# Epoch 91/200
# 1/1 [==============================] - 1s 602ms/step - loss: 0.7074 - accuracy: 0.2500 - val_loss: 0.5073 - val_accuracy: 0.6545
# Epoch 92/200
# 1/1 [==============================] - 1s 614ms/step - loss: 0.6725 - accuracy: 0.7500 - val_loss: 0.5007 - val_accuracy: 0.6909
# Epoch 93/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.4878 - accuracy: 0.8750 - val_loss: 0.4963 - val_accuracy: 0.7273
# Epoch 94/200
# 1/1 [==============================] - 1s 604ms/step - loss: 0.6965 - accuracy: 0.5000 - val_loss: 0.4927 - val_accuracy: 0.7273
# Epoch 95/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.5452 - accuracy: 0.7812 - val_loss: 0.4900 - val_accuracy: 0.7273
# Epoch 96/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.4856 - accuracy: 0.8438 - val_loss: 0.4863 - val_accuracy: 0.7273
# Epoch 97/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.5219 - accuracy: 0.8750 - val_loss: 0.4814 - val_accuracy: 0.7273
# Epoch 98/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.4896 - accuracy: 0.8438 - val_loss: 0.4760 - val_accuracy: 0.7273
# Epoch 99/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.4730 - accuracy: 0.8438 - val_loss: 0.4723 - val_accuracy: 0.7091
# Epoch 100/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.4827 - accuracy: 0.8125 - val_loss: 0.4740 - val_accuracy: 0.7273
# Epoch 101/200
# 1/1 [==============================] - 1s 591ms/step - loss: 0.3187 - accuracy: 1.0000 - val_loss: 0.4850 - val_accuracy: 0.7273
# Epoch 102/200
# 1/1 [==============================] - 1s 653ms/step - loss: 0.4097 - accuracy: 1.0000 - val_loss: 0.5211 - val_accuracy: 0.6909
# Epoch 103/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.4481 - accuracy: 0.8438 - val_loss: 0.5663 - val_accuracy: 0.6909
# Epoch 104/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.5153 - accuracy: 0.8125 - val_loss: 0.5976 - val_accuracy: 0.6727
# Epoch 105/200
# 1/1 [==============================] - 1s 596ms/step - loss: 0.4746 - accuracy: 0.5000 - val_loss: 0.6256 - val_accuracy: 0.6909
# Epoch 106/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.4902 - accuracy: 0.7812 - val_loss: 0.5974 - val_accuracy: 0.6909
# Epoch 107/200
# 1/1 [==============================] - 1s 607ms/step - loss: 0.0747 - accuracy: 1.0000 - val_loss: 0.6018 - val_accuracy: 0.6909
# Epoch 108/200
# 1/1 [==============================] - 1s 660ms/step - loss: 0.6086 - accuracy: 0.7500 - val_loss: 0.5486 - val_accuracy: 0.7273
# Epoch 109/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.4609 - accuracy: 0.8438 - val_loss: 0.5078 - val_accuracy: 0.7273
# Epoch 110/200
# 1/1 [==============================] - 1s 614ms/step - loss: 0.8341 - accuracy: 0.7500 - val_loss: 0.4418 - val_accuracy: 0.7273
# Epoch 111/200
# 1/1 [==============================] - 1s 718ms/step - loss: 0.4004 - accuracy: 1.0000 - val_loss: 0.4266 - val_accuracy: 0.8000
# Epoch 112/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.4106 - accuracy: 0.7812 - val_loss: 0.4343 - val_accuracy: 0.8182
# Epoch 113/200
# 1/1 [==============================] - 1s 619ms/step - loss: 0.4805 - accuracy: 0.7500 - val_loss: 0.4518 - val_accuracy: 0.8182
# Epoch 114/200
# 1/1 [==============================] - 1s 630ms/step - loss: 0.3126 - accuracy: 1.0000 - val_loss: 0.4590 - val_accuracy: 0.8182
# Epoch 115/200
# 1/1 [==============================] - 1s 623ms/step - loss: 0.3158 - accuracy: 1.0000 - val_loss: 0.4584 - val_accuracy: 0.8182
# Epoch 116/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.4875 - accuracy: 0.8125 - val_loss: 0.4473 - val_accuracy: 0.8182
# Epoch 117/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.5028 - accuracy: 0.7812 - val_loss: 0.4303 - val_accuracy: 0.8000
# Epoch 118/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.4528 - accuracy: 0.8438 - val_loss: 0.4202 - val_accuracy: 0.7818
# Epoch 119/200
# 1/1 [==============================] - 1s 604ms/step - loss: 0.3517 - accuracy: 1.0000 - val_loss: 0.4271 - val_accuracy: 0.7455
# Epoch 120/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.3888 - accuracy: 0.9062 - val_loss: 0.4566 - val_accuracy: 0.7636
# Epoch 121/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.3944 - accuracy: 0.8750 - val_loss: 0.5092 - val_accuracy: 0.7455
# Epoch 122/200
# 1/1 [==============================] - 1s 606ms/step - loss: 0.5435 - accuracy: 0.7500 - val_loss: 0.5055 - val_accuracy: 0.7455
# Epoch 123/200
# 1/1 [==============================] - 1s 602ms/step - loss: 0.4656 - accuracy: 0.7500 - val_loss: 0.4460 - val_accuracy: 0.7455
# Epoch 124/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.3316 - accuracy: 0.9375 - val_loss: 0.4078 - val_accuracy: 0.7455
# Epoch 125/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.3746 - accuracy: 0.8438 - val_loss: 0.3886 - val_accuracy: 0.8000
# Epoch 126/200
# 1/1 [==============================] - 1s 683ms/step - loss: 0.4960 - accuracy: 0.7500 - val_loss: 0.3793 - val_accuracy: 0.8182
# Epoch 127/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.3786 - accuracy: 0.9062 - val_loss: 0.3760 - val_accuracy: 0.8182
# Epoch 128/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.3333 - accuracy: 0.9062 - val_loss: 0.3797 - val_accuracy: 0.8000
# Epoch 129/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.3938 - accuracy: 0.8438 - val_loss: 0.4084 - val_accuracy: 0.7818
# Epoch 130/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.2855 - accuracy: 0.8750 - val_loss: 0.4606 - val_accuracy: 0.7455
# Epoch 131/200
# 1/1 [==============================] - 1s 610ms/step - loss: 0.4394 - accuracy: 0.7500 - val_loss: 0.6290 - val_accuracy: 0.7455
# Epoch 132/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.3895 - accuracy: 0.8750 - val_loss: 0.7696 - val_accuracy: 0.6364
# Epoch 133/200
# 1/1 [==============================] - 1s 600ms/step - loss: 0.1143 - accuracy: 1.0000 - val_loss: 0.9072 - val_accuracy: 0.6364
# Epoch 134/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.4669 - accuracy: 0.8438 - val_loss: 0.7438 - val_accuracy: 0.6545
# Epoch 135/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.2796 - accuracy: 0.9375 - val_loss: 0.5651 - val_accuracy: 0.7455
# Epoch 136/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.2422 - accuracy: 0.9375 - val_loss: 0.4526 - val_accuracy: 0.8000
# Epoch 137/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.2688 - accuracy: 0.9062 - val_loss: 0.4086 - val_accuracy: 0.8364
# Epoch 138/200
# 1/1 [==============================] - 1s 600ms/step - loss: 0.1937 - accuracy: 1.0000 - val_loss: 0.3957 - val_accuracy: 0.8364
# Epoch 139/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.2534 - accuracy: 0.9062 - val_loss: 0.3956 - val_accuracy: 0.8364
# Epoch 140/200
# 1/1 [==============================] - 1s 596ms/step - loss: 0.1821 - accuracy: 1.0000 - val_loss: 0.3939 - val_accuracy: 0.8182
# Epoch 141/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.2736 - accuracy: 0.9062 - val_loss: 0.3959 - val_accuracy: 0.8182
# Epoch 142/200
# 1/1 [==============================] - 1s 654ms/step - loss: 0.4194 - accuracy: 0.7500 - val_loss: 0.4133 - val_accuracy: 0.8364
# Epoch 143/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.4079 - accuracy: 0.8750 - val_loss: 0.4513 - val_accuracy: 0.8182
# Epoch 144/200
# 1/1 [==============================] - 1s 599ms/step - loss: 0.0869 - accuracy: 1.0000 - val_loss: 0.5153 - val_accuracy: 0.8000
# Epoch 145/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.3904 - accuracy: 0.9062 - val_loss: 0.5923 - val_accuracy: 0.7636
# Epoch 146/200
# 1/1 [==============================] - 1s 629ms/step - loss: 0.1122 - accuracy: 1.0000 - val_loss: 0.6517 - val_accuracy: 0.7273
# Epoch 147/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.3561 - accuracy: 0.8438 - val_loss: 0.6672 - val_accuracy: 0.7273
# Epoch 148/200
# 1/1 [==============================] - 1s 611ms/step - loss: 0.1394 - accuracy: 1.0000 - val_loss: 0.6329 - val_accuracy: 0.7818
# Epoch 149/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.2275 - accuracy: 0.9375 - val_loss: 0.5694 - val_accuracy: 0.8000
# Epoch 150/200
# 1/1 [==============================] - 1s 600ms/step - loss: 0.0887 - accuracy: 1.0000 - val_loss: 0.5232 - val_accuracy: 0.8000
# Epoch 151/200
# 1/1 [==============================] - 1s 644ms/step - loss: 0.4453 - accuracy: 0.7500 - val_loss: 0.4361 - val_accuracy: 0.8364
# Epoch 152/200
# 1/1 [==============================] - 1s 618ms/step - loss: 0.2005 - accuracy: 1.0000 - val_loss: 0.4130 - val_accuracy: 0.8182
# Epoch 153/200
# 1/1 [==============================] - 1s 645ms/step - loss: 0.4529 - accuracy: 0.7500 - val_loss: 0.4114 - val_accuracy: 0.8182
# Epoch 154/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.3760 - accuracy: 0.7812 - val_loss: 0.4125 - val_accuracy: 0.8182
# Epoch 155/200
# 1/1 [==============================] - 1s 602ms/step - loss: 0.2401 - accuracy: 1.0000 - val_loss: 0.4214 - val_accuracy: 0.8182
# Epoch 156/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.2777 - accuracy: 0.9062 - val_loss: 0.4513 - val_accuracy: 0.8364
# Epoch 157/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.3401 - accuracy: 0.8438 - val_loss: 0.5331 - val_accuracy: 0.8182
# Epoch 158/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.2221 - accuracy: 0.9062 - val_loss: 0.6713 - val_accuracy: 0.7636
# Epoch 159/200
# 1/1 [==============================] - 1s 607ms/step - loss: 0.1825 - accuracy: 1.0000 - val_loss: 0.7778 - val_accuracy: 0.7636
# Epoch 160/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.2555 - accuracy: 0.9375 - val_loss: 0.8204 - val_accuracy: 0.7636
# Epoch 161/200
# 1/1 [==============================] - 1s 606ms/step - loss: 0.0772 - accuracy: 1.0000 - val_loss: 0.8324 - val_accuracy: 0.7455
# Epoch 162/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.2871 - accuracy: 0.8125 - val_loss: 0.7551 - val_accuracy: 0.7636
# Epoch 163/200
# 1/1 [==============================] - 1s 597ms/step - loss: 0.2370 - accuracy: 1.0000 - val_loss: 0.5477 - val_accuracy: 0.8182
# Epoch 164/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.1719 - accuracy: 0.9375 - val_loss: 0.4767 - val_accuracy: 0.8364
# Epoch 165/200
# 1/1 [==============================] - 1s 610ms/step - loss: 0.1285 - accuracy: 1.0000 - val_loss: 0.4573 - val_accuracy: 0.8364
# Epoch 166/200
# 1/1 [==============================] - 1s 631ms/step - loss: 0.0877 - accuracy: 1.0000 - val_loss: 0.4414 - val_accuracy: 0.8182
# Epoch 167/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.3354 - accuracy: 0.8750 - val_loss: 0.4384 - val_accuracy: 0.8182
# Epoch 168/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.2292 - accuracy: 0.9375 - val_loss: 0.4451 - val_accuracy: 0.8182
# Epoch 169/200
# 1/1 [==============================] - 1s 844ms/step - loss: 0.0579 - accuracy: 1.0000 - val_loss: 0.4527 - val_accuracy: 0.8182
# Epoch 170/200
# 1/1 [==============================] - 1s 758ms/step - loss: 0.1056 - accuracy: 1.0000 - val_loss: 0.4585 - val_accuracy: 0.8182
# Epoch 171/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.3254 - accuracy: 0.9062 - val_loss: 0.4744 - val_accuracy: 0.8364
# Epoch 172/200
# 1/1 [==============================] - 1s 647ms/step - loss: 0.3852 - accuracy: 0.7500 - val_loss: 0.5460 - val_accuracy: 0.8000
# Epoch 173/200
# 1/1 [==============================] - 1s 659ms/step - loss: 0.0365 - accuracy: 1.0000 - val_loss: 0.6881 - val_accuracy: 0.7818
# Epoch 174/200
# 1/1 [==============================] - 1s 939ms/step - loss: 0.0874 - accuracy: 1.0000 - val_loss: 0.9644 - val_accuracy: 0.7455
# Epoch 175/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.1887 - accuracy: 0.8750 - val_loss: 1.1378 - val_accuracy: 0.7273
# Epoch 176/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.4811 - accuracy: 0.8438 - val_loss: 0.8410 - val_accuracy: 0.7636
# Epoch 177/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.1778 - accuracy: 0.9062 - val_loss: 0.6233 - val_accuracy: 0.8182
# Epoch 178/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.1422 - accuracy: 1.0000 - val_loss: 0.5362 - val_accuracy: 0.8364
# Epoch 179/200
# 1/1 [==============================] - 1s 685ms/step - loss: 0.0711 - accuracy: 1.0000 - val_loss: 0.5068 - val_accuracy: 0.8364
# Epoch 180/200
# 1/1 [==============================] - 1s 683ms/step - loss: 0.2285 - accuracy: 0.7500 - val_loss: 0.5034 - val_accuracy: 0.8364
# Epoch 181/200
# 1/1 [==============================] - 1s 652ms/step - loss: 0.0941 - accuracy: 1.0000 - val_loss: 0.5050 - val_accuracy: 0.8364
# Epoch 182/200
# 1/1 [==============================] - 1s 643ms/step - loss: 0.4624 - accuracy: 0.7500 - val_loss: 0.5278 - val_accuracy: 0.8364
# Epoch 183/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.1151 - accuracy: 0.9688 - val_loss: 0.5614 - val_accuracy: 0.8364
# Epoch 184/200
# 1/1 [==============================] - 1s 649ms/step - loss: 0.0814 - accuracy: 1.0000 - val_loss: 0.6127 - val_accuracy: 0.8364
# Epoch 185/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.1566 - accuracy: 0.9375 - val_loss: 0.6686 - val_accuracy: 0.8000
# Epoch 186/200
# 1/1 [==============================] - 1s 728ms/step - loss: 0.1912 - accuracy: 1.0000 - val_loss: 0.7049 - val_accuracy: 0.8000
# Epoch 187/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.1789 - accuracy: 0.9375 - val_loss: 0.7253 - val_accuracy: 0.8000
# Epoch 188/200
# 1/1 [==============================] - 1s 644ms/step - loss: 0.1298 - accuracy: 1.0000 - val_loss: 0.8061 - val_accuracy: 0.8000
# Epoch 189/200
# 1/1 [==============================] - 1s 641ms/step - loss: 0.0596 - accuracy: 1.0000 - val_loss: 0.9280 - val_accuracy: 0.7455
# Epoch 190/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.2096 - accuracy: 0.9062 - val_loss: 0.9973 - val_accuracy: 0.7455
# Epoch 191/200
# 1/1 [==============================] - 1s 635ms/step - loss: 0.1703 - accuracy: 1.0000 - val_loss: 1.0347 - val_accuracy: 0.7455
# Epoch 192/200
# 1/1 [==============================] - 1s 634ms/step - loss: 0.1214 - accuracy: 1.0000 - val_loss: 1.0409 - val_accuracy: 0.7636
# Epoch 193/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.2229 - accuracy: 0.8750 - val_loss: 0.9532 - val_accuracy: 0.7636
# Epoch 194/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.1907 - accuracy: 0.9375 - val_loss: 0.8158 - val_accuracy: 0.8000
# Epoch 195/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.0954 - accuracy: 0.9688 - val_loss: 0.7295 - val_accuracy: 0.8182
# Epoch 196/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.1276 - accuracy: 0.9375 - val_loss: 0.6785 - val_accuracy: 0.8182
# Epoch 197/200
# 1/1 [==============================] - 1s 639ms/step - loss: 0.1103 - accuracy: 1.0000 - val_loss: 0.6336 - val_accuracy: 0.8364
# Epoch 198/200
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0312 - accuracy: 1.0000 - val_loss: 0.6119 - val_accuracy: 0.8364
# Epoch 199/200
# 1/1 [==============================] - 1s 634ms/step - loss: 0.0163 - accuracy: 1.0000 - val_loss: 0.5986 - val_accuracy: 0.8364
# Epoch 200/200
# 1/1 [==============================] - 1s 648ms/step - loss: 0.0423 - accuracy: 1.0000 - val_loss: 0.5896 - val_accuracy: 0.8182

# %% [markdown]
# ### Dropout 0.5

# %%
# Crear el generador de datos para el conjunto de entrenamiento con data augmentation
train_data_generator = data_augmentation.flow(train_X, train_label_one_hot, batch_size=batch_size)

## Modifica el train_x para incluir las imagenes del train_data_generator
history2=modelo2.fit(train_data_generator, steps_per_epoch=len(train_X) // batch_size, epochs=epochs, verbose=1, validation_data=(valid_X, valid_label_one_hot))
# Out:
# Epoch 1/200
# 1/1 [==============================] - 3s 3s/step - loss: 0.6752 - accuracy: 1.0000 - val_loss: 0.6980 - val_accuracy: 0.3636
# Epoch 2/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6997 - accuracy: 0.4688 - val_loss: 0.6772 - val_accuracy: 0.6364
# Epoch 3/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6965 - accuracy: 0.5625 - val_loss: 0.6652 - val_accuracy: 0.6364
# Epoch 4/200
# 1/1 [==============================] - 1s 592ms/step - loss: 0.7159 - accuracy: 0.5000 - val_loss: 0.6613 - val_accuracy: 0.6364
# Epoch 5/200
# 1/1 [==============================] - 1s 605ms/step - loss: 0.7059 - accuracy: 0.5000 - val_loss: 0.6609 - val_accuracy: 0.6364
# Epoch 6/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6671 - accuracy: 0.5625 - val_loss: 0.6608 - val_accuracy: 0.6364
# Epoch 7/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6678 - accuracy: 0.5938 - val_loss: 0.6603 - val_accuracy: 0.6364
# Epoch 8/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6958 - accuracy: 0.5000 - val_loss: 0.6604 - val_accuracy: 0.6364
# Epoch 9/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6839 - accuracy: 0.5938 - val_loss: 0.6599 - val_accuracy: 0.6364
# Epoch 10/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6790 - accuracy: 0.5312 - val_loss: 0.6594 - val_accuracy: 0.6364
# Epoch 11/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6634 - accuracy: 0.5938 - val_loss: 0.6582 - val_accuracy: 0.6364
# Epoch 12/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6801 - accuracy: 0.5000 - val_loss: 0.6571 - val_accuracy: 0.6364
# Epoch 13/200
# 1/1 [==============================] - 1s 606ms/step - loss: 0.7057 - accuracy: 0.2500 - val_loss: 0.6591 - val_accuracy: 0.6364
# Epoch 14/200
# 1/1 [==============================] - 1s 596ms/step - loss: 0.7071 - accuracy: 0.2500 - val_loss: 0.6629 - val_accuracy: 0.6364
# Epoch 15/200
# 1/1 [==============================] - 1s 618ms/step - loss: 0.7016 - accuracy: 0.7500 - val_loss: 0.6657 - val_accuracy: 0.6364
# Epoch 16/200
# 1/1 [==============================] - 1s 583ms/step - loss: 0.6377 - accuracy: 0.5000 - val_loss: 0.6689 - val_accuracy: 0.6364
# Epoch 17/200
# 1/1 [==============================] - 1s 632ms/step - loss: 0.6607 - accuracy: 0.7500 - val_loss: 0.6668 - val_accuracy: 0.6364
# Epoch 18/200
# 1/1 [==============================] - 1s 621ms/step - loss: 0.6903 - accuracy: 0.2500 - val_loss: 0.6636 - val_accuracy: 0.6364
# Epoch 19/200
# 1/1 [==============================] - 1s 813ms/step - loss: 0.6987 - accuracy: 0.5000 - val_loss: 0.6612 - val_accuracy: 0.6364
# Epoch 20/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.6516 - accuracy: 0.7188 - val_loss: 0.6575 - val_accuracy: 0.6364
# Epoch 21/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6790 - accuracy: 0.5625 - val_loss: 0.6545 - val_accuracy: 0.6364
# Epoch 22/200
# 1/1 [==============================] - 1s 670ms/step - loss: 0.6040 - accuracy: 0.7500 - val_loss: 0.6509 - val_accuracy: 0.6364
# Epoch 23/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6518 - accuracy: 0.5625 - val_loss: 0.6503 - val_accuracy: 0.6364
# Epoch 24/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6422 - accuracy: 0.5938 - val_loss: 0.6521 - val_accuracy: 0.6364
# Epoch 25/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6333 - accuracy: 0.5938 - val_loss: 0.6554 - val_accuracy: 0.6364
# Epoch 26/200
# 1/1 [==============================] - 1s 592ms/step - loss: 0.5265 - accuracy: 1.0000 - val_loss: 0.6701 - val_accuracy: 0.6364
# Epoch 27/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6867 - accuracy: 0.5938 - val_loss: 0.6863 - val_accuracy: 0.6364
# Epoch 28/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.7055 - accuracy: 0.5625 - val_loss: 0.6906 - val_accuracy: 0.6364
# Epoch 29/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.7147 - accuracy: 0.5625 - val_loss: 0.6812 - val_accuracy: 0.6364
# Epoch 30/200
# 1/1 [==============================] - 1s 535ms/step - loss: 0.5419 - accuracy: 0.7500 - val_loss: 0.6779 - val_accuracy: 0.6364
# Epoch 31/200
# 1/1 [==============================] - 1s 647ms/step - loss: 0.4996 - accuracy: 0.7500 - val_loss: 0.6796 - val_accuracy: 0.6364
# Epoch 32/200
# 1/1 [==============================] - 1s 536ms/step - loss: 0.5335 - accuracy: 0.7500 - val_loss: 0.6835 - val_accuracy: 0.6364
# Epoch 33/200
# 1/1 [==============================] - 1s 528ms/step - loss: 0.4931 - accuracy: 0.7500 - val_loss: 0.6941 - val_accuracy: 0.6364
# Epoch 34/200
# 1/1 [==============================] - 1s 997ms/step - loss: 0.7133 - accuracy: 0.5625 - val_loss: 0.6913 - val_accuracy: 0.6364
# Epoch 35/200
# 1/1 [==============================] - 1s 992ms/step - loss: 0.6780 - accuracy: 0.5938 - val_loss: 0.6807 - val_accuracy: 0.6364
# Epoch 36/200
# 1/1 [==============================] - 1s 532ms/step - loss: 0.7701 - accuracy: 0.5000 - val_loss: 0.6621 - val_accuracy: 0.6364
# Epoch 37/200
# 1/1 [==============================] - 1s 565ms/step - loss: 0.3691 - accuracy: 1.0000 - val_loss: 0.6600 - val_accuracy: 0.6364
# Epoch 38/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6386 - accuracy: 0.5938 - val_loss: 0.6567 - val_accuracy: 0.6364
# Epoch 39/200
# 1/1 [==============================] - 1s 533ms/step - loss: 0.3895 - accuracy: 0.7500 - val_loss: 0.6579 - val_accuracy: 0.6364
# Epoch 40/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6090 - accuracy: 0.6250 - val_loss: 0.6579 - val_accuracy: 0.6364
# Epoch 41/200
# 1/1 [==============================] - 1s 989ms/step - loss: 0.6417 - accuracy: 0.5938 - val_loss: 0.6552 - val_accuracy: 0.6364
# Epoch 42/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6694 - accuracy: 0.5938 - val_loss: 0.6498 - val_accuracy: 0.6364
# Epoch 43/200
# 1/1 [==============================] - 1s 553ms/step - loss: 0.9042 - accuracy: 0.2500 - val_loss: 0.6395 - val_accuracy: 0.6364
# Epoch 44/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6390 - accuracy: 0.5938 - val_loss: 0.6332 - val_accuracy: 0.6364
# Epoch 45/200
# 1/1 [==============================] - 1s 547ms/step - loss: 0.6461 - accuracy: 0.5000 - val_loss: 0.6294 - val_accuracy: 0.6364
# Epoch 46/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6211 - accuracy: 0.5938 - val_loss: 0.6278 - val_accuracy: 0.6364
# Epoch 47/200
# 1/1 [==============================] - 1s 611ms/step - loss: 0.6346 - accuracy: 0.5000 - val_loss: 0.6269 - val_accuracy: 0.6364
# Epoch 48/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6338 - accuracy: 0.6875 - val_loss: 0.6260 - val_accuracy: 0.6364
# Epoch 49/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6429 - accuracy: 0.5625 - val_loss: 0.6247 - val_accuracy: 0.6364
# Epoch 50/200
# 1/1 [==============================] - 1s 534ms/step - loss: 0.6103 - accuracy: 0.7500 - val_loss: 0.6223 - val_accuracy: 0.6364
# Epoch 51/200
# 1/1 [==============================] - 1s 993ms/step - loss: 0.6312 - accuracy: 0.5312 - val_loss: 0.6203 - val_accuracy: 0.6364
# Epoch 52/200
# 1/1 [==============================] - 1s 527ms/step - loss: 0.5486 - accuracy: 1.0000 - val_loss: 0.6207 - val_accuracy: 0.6364
# Epoch 53/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6270 - accuracy: 0.5312 - val_loss: 0.6258 - val_accuracy: 0.6364
# Epoch 54/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6126 - accuracy: 0.5938 - val_loss: 0.6358 - val_accuracy: 0.6364
# Epoch 55/200
# 1/1 [==============================] - 1s 529ms/step - loss: 0.6727 - accuracy: 0.5000 - val_loss: 0.6425 - val_accuracy: 0.6364
# Epoch 56/200
# 1/1 [==============================] - 1s 536ms/step - loss: 0.6347 - accuracy: 0.5000 - val_loss: 0.6463 - val_accuracy: 0.6364
# Epoch 57/200
# 1/1 [==============================] - 1s 574ms/step - loss: 0.7875 - accuracy: 0.5000 - val_loss: 0.6292 - val_accuracy: 0.6364
# Epoch 58/200
# 1/1 [==============================] - 1s 528ms/step - loss: 0.5926 - accuracy: 0.7500 - val_loss: 0.6152 - val_accuracy: 0.6364
# Epoch 59/200
# 1/1 [==============================] - 1s 624ms/step - loss: 0.7637 - accuracy: 0.2500 - val_loss: 0.6090 - val_accuracy: 0.6364
# Epoch 60/200
# 1/1 [==============================] - 1s 536ms/step - loss: 0.7236 - accuracy: 0.2500 - val_loss: 0.6124 - val_accuracy: 0.6545
# Epoch 61/200
# 1/1 [==============================] - 1s 526ms/step - loss: 0.6483 - accuracy: 0.5000 - val_loss: 0.6196 - val_accuracy: 0.7091
# Epoch 62/200
# 1/1 [==============================] - 1s 995ms/step - loss: 0.6353 - accuracy: 0.7812 - val_loss: 0.6258 - val_accuracy: 0.7273
# Epoch 63/200
# 1/1 [==============================] - 1s 520ms/step - loss: 0.6579 - accuracy: 0.5000 - val_loss: 0.6297 - val_accuracy: 0.7273
# Epoch 64/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6622 - accuracy: 0.5938 - val_loss: 0.6310 - val_accuracy: 0.7091
# Epoch 65/200
# 1/1 [==============================] - 1s 523ms/step - loss: 0.6569 - accuracy: 1.0000 - val_loss: 0.6329 - val_accuracy: 0.7455
# Epoch 66/200
# 1/1 [==============================] - 1s 530ms/step - loss: 0.6455 - accuracy: 0.7500 - val_loss: 0.6299 - val_accuracy: 0.7091
# Epoch 67/200
# 1/1 [==============================] - 1s 525ms/step - loss: 0.6261 - accuracy: 1.0000 - val_loss: 0.6231 - val_accuracy: 0.7273
# Epoch 68/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6279 - accuracy: 0.6875 - val_loss: 0.6176 - val_accuracy: 0.6364
# Epoch 69/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6125 - accuracy: 0.8125 - val_loss: 0.6151 - val_accuracy: 0.6364
# Epoch 70/200
# 1/1 [==============================] - 1s 554ms/step - loss: 0.5478 - accuracy: 1.0000 - val_loss: 0.6205 - val_accuracy: 0.6364
# Epoch 71/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6523 - accuracy: 0.5312 - val_loss: 0.6329 - val_accuracy: 0.6364
# Epoch 72/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6035 - accuracy: 0.5625 - val_loss: 0.6519 - val_accuracy: 0.6364
# Epoch 73/200
# 1/1 [==============================] - 1s 994ms/step - loss: 0.6032 - accuracy: 0.5625 - val_loss: 0.6680 - val_accuracy: 0.6364
# Epoch 74/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6271 - accuracy: 0.5312 - val_loss: 0.6710 - val_accuracy: 0.6364
# Epoch 75/200
# 1/1 [==============================] - 1s 527ms/step - loss: 0.9373 - accuracy: 0.2500 - val_loss: 0.6411 - val_accuracy: 0.6364
# Epoch 76/200
# 1/1 [==============================] - 1s 991ms/step - loss: 0.6025 - accuracy: 0.5938 - val_loss: 0.6209 - val_accuracy: 0.6182
# Epoch 77/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6199 - accuracy: 0.5938 - val_loss: 0.6077 - val_accuracy: 0.6364
# Epoch 78/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6370 - accuracy: 0.5625 - val_loss: 0.5996 - val_accuracy: 0.6364
# Epoch 79/200
# 1/1 [==============================] - 1s 525ms/step - loss: 0.4930 - accuracy: 0.7500 - val_loss: 0.5949 - val_accuracy: 0.6364
# Epoch 80/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.6032 - accuracy: 0.7500 - val_loss: 0.5912 - val_accuracy: 0.6727
# Epoch 81/200
# 1/1 [==============================] - 1s 548ms/step - loss: 0.7188 - accuracy: 0.5000 - val_loss: 0.5880 - val_accuracy: 0.7091
# Epoch 82/200
# 1/1 [==============================] - 1s 513ms/step - loss: 0.5154 - accuracy: 0.7500 - val_loss: 0.5857 - val_accuracy: 0.6909
# Epoch 83/200
# 1/1 [==============================] - 1s 998ms/step - loss: 0.5579 - accuracy: 0.8438 - val_loss: 0.5824 - val_accuracy: 0.7273
# Epoch 84/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.5745 - accuracy: 0.8750 - val_loss: 0.5780 - val_accuracy: 0.7273
# Epoch 85/200
# 1/1 [==============================] - 1s 523ms/step - loss: 0.5714 - accuracy: 1.0000 - val_loss: 0.5733 - val_accuracy: 0.7091
# Epoch 86/200
# 1/1 [==============================] - 1s 538ms/step - loss: 0.7088 - accuracy: 0.5000 - val_loss: 0.5717 - val_accuracy: 0.7091
# Epoch 87/200
# 1/1 [==============================] - 1s 540ms/step - loss: 0.5588 - accuracy: 1.0000 - val_loss: 0.5698 - val_accuracy: 0.7636
# Epoch 88/200
# 1/1 [==============================] - 1s 991ms/step - loss: 0.6022 - accuracy: 0.7188 - val_loss: 0.5654 - val_accuracy: 0.8000
# Epoch 89/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.5744 - accuracy: 0.8125 - val_loss: 0.5577 - val_accuracy: 0.7636
# Epoch 90/200
# 1/1 [==============================] - 1s 536ms/step - loss: 0.6210 - accuracy: 0.7500 - val_loss: 0.5503 - val_accuracy: 0.6909
# Epoch 91/200
# 1/1 [==============================] - 1s 531ms/step - loss: 0.5074 - accuracy: 0.7500 - val_loss: 0.5659 - val_accuracy: 0.6545
# Epoch 92/200
# 1/1 [==============================] - 1s 526ms/step - loss: 0.6169 - accuracy: 1.0000 - val_loss: 0.5635 - val_accuracy: 0.6909
# Epoch 93/200
# 1/1 [==============================] - 1s 627ms/step - loss: 0.6430 - accuracy: 0.5000 - val_loss: 0.5491 - val_accuracy: 0.7091
# Epoch 94/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.5378 - accuracy: 0.7812 - val_loss: 0.5381 - val_accuracy: 0.6909
# Epoch 95/200
# 1/1 [==============================] - 1s 525ms/step - loss: 0.5435 - accuracy: 1.0000 - val_loss: 0.5370 - val_accuracy: 0.7091
# Epoch 96/200
# 1/1 [==============================] - 1s 993ms/step - loss: 0.4946 - accuracy: 0.9062 - val_loss: 0.5416 - val_accuracy: 0.7091
# Epoch 97/200
# 1/1 [==============================] - 1s 522ms/step - loss: 0.6267 - accuracy: 0.7500 - val_loss: 0.5761 - val_accuracy: 0.6909
# Epoch 98/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.5077 - accuracy: 0.8125 - val_loss: 0.6210 - val_accuracy: 0.6545
# Epoch 99/200
# 1/1 [==============================] - 1s 995ms/step - loss: 0.4929 - accuracy: 0.7500 - val_loss: 0.6706 - val_accuracy: 0.6727
# Epoch 100/200
# 1/1 [==============================] - 1s 566ms/step - loss: 0.4299 - accuracy: 0.7500 - val_loss: 0.7926 - val_accuracy: 0.6182
# Epoch 101/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.5216 - accuracy: 0.6562 - val_loss: 0.7916 - val_accuracy: 0.6182
# Epoch 102/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.5150 - accuracy: 0.7500 - val_loss: 0.6898 - val_accuracy: 0.6727
# Epoch 103/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.5454 - accuracy: 0.7500 - val_loss: 0.5697 - val_accuracy: 0.7091
# Epoch 104/200
# 1/1 [==============================] - 1s 529ms/step - loss: 0.4386 - accuracy: 0.7500 - val_loss: 0.5079 - val_accuracy: 0.7455
# Epoch 105/200
# 1/1 [==============================] - 1s 525ms/step - loss: 0.6709 - accuracy: 0.5000 - val_loss: 0.4975 - val_accuracy: 0.7455
# Epoch 106/200
# 1/1 [==============================] - 1s 987ms/step - loss: 0.5340 - accuracy: 0.7500 - val_loss: 0.4974 - val_accuracy: 0.7818
# Epoch 107/200
# 1/1 [==============================] - 1s 998ms/step - loss: 0.5590 - accuracy: 0.6875 - val_loss: 0.4976 - val_accuracy: 0.7818
# Epoch 108/200
# 1/1 [==============================] - 1s 994ms/step - loss: 0.5114 - accuracy: 0.8750 - val_loss: 0.4968 - val_accuracy: 0.7455
# Epoch 109/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.5164 - accuracy: 0.8750 - val_loss: 0.4999 - val_accuracy: 0.7455
# Epoch 110/200
# 1/1 [==============================] - 1s 991ms/step - loss: 0.4790 - accuracy: 0.7812 - val_loss: 0.5148 - val_accuracy: 0.7636
# Epoch 111/200
# 1/1 [==============================] - 1s 537ms/step - loss: 0.6339 - accuracy: 0.7500 - val_loss: 0.5110 - val_accuracy: 0.7636
# Epoch 112/200
# 1/1 [==============================] - 1s 536ms/step - loss: 0.5972 - accuracy: 1.0000 - val_loss: 0.5031 - val_accuracy: 0.7636
# Epoch 113/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.4699 - accuracy: 0.8438 - val_loss: 0.5006 - val_accuracy: 0.7636
# Epoch 114/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.4625 - accuracy: 0.8125 - val_loss: 0.5061 - val_accuracy: 0.7636
# Epoch 115/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.4512 - accuracy: 0.8750 - val_loss: 0.5161 - val_accuracy: 0.7636
# Epoch 116/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.5462 - accuracy: 0.6875 - val_loss: 0.5289 - val_accuracy: 0.7455
# Epoch 117/200
# 1/1 [==============================] - 1s 610ms/step - loss: 0.8844 - accuracy: 0.2500 - val_loss: 0.4930 - val_accuracy: 0.7636
# Epoch 118/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4142 - accuracy: 0.9062 - val_loss: 0.4740 - val_accuracy: 0.7636
# Epoch 119/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.4076 - accuracy: 0.8750 - val_loss: 0.4639 - val_accuracy: 0.7455
# Epoch 120/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.4983 - accuracy: 0.7812 - val_loss: 0.4599 - val_accuracy: 0.7455
# Epoch 121/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.3863 - accuracy: 0.8438 - val_loss: 0.4640 - val_accuracy: 0.7636
# Epoch 122/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.3815 - accuracy: 0.9375 - val_loss: 0.4827 - val_accuracy: 0.7636
# Epoch 123/200
# 1/1 [==============================] - 1s 551ms/step - loss: 0.2704 - accuracy: 1.0000 - val_loss: 0.5423 - val_accuracy: 0.7455
# Epoch 124/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.3971 - accuracy: 0.8125 - val_loss: 0.6156 - val_accuracy: 0.7273
# Epoch 125/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.3920 - accuracy: 0.8438 - val_loss: 0.6911 - val_accuracy: 0.6909
# Epoch 126/200
# 1/1 [==============================] - 1s 638ms/step - loss: 0.7648 - accuracy: 0.5000 - val_loss: 0.4988 - val_accuracy: 0.7636
# Epoch 127/200
# 1/1 [==============================] - 1s 577ms/step - loss: 0.4666 - accuracy: 0.7500 - val_loss: 0.4241 - val_accuracy: 0.7818
# Epoch 128/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.3668 - accuracy: 0.8750 - val_loss: 0.4381 - val_accuracy: 0.8000
# Epoch 129/200
# 1/1 [==============================] - 1s 542ms/step - loss: 0.3357 - accuracy: 1.0000 - val_loss: 0.4552 - val_accuracy: 0.7818
# Epoch 130/200
# 1/1 [==============================] - 1s 553ms/step - loss: 0.5588 - accuracy: 0.7500 - val_loss: 0.4437 - val_accuracy: 0.8000
# Epoch 131/200
# 1/1 [==============================] - 1s 556ms/step - loss: 0.5959 - accuracy: 0.7500 - val_loss: 0.4251 - val_accuracy: 0.8000
# Epoch 132/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.4733 - accuracy: 0.7500 - val_loss: 0.4267 - val_accuracy: 0.7818
# Epoch 133/200
# 1/1 [==============================] - 1s 558ms/step - loss: 0.1736 - accuracy: 1.0000 - val_loss: 0.4606 - val_accuracy: 0.7636
# Epoch 134/200
# 1/1 [==============================] - 1s 545ms/step - loss: 0.3011 - accuracy: 1.0000 - val_loss: 0.5235 - val_accuracy: 0.7818
# Epoch 135/200
# 1/1 [==============================] - 1s 565ms/step - loss: 0.1960 - accuracy: 1.0000 - val_loss: 0.6117 - val_accuracy: 0.7636
# Epoch 136/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.2515 - accuracy: 0.9688 - val_loss: 0.7388 - val_accuracy: 0.7455
# Epoch 137/200
# 1/1 [==============================] - 1s 547ms/step - loss: 0.1769 - accuracy: 1.0000 - val_loss: 0.8313 - val_accuracy: 0.6909
# Epoch 138/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.3676 - accuracy: 0.8750 - val_loss: 0.8300 - val_accuracy: 0.7091
# Epoch 139/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.3413 - accuracy: 0.9062 - val_loss: 0.7606 - val_accuracy: 0.7455
# Epoch 140/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.4159 - accuracy: 0.8125 - val_loss: 0.6589 - val_accuracy: 0.7636
# Epoch 141/200
# 1/1 [==============================] - 1s 632ms/step - loss: 0.0927 - accuracy: 1.0000 - val_loss: 0.6020 - val_accuracy: 0.7818
# Epoch 142/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.2223 - accuracy: 0.9688 - val_loss: 0.5759 - val_accuracy: 0.7818
# Epoch 143/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.4200 - accuracy: 0.8125 - val_loss: 0.5541 - val_accuracy: 0.7818
# Epoch 144/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.2282 - accuracy: 0.8750 - val_loss: 0.5464 - val_accuracy: 0.7818
# Epoch 145/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.2480 - accuracy: 0.9375 - val_loss: 0.5812 - val_accuracy: 0.7818
# Epoch 146/200
# 1/1 [==============================] - 1s 556ms/step - loss: 0.3381 - accuracy: 1.0000 - val_loss: 0.5251 - val_accuracy: 0.8000
# Epoch 147/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.3171 - accuracy: 0.8750 - val_loss: 0.5037 - val_accuracy: 0.8000
# Epoch 148/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.4032 - accuracy: 0.7500 - val_loss: 0.5406 - val_accuracy: 0.8000
# Epoch 149/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.2557 - accuracy: 0.9062 - val_loss: 0.6346 - val_accuracy: 0.7818
# Epoch 150/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.2329 - accuracy: 0.9375 - val_loss: 0.7976 - val_accuracy: 0.7636
# Epoch 151/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.2522 - accuracy: 0.9375 - val_loss: 0.9438 - val_accuracy: 0.7636
# Epoch 152/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.3756 - accuracy: 0.8750 - val_loss: 0.9419 - val_accuracy: 0.7636
# Epoch 153/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.3402 - accuracy: 0.8438 - val_loss: 0.7906 - val_accuracy: 0.7636
# Epoch 154/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.2901 - accuracy: 0.9062 - val_loss: 0.6489 - val_accuracy: 0.7818
# Epoch 155/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.1639 - accuracy: 0.9375 - val_loss: 0.5593 - val_accuracy: 0.8182
# Epoch 156/200
# 1/1 [==============================] - 1s 528ms/step - loss: 0.5149 - accuracy: 0.7500 - val_loss: 0.6773 - val_accuracy: 0.7818
# Epoch 157/200
# 1/1 [==============================] - 1s 994ms/step - loss: 0.2347 - accuracy: 0.9375 - val_loss: 0.8127 - val_accuracy: 0.7636
# Epoch 158/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.1437 - accuracy: 0.9688 - val_loss: 0.9292 - val_accuracy: 0.7455
# Epoch 159/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.1831 - accuracy: 0.9375 - val_loss: 0.9192 - val_accuracy: 0.7455
# Epoch 160/200
# 1/1 [==============================] - 1s 539ms/step - loss: 0.3038 - accuracy: 0.7500 - val_loss: 0.6393 - val_accuracy: 0.7818
# Epoch 161/200
# 1/1 [==============================] - 1s 528ms/step - loss: 0.1114 - accuracy: 1.0000 - val_loss: 0.5141 - val_accuracy: 0.8364
# Epoch 162/200
# 1/1 [==============================] - 1s 980ms/step - loss: 0.2315 - accuracy: 0.9062 - val_loss: 0.4791 - val_accuracy: 0.8364
# Epoch 163/200
# 1/1 [==============================] - 1s 580ms/step - loss: 0.8720 - accuracy: 0.5000 - val_loss: 0.5601 - val_accuracy: 0.8182
# Epoch 164/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.3210 - accuracy: 0.9375 - val_loss: 0.7794 - val_accuracy: 0.7455
# Epoch 165/200
# 1/1 [==============================] - 1s 585ms/step - loss: 0.6865 - accuracy: 0.5000 - val_loss: 0.8697 - val_accuracy: 0.7455
# Epoch 166/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.1876 - accuracy: 0.9375 - val_loss: 0.9247 - val_accuracy: 0.7455
# Epoch 167/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.3054 - accuracy: 0.8750 - val_loss: 0.8709 - val_accuracy: 0.7455
# Epoch 168/200
# 1/1 [==============================] - 1s 605ms/step - loss: 0.5977 - accuracy: 0.5000 - val_loss: 0.5838 - val_accuracy: 0.8000
# Epoch 169/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.2229 - accuracy: 0.9375 - val_loss: 0.4896 - val_accuracy: 0.8364
# Epoch 170/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.2482 - accuracy: 0.8750 - val_loss: 0.4688 - val_accuracy: 0.8182
# Epoch 171/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.3012 - accuracy: 0.8750 - val_loss: 0.4658 - val_accuracy: 0.7818
# Epoch 172/200
# 1/1 [==============================] - 1s 559ms/step - loss: 0.0979 - accuracy: 1.0000 - val_loss: 0.4660 - val_accuracy: 0.7818
# Epoch 173/200
# 1/1 [==============================] - 1s 549ms/step - loss: 0.2802 - accuracy: 1.0000 - val_loss: 0.4655 - val_accuracy: 0.7818
# Epoch 174/200
# 1/1 [==============================] - 1s 558ms/step - loss: 0.2628 - accuracy: 1.0000 - val_loss: 0.4682 - val_accuracy: 0.8182
# Epoch 175/200
# 1/1 [==============================] - 1s 555ms/step - loss: 0.9638 - accuracy: 0.5000 - val_loss: 0.4980 - val_accuracy: 0.8364
# Epoch 176/200
# 1/1 [==============================] - 1s 550ms/step - loss: 0.4432 - accuracy: 0.5000 - val_loss: 0.6204 - val_accuracy: 0.7636
# Epoch 177/200
# 1/1 [==============================] - 1s 559ms/step - loss: 0.1604 - accuracy: 1.0000 - val_loss: 0.8928 - val_accuracy: 0.7455
# Epoch 178/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.2593 - accuracy: 0.9375 - val_loss: 1.1922 - val_accuracy: 0.7273
# Epoch 179/200
# 1/1 [==============================] - 1s 549ms/step - loss: 0.0944 - accuracy: 1.0000 - val_loss: 1.5281 - val_accuracy: 0.6727
# Epoch 180/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.5253 - accuracy: 0.7812 - val_loss: 1.4863 - val_accuracy: 0.6727
# Epoch 181/200
# 1/1 [==============================] - 1s 549ms/step - loss: 0.3981 - accuracy: 0.7500 - val_loss: 1.2550 - val_accuracy: 0.7091
# Epoch 182/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.2623 - accuracy: 0.8750 - val_loss: 1.0199 - val_accuracy: 0.6909
# Epoch 183/200
# 1/1 [==============================] - 1s 706ms/step - loss: 0.6214 - accuracy: 0.7500 - val_loss: 0.7028 - val_accuracy: 0.7636
# Epoch 184/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.1383 - accuracy: 1.0000 - val_loss: 0.5564 - val_accuracy: 0.8182
# Epoch 185/200
# 1/1 [==============================] - 1s 607ms/step - loss: 0.0196 - accuracy: 1.0000 - val_loss: 0.4964 - val_accuracy: 0.8182
# Epoch 186/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.2969 - accuracy: 0.8750 - val_loss: 0.4773 - val_accuracy: 0.8182
# Epoch 187/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.3057 - accuracy: 0.8438 - val_loss: 0.4720 - val_accuracy: 0.8182
# Epoch 188/200
# 1/1 [==============================] - 1s 548ms/step - loss: 0.5340 - accuracy: 0.7500 - val_loss: 0.4745 - val_accuracy: 0.8182
# Epoch 189/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.2922 - accuracy: 0.9062 - val_loss: 0.4817 - val_accuracy: 0.8000
# Epoch 190/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.3913 - accuracy: 0.8125 - val_loss: 0.5002 - val_accuracy: 0.8182
# Epoch 191/200
# 1/1 [==============================] - 1s 559ms/step - loss: 0.3105 - accuracy: 1.0000 - val_loss: 0.5459 - val_accuracy: 0.8182
# Epoch 192/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.3221 - accuracy: 0.8750 - val_loss: 0.6199 - val_accuracy: 0.7818
# Epoch 193/200
# 1/1 [==============================] - 1s 564ms/step - loss: 0.3702 - accuracy: 0.7500 - val_loss: 0.7199 - val_accuracy: 0.7636
# Epoch 194/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.2349 - accuracy: 0.9375 - val_loss: 0.8375 - val_accuracy: 0.7455
# Epoch 195/200
# 1/1 [==============================] - 1s 563ms/step - loss: 0.2972 - accuracy: 1.0000 - val_loss: 0.8871 - val_accuracy: 0.7455
# Epoch 196/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.3433 - accuracy: 0.8438 - val_loss: 0.8792 - val_accuracy: 0.7455
# Epoch 197/200
# 1/1 [==============================] - 1s 553ms/step - loss: 0.1255 - accuracy: 1.0000 - val_loss: 0.8644 - val_accuracy: 0.7455
# Epoch 198/200
# 1/1 [==============================] - 1s 547ms/step - loss: 0.4515 - accuracy: 0.7500 - val_loss: 0.8572 - val_accuracy: 0.7455
# Epoch 199/200
# 1/1 [==============================] - 1s 549ms/step - loss: 0.2110 - accuracy: 1.0000 - val_loss: 0.8354 - val_accuracy: 0.7455
# Epoch 200/200
# 1/1 [==============================] - 1s 1s/step - loss: 0.2467 - accuracy: 0.9062 - val_loss: 0.7909 - val_accuracy: 0.7455

# %% [markdown]
# ### Dropout 0.7

# %%
# Crear el generador de datos para el conjunto de entrenamiento con data augmentation
train_data_generator = data_augmentation.flow(train_X, train_label_one_hot, batch_size=batch_size)

## Modifica el train_x para incluir las imagenes del train_data_generator
history3=modelo3.fit(train_data_generator, steps_per_epoch=len(train_X) // batch_size, epochs=epochs, verbose=1, validation_data=(valid_X, valid_label_one_hot))
# Out:
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2056 - accuracy: 0.9032 - val_loss: 0.5823 - val_accuracy: 0.8571
# Epoch 2/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3245 - accuracy: 0.8750 - val_loss: 0.5195 - val_accuracy: 0.8214
# Epoch 3/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3305 - accuracy: 0.9032 - val_loss: 0.4969 - val_accuracy: 0.8571
# Epoch 4/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3542 - accuracy: 0.9032 - val_loss: 0.5155 - val_accuracy: 0.8214
# Epoch 5/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3090 - accuracy: 0.8387 - val_loss: 0.5801 - val_accuracy: 0.8571
# Epoch 6/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1589 - accuracy: 0.9688 - val_loss: 0.6927 - val_accuracy: 0.8571
# Epoch 7/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2669 - accuracy: 0.8750 - val_loss: 0.7231 - val_accuracy: 0.8571
# Epoch 8/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3056 - accuracy: 0.8125 - val_loss: 0.6661 - val_accuracy: 0.8571
# Epoch 9/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.2430 - accuracy: 0.9062 - val_loss: 0.6885 - val_accuracy: 0.8571
# Epoch 10/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2464 - accuracy: 0.8750 - val_loss: 0.7173 - val_accuracy: 0.8571
# Epoch 11/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2727 - accuracy: 0.8750 - val_loss: 0.8047 - val_accuracy: 0.8214
# Epoch 12/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2986 - accuracy: 0.8710 - val_loss: 0.8816 - val_accuracy: 0.8214
# Epoch 13/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2849 - accuracy: 0.9032 - val_loss: 0.8197 - val_accuracy: 0.8214
# Epoch 14/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1943 - accuracy: 0.9032 - val_loss: 0.8272 - val_accuracy: 0.8214
# Epoch 15/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3428 - accuracy: 0.8065 - val_loss: 0.7980 - val_accuracy: 0.8214
# Epoch 16/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3043 - accuracy: 0.8387 - val_loss: 0.6747 - val_accuracy: 0.8571
# Epoch 17/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3664 - accuracy: 0.8387 - val_loss: 0.5385 - val_accuracy: 0.8571
# Epoch 18/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2216 - accuracy: 0.9375 - val_loss: 0.4830 - val_accuracy: 0.8214
# Epoch 19/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2625 - accuracy: 0.9375 - val_loss: 0.5049 - val_accuracy: 0.8571
# Epoch 20/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2399 - accuracy: 0.9032 - val_loss: 0.6650 - val_accuracy: 0.8571
# Epoch 21/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2195 - accuracy: 0.9062 - val_loss: 0.9141 - val_accuracy: 0.8214
# Epoch 22/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3619 - accuracy: 0.8065 - val_loss: 0.7732 - val_accuracy: 0.8214
# Epoch 23/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2656 - accuracy: 0.8387 - val_loss: 0.6221 - val_accuracy: 0.8571
# Epoch 24/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3905 - accuracy: 0.8438 - val_loss: 0.5454 - val_accuracy: 0.8571
# Epoch 25/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2728 - accuracy: 0.9355 - val_loss: 0.5495 - val_accuracy: 0.8571
# Epoch 26/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2382 - accuracy: 0.9062 - val_loss: 0.6361 - val_accuracy: 0.8571
# Epoch 27/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1912 - accuracy: 0.9375 - val_loss: 0.8311 - val_accuracy: 0.8214
# Epoch 28/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1750 - accuracy: 0.9355 - val_loss: 0.8845 - val_accuracy: 0.8214
# Epoch 29/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.2133 - accuracy: 0.9062 - val_loss: 0.8748 - val_accuracy: 0.8214
# Epoch 30/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1858 - accuracy: 0.9355 - val_loss: 0.8405 - val_accuracy: 0.8214
# Epoch 31/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.4018 - accuracy: 0.8750 - val_loss: 0.7571 - val_accuracy: 0.8571
# Epoch 32/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1905 - accuracy: 0.9062 - val_loss: 0.6382 - val_accuracy: 0.8571
# Epoch 33/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2474 - accuracy: 0.8710 - val_loss: 0.5979 - val_accuracy: 0.8571
# Epoch 34/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2451 - accuracy: 0.9032 - val_loss: 0.6855 - val_accuracy: 0.8571
# Epoch 35/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2845 - accuracy: 0.8750 - val_loss: 0.7468 - val_accuracy: 0.8571
# Epoch 36/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1682 - accuracy: 0.9355 - val_loss: 0.8163 - val_accuracy: 0.8214
# Epoch 37/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3892 - accuracy: 0.8065 - val_loss: 0.8869 - val_accuracy: 0.8214
# Epoch 38/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3038 - accuracy: 0.8438 - val_loss: 0.8183 - val_accuracy: 0.8214
# Epoch 39/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3605 - accuracy: 0.8125 - val_loss: 0.5136 - val_accuracy: 0.8929
# Epoch 40/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2555 - accuracy: 0.9062 - val_loss: 0.4586 - val_accuracy: 0.8929
# Epoch 41/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2881 - accuracy: 0.8387 - val_loss: 0.5007 - val_accuracy: 0.9286
# Epoch 42/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2599 - accuracy: 0.8710 - val_loss: 0.6398 - val_accuracy: 0.8571
# Epoch 43/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3137 - accuracy: 0.9062 - val_loss: 0.7904 - val_accuracy: 0.8571
# Epoch 44/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2244 - accuracy: 0.8750 - val_loss: 0.9790 - val_accuracy: 0.8214
# Epoch 45/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2442 - accuracy: 0.9355 - val_loss: 1.0302 - val_accuracy: 0.8214
# Epoch 46/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1620 - accuracy: 0.9375 - val_loss: 0.8423 - val_accuracy: 0.8214
# Epoch 47/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2373 - accuracy: 0.8750 - val_loss: 0.6530 - val_accuracy: 0.8571
# Epoch 48/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3538 - accuracy: 0.8387 - val_loss: 0.4997 - val_accuracy: 0.9286
# Epoch 49/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2331 - accuracy: 0.9355 - val_loss: 0.4478 - val_accuracy: 0.8571
# Epoch 50/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3868 - accuracy: 0.7742 - val_loss: 0.4717 - val_accuracy: 0.8929
# Epoch 51/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3029 - accuracy: 0.8750 - val_loss: 0.5662 - val_accuracy: 0.8571
# Epoch 52/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3065 - accuracy: 0.8750 - val_loss: 0.8178 - val_accuracy: 0.8214
# Epoch 53/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3087 - accuracy: 0.9375 - val_loss: 0.8972 - val_accuracy: 0.8214
# Epoch 54/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1671 - accuracy: 0.9688 - val_loss: 0.6821 - val_accuracy: 0.8571
# Epoch 55/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2359 - accuracy: 0.9355 - val_loss: 0.5677 - val_accuracy: 0.8571
# Epoch 56/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2993 - accuracy: 0.8710 - val_loss: 0.5233 - val_accuracy: 0.8929
# Epoch 57/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2895 - accuracy: 0.8710 - val_loss: 0.5269 - val_accuracy: 0.8929
# Epoch 58/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3454 - accuracy: 0.8387 - val_loss: 0.5919 - val_accuracy: 0.8571
# Epoch 59/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3335 - accuracy: 0.9032 - val_loss: 0.6288 - val_accuracy: 0.8571
# Epoch 60/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2062 - accuracy: 0.8750 - val_loss: 0.6477 - val_accuracy: 0.8571
# Epoch 61/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2353 - accuracy: 0.9062 - val_loss: 0.6750 - val_accuracy: 0.8571
# Epoch 62/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3524 - accuracy: 0.8438 - val_loss: 0.6851 - val_accuracy: 0.8571
# Epoch 63/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2397 - accuracy: 0.9062 - val_loss: 0.7606 - val_accuracy: 0.8571
# Epoch 64/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3518 - accuracy: 0.8125 - val_loss: 0.6426 - val_accuracy: 0.8571
# Epoch 65/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2812 - accuracy: 0.8387 - val_loss: 0.6086 - val_accuracy: 0.8571
# Epoch 66/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3244 - accuracy: 0.8750 - val_loss: 0.5937 - val_accuracy: 0.8571
# Epoch 67/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2647 - accuracy: 0.9355 - val_loss: 0.5771 - val_accuracy: 0.8571
# Epoch 68/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2705 - accuracy: 0.9032 - val_loss: 0.5934 - val_accuracy: 0.8571
# Epoch 69/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1978 - accuracy: 0.9375 - val_loss: 0.6418 - val_accuracy: 0.8571
# Epoch 70/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1565 - accuracy: 0.9677 - val_loss: 0.6821 - val_accuracy: 0.8571
# Epoch 71/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3407 - accuracy: 0.8710 - val_loss: 0.6609 - val_accuracy: 0.8571
# Epoch 72/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1547 - accuracy: 0.9688 - val_loss: 0.6237 - val_accuracy: 0.8571
# Epoch 73/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1438 - accuracy: 0.9355 - val_loss: 0.6241 - val_accuracy: 0.8571
# Epoch 74/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2244 - accuracy: 0.9355 - val_loss: 0.5911 - val_accuracy: 0.8571
# Epoch 75/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2548 - accuracy: 0.9032 - val_loss: 0.5431 - val_accuracy: 0.8929
# Epoch 76/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3119 - accuracy: 0.9062 - val_loss: 0.5289 - val_accuracy: 0.8929
# Epoch 77/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2411 - accuracy: 0.8710 - val_loss: 0.5598 - val_accuracy: 0.8571
# Epoch 78/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2140 - accuracy: 0.8710 - val_loss: 0.6739 - val_accuracy: 0.8571
# Epoch 79/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2142 - accuracy: 0.9032 - val_loss: 0.7112 - val_accuracy: 0.8571
# Epoch 80/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.2388 - accuracy: 0.9062 - val_loss: 0.6898 - val_accuracy: 0.8571
# Epoch 81/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2423 - accuracy: 0.9062 - val_loss: 0.6248 - val_accuracy: 0.8571
# Epoch 82/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3652 - accuracy: 0.7812 - val_loss: 0.5604 - val_accuracy: 0.8571
# Epoch 83/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.1857 - accuracy: 0.9375 - val_loss: 0.5212 - val_accuracy: 0.9286
# Epoch 84/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.2176 - accuracy: 0.9355 - val_loss: 0.5489 - val_accuracy: 0.8929
# Epoch 85/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.2031 - accuracy: 0.9355 - val_loss: 0.5704 - val_accuracy: 0.8571
# Epoch 86/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.2878 - accuracy: 0.8387 - val_loss: 0.6548 - val_accuracy: 0.8571
# Epoch 87/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2639 - accuracy: 0.9062 - val_loss: 0.6831 - val_accuracy: 0.8571
# Epoch 88/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.1998 - accuracy: 0.9032 - val_loss: 0.7047 - val_accuracy: 0.8571
# Epoch 89/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2876 - accuracy: 0.8710 - val_loss: 0.8341 - val_accuracy: 0.8214
# Epoch 90/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.3417 - accuracy: 0.8387 - val_loss: 0.5392 - val_accuracy: 0.8929
# Epoch 91/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1949 - accuracy: 0.9375 - val_loss: 0.4225 - val_accuracy: 0.8571
# Epoch 92/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.5412 - accuracy: 0.7500 - val_loss: 0.4418 - val_accuracy: 0.8571
# Epoch 93/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1553 - accuracy: 0.9688 - val_loss: 0.5074 - val_accuracy: 0.9286
# Epoch 94/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3446 - accuracy: 0.8710 - val_loss: 0.7285 - val_accuracy: 0.8571
# Epoch 95/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2499 - accuracy: 0.8750 - val_loss: 1.1055 - val_accuracy: 0.8214
# Epoch 96/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3752 - accuracy: 0.8438 - val_loss: 0.9974 - val_accuracy: 0.8214
# Epoch 97/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.4092 - accuracy: 0.8387 - val_loss: 0.6751 - val_accuracy: 0.8571
# Epoch 98/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1881 - accuracy: 0.9375 - val_loss: 0.5267 - val_accuracy: 0.8929
# Epoch 99/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3145 - accuracy: 0.8750 - val_loss: 0.4692 - val_accuracy: 0.8929
# Epoch 100/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3806 - accuracy: 0.8750 - val_loss: 0.4655 - val_accuracy: 0.8929

# %% [markdown]
# ## Obtenemos las métricas de entrenamiento y validación, luego graficamos

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

def metricas(clases_reales, clases_predichas):
    matriz_conf=confusion_matrix(clases_reales, clases_predichas)
    accuracy=accuracy_score(clases_reales,clases_predichas)
    precision=precision_score(clases_reales,clases_predichas)
    recall=recall_score(clases_reales,clases_predichas)
    f1=f1_score(clases_reales,clases_predichas)
    return matriz_conf, accuracy, recall, precision, f1

def visualizar_metricas(clases_reales,clases_predichas, titulo):
    #Calculamos metricas con la funcion previa
    matriz, accuracy, recall, precision, f1=metricas(clases_reales,clases_predichas)

    #Graficamos
    plt.figure(figsize=(3,3))
    matriz=pd.DataFrame(matriz,columns=['0: Mercante', '1: Otro'])
    plt.matshow(matriz, cmap="Blues", vmin=0, vmax=10, fignum=1)
    plt.title("Reales")
    plt.ylabel("Predichas")
    plt.xticks(range(len(matriz.columns)), matriz.columns, rotation=45)
    plt.yticks(range(len(matriz.columns)), matriz.columns)
    etiquetas = (("Verdaderos\nnegativos", "Falsos\npositivos"),
                 ("Falsos\nnegativos", "Verdaderos\npositivos"))
    for i in range(len(matriz.columns)):
        for j in range(len(matriz.columns)):
            plt.text(i, j + 0.14, str(matriz.iloc[i, j]),
                     fontsize=30, ha="center", va="center")
            plt.text(i, j - 0.25, etiquetas[i][j],
                     fontsize=11.5, ha="center", va="center")           
    plt.text(1.60, -0.30, titulo, fontsize=25, c="red")
    plt.text(2.1, 0.10, "Accuracy: %0.2f" % accuracy, fontsize=20)
    plt.text(2.1, 0.40, "Precision: %0.2f" % precision, fontsize=20)
    plt.text(2.1, 0.70, "Recall: %0.2f" % recall, fontsize=20)
    plt.text(2.1, 1.00, "F1: %0.2f" % f1, fontsize=20)    
    plt.show()
    print("\n")

#print("\n")

#reales=[1,1,0,0,0,0,1,1]
#predichas=[1,1,0,1,0,1,1,1]

#visualizar_metricas(reales,predichas,'Métricas')

# %% [markdown]
# ## Métricas dropout 0.3

# %%
# Obtener las métricas de entrenamiento y validación
train_accuracy = history1.history['accuracy']
val_accuracy = history1.history['val_accuracy']
train_loss = history1.history['loss']
val_loss = history1.history['val_loss']
epochs_range = range(1, epochs + 1)

plt.figure(figsize=(20,6))

# Gráfica de precisión (accuracy)
plt.subplot(1,2,1)
plt.plot(epochs_range, train_accuracy, label='Training Accuracy', color='blue')
plt.plot(epochs_range, val_accuracy, label='Validation Accuracy', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy with 4 Layers and Dropot 0.3')
plt.legend()
plt.grid(True)

plt.subplot(1,2,2)
# Gráfica de pérdida (loss)
plt.plot(epochs_range, train_loss, label='Training Loss', color='blue')
plt.plot(epochs_range, val_loss, label='Validation Loss', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss with 4 Layers and Dropot 0.3')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Métricas dropout 0.5

# %%
# Obtener las métricas de entrenamiento y validación
train_accuracy = history2.history['accuracy']
val_accuracy = history2.history['val_accuracy']
train_loss = history2.history['loss']
val_loss = history2.history['val_loss']
epochs_range = range(1, epochs + 1)

plt.figure(figsize=(20,6))

# Gráfica de precisión (accuracy)
plt.subplot(1,2,1)
plt.plot(epochs_range, train_accuracy, label='Training Accuracy', color='blue')
plt.plot(epochs_range, val_accuracy, label='Validation Accuracy', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy with 4 Layers and Dropot 0.5')
plt.legend()
plt.grid(True)

plt.subplot(1,2,2)
# Gráfica de pérdida (loss)
plt.plot(epochs_range, train_loss, label='Training Loss', color='blue')
plt.plot(epochs_range, val_loss, label='Validation Loss', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss with 4 Layers and Dropot 0.5')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Métricas dropout 0.7

# %%
# Obtener las métricas de entrenamiento y validación
train_accuracy = history3.history['accuracy']
val_accuracy = history3.history['val_accuracy']
train_loss = history3.history['loss']
val_loss = history3.history['val_loss']
epochs_range = range(1, epochs + 1)

plt.figure(figsize=(20,6))

# Gráfica de precisión (accuracy)
plt.subplot(1,2,1)
plt.plot(epochs_range, train_accuracy, label='Training Accuracy', color='blue')
plt.plot(epochs_range, val_accuracy, label='Validation Accuracy', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy with 4 Layers and Dropot 0.8')
plt.legend()
plt.grid(True)

plt.subplot(1,2,2)
# Gráfica de pérdida (loss)
plt.plot(epochs_range, train_loss, label='Training Loss', color='blue')
plt.plot(epochs_range, val_loss, label='Validation Loss', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss with 4 Layers and Dropot 0.8')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Probamos la red

# %%
# Muestra de Etiqueta Mercante:
import matplotlib.pyplot as plt
plt.imshow(plt.imread('prueba/4.jpg'))

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage import color

directorio_imagen_prueba='./prueba/4.jpg'
# Carga la imagen de prueba
imagen_prueba = cv2.imread(directorio_imagen_prueba)
imagen_prueba = cv2.resize(imagen_prueba, (100, 100))

# OpenCV lee las imágenes en formato BGR, pero los modelos de Keras están entrenados con imágenes en formato RGB, por lo que es necesario convertir la imagen de BGR a RGB
imagen_prueba = cv2.cvtColor(imagen_prueba, cv2.COLOR_BGR2RGB)

# Convertir a float32 y normalizar
imagen_prueba = imagen_prueba.astype('float32') / 255.0

# Ajusta las dimensiones de la imagen para que sea compatible con la entrada del modelo
imagen_prueba = np.expand_dims(imagen_prueba, axis=0)

# Obtén las predicciones utilizando el modelo entrenado
predicciones = modelo.predict(imagen_prueba)

# Las predicciones son un arreglo de probabilidades, conviértelas a una clase
clase_predicha = np.argmax(predicciones[0])

# Obten la clase correspondiente al índice
clase = classes[clase_predicha]

# Obten el porcentaje de confianza para la clase predicha
porcentaje_confianza = predicciones[0][clase_predicha] * 100

# Carga la imagen de nuevo para mostrarla (esta vez en formato RGB para matplotlib)
imagen_prueba = cv2.cvtColor(cv2.imread(directorio_imagen_prueba), cv2.COLOR_BGR2RGB)
imagen_prueba = cv2.resize(imagen_prueba, (100, 100))
imagen_array = np.array(imagen_prueba) # Arreglo de pixeles de la imagen

plt.imshow(imagen_prueba)
plt.title("La imagen es de clase: {} con un porcentaje de confianza de: {:.2f}%".format(clase, porcentaje_confianza))
plt.show()

imagen_prueba1=cv2.resize(imagen_prueba, (30, 30))
imagen_array1=np.array(imagen_prueba1)
# Aproximar los valores de píxeles a la unidad
imagen_pixeles = np.round(color.rgb2gray(imagen_array1) * 255).astype(int)

np.set_printoptions(linewidth=np.inf)
print(f'\nArreglo de pixeles de la imagen:\n {imagen_pixeles}') #Valores entre 0 y 255
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 21
#      18 imagen_prueba = np.expand_dims(imagen_prueba, axis=0)
#      20 # Obtén las predicciones utilizando el modelo entrenado
# ---> 21 predicciones = modelo.predict(imagen_prueba)
#      23 # Las predicciones son un arreglo de probabilidades, conviértelas a una clase
#      24 clase_predicha = np.argmax(predicciones[0])
#
# NameError: name 'modelo' is not defined

# %%
def prueba_modelo(modelo, directorio, altura, longitud, classes):
    resultados = []
    for archivo in os.listdir(directorio):
        ruta_imagen = os.path.join(directorio, archivo)
        # Carga la imagen de prueba
        imagen_prueba = cv2.imread(ruta_imagen)
        imagen_prueba = cv2.resize(imagen_prueba, (altura, longitud))

        # OpenCV lee las imágenes en formato BGR, pero los modelos de Keras están entrenados con imágenes en formato RGB, por lo que es necesario convertir la imagen de BGR a RGB
        imagen_prueba = cv2.cvtColor(imagen_prueba, cv2.COLOR_BGR2RGB)

        # Convertir a float32 y normalizar
        imagen_prueba = imagen_prueba.astype('float32') / 255.0

        # Ajusta las dimensiones de la imagen para que sea compatible con la entrada del modelo
        imagen_prueba = np.expand_dims(imagen_prueba, axis=0)

        # Obtén las predicciones utilizando el modelo entrenado
        predicciones = modelo.predict(imagen_prueba)

        # Las predicciones son un arreglo de probabilidades, conviértelas a una clase
        clase_predicha = np.argmax(predicciones[0])

        # Obten la clase correspondiente al índice
        clase = classes[clase_predicha]

        resultados.append((archivo, clase))

    return resultados

# Uso de la función prueba_modelo
directorio_imagenes = './prueba'
resultados = prueba_modelo(modelo, directorio_imagenes, altura, longitud, classes)

# Mostrar resultados
for archivo, clase in resultados:
    print(f"La imagen {archivo} es de clase: {clase}")
# Out:
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# La imagen 1.jpg es de clase: 0
# La imagen 2.png es de clase: 0
# La imagen 3.jpg es de clase: 0
# La imagen 4.jpg es de clase: 0
# La imagen 5.jpg es de clase: 0
# La imagen 6.jpg es de clase: 0
# La imagen 7.jpg es de clase: 0
# La imagen 8.jpg es de clase: 0
